# %%
import os
import sys
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import nipes_data_fcts as df

# %%
loco_folder = "/home/leni/are-logs/meim_ds_loco_59_3/"

# %% [markdown]
# # Locomotion

# %%
fit_lines = []
for folder in os.listdir(loco_folder):
    if folder.split("_")[0] != "nipes":
        continue
    print(folder)
    fit_lines += [[folder] + d for d in df.load_objective_values_agg(loco_folder + "/" + folder + "/fitnesses.csv")]
fit_data = pd.DataFrame(data=fit_lines,columns=["replicate","generation","evaluations per learning","evaluations","max","min","median","mean"])
# Out:
# nipes_6_4_16-56-38-8930-2841130048
# nipes_7_4_16-57-8-8876-920240185
# nipes_6_4_16-56-42-2932-3163316319
# nipes_7_4_17-20-47-7248-2855365694
# nipes_7_4_16-57-20-904-1626602669
# nipes_6_4_16-56-32-2929-3854137100
# nipes_6_4_16-56-29-9695-1114408563
# nipes_6_4_16-56-47-7934-1033644022
# nipes_6_4_16-58-50-825-2214664548
# nipes_6_4_16-56-50-953-3406994365

# %%
print(fit_data)
# Out:
#                                replicate  generation  population size  \
# 0     nipes_6_4_16-56-38-8930-2841130048           0               50
# 1     nipes_6_4_16-56-38-8930-2841130048           1               50
# 2     nipes_6_4_16-56-38-8930-2841130048           2               50
# 3     nipes_6_4_16-56-38-8930-2841130048           3               50
# 4     nipes_6_4_16-56-38-8930-2841130048           4               50
# ...                                  ...         ...              ...
# 5513   nipes_6_4_16-56-50-953-3406994365         621              200
# 5514   nipes_6_4_16-56-50-953-3406994365         622              200
# 5515   nipes_6_4_16-56-50-953-3406994365         623              200
# 5516   nipes_6_4_16-56-50-953-3406994365         624              200
# 5517   nipes_6_4_16-56-50-953-3406994365         625              200
#
#            max       min    median      mean
# 0     0.090799  0.037102  0.067551  0.064342
# ...

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.lineplot(data=fit_data,x="generation",y="median",estimator=np.median,color='b')
sns.lineplot(data=fit_data,x="generation",y="max",linestyle=":",estimator=np.median,ci=None,color='b')
sns.lineplot(data=fit_data,x="generation",y="min",linestyle=":",estimator=np.median,ci=None,color='b')
# Out:
# /tmp/ipykernel_149570/2583238845.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=fit_data,x="generation",y="max",linestyle=":",estimator=np.median,ci=None,color='b')
# /tmp/ipykernel_149570/2583238845.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=fit_data,x="generation",y="min",linestyle=":",estimator=np.median,ci=None,color='b')
# <Axes: xlabel='generation', ylabel='median'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.lineplot(data=fit_data,x="evaluations",y="median",estimator=np.median,color='b')
sns.lineplot(data=fit_data,x="evaluations",y="max",linestyle=":",estimator=np.median,ci=None,color='b')
sns.lineplot(data=fit_data,x="evaluations",y="min",linestyle=":",estimator=np.median,ci=None,color='b')
# Out:
# /tmp/ipykernel_167358/1639126073.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=fit_data,x="evaluations",y="max",linestyle=":",estimator=np.median,ci=None,color='b')
# /tmp/ipykernel_167358/1639126073.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=fit_data,x="evaluations",y="min",linestyle=":",estimator=np.median,ci=None,color='b')
# <Axes: xlabel='evaluations', ylabel='median'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.lineplot(data=fit_data,x="generation",y="population size",estimator=np.median,color='b')
# Out:
# <Axes: xlabel='generation', ylabel='population size'>

# %% [markdown]
# # Multi target arena

# %%
mt_arena_folder = "/media/leni/DATADRIVE1/are-logs/meim_ds_10659/mt_arena/"

# %%
fit_lines = []
for folder in os.listdir(mt_arena_folder):
    if folder.split("_")[0] != "nipes":
        continue
    print(folder)
    fit_lines += [[folder] + d for d in df.load_objective_values_agg(mt_arena_folder + "/" + folder + "/fitnesses.csv")]
fit_data = pd.DataFrame(data=fit_lines,columns=["replicate","generation","population size","max","min","median"])
# Out:
# nipes_10_3_6-9-38-8936-4238617239
# nipes_9_3_11-31-45-5218-3248657693
# nipes_9_3_18-46-44-4711-3561890868
# nipes_9_3_6-21-53-3914-2381629105
# nipes_9_3_6-26-46-6956-708858767
# nipes_9_3_6-27-9-9249-2927305384
# nipes_9_3_6-8-49-9972-255271992
# nipes_9_3_6-9-13-3008-3170893490
# nipes_9_3_6-9-9-9992-4192679089

# %%
print(fit_data)
# Out:
#                               replicate  generation  population size  \
# 0     nipes_10_3_6-9-38-8936-4238617239           0               50
# 1     nipes_10_3_6-9-38-8936-4238617239           1               50
# 2     nipes_10_3_6-9-38-8936-4238617239           2               50
# 3     nipes_10_3_6-9-38-8936-4238617239           3               50
# 4     nipes_10_3_6-9-38-8936-4238617239           4               50
# ...                                 ...         ...              ...
# 9472    nipes_9_3_6-9-9-9992-4192679089         494              200
# 9473    nipes_9_3_6-9-9-9992-4192679089         495              200
# 9474    nipes_9_3_6-9-9-9992-4192679089         496              200
# 9475    nipes_9_3_6-9-9-9992-4192679089         497              200
# 9476    nipes_9_3_6-9-9-9992-4192679089         498              200
#
#            max       min    median
# 0     0.712246  0.423521  0.517601
# 1     0.645561  0.450730  0.555357
# ...

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.lineplot(data=fit_data,x="generation",y="median",estimator=np.median,color='b')
sns.lineplot(data=fit_data,x="generation",y="max",linestyle=":",estimator=np.max,ci=None,color='b')
sns.lineplot(data=fit_data,x="generation",y="min",linestyle=":",estimator=np.min,ci=None,color='b')
# Out:
# <Axes: xlabel='generation', ylabel='median'>

# %% [markdown]
# # Multi target obstacles

# %%
mt_obs_folder = "/media/leni/DATADRIVE1/are-logs/meim_ds_10659/mt_obstacles/"

# %%
fit_lines = []
for folder in os.listdir(mt_obs_folder):
    if folder.split("_")[0] != "nipes":
        continue
    print(folder)
    fit_lines += [[folder] + d for d in df.load_objective_values_agg(mt_obs_folder + "/" + folder + "/fitnesses.csv")]
fit_data = pd.DataFrame(data=fit_lines,columns=["replicate","generation","population size","max","min","median"])
# Out:
# nipes_10_3_6-9-49-9732-2393264336
# nipes_11_3_13-46-53-3448-1193117435
# nipes_11_3_20-54-46-6365-2463596210
# nipes_11_3_21-2-44-4670-2379969788
# nipes_11_3_6-10-35-5736-537443021
# nipes_11_3_6-10-39-9740-1682010489
# nipes_11_3_6-2-49-9179-3969280123
# nipes_11_3_7-43-58-8021-1361149252
# nipes_12_3_6-30-5-5528-2462763250

# %%
print(fit_data)
# Out:
#                                replicate  generation  population size  \
# 0      nipes_10_3_6-9-49-9732-2393264336           0               50
# 1      nipes_10_3_6-9-49-9732-2393264336           1               50
# 2      nipes_10_3_6-9-49-9732-2393264336           2               50
# 3      nipes_10_3_6-9-49-9732-2393264336           3               50
# 4      nipes_10_3_6-9-49-9732-2393264336           4               50
# ...                                  ...         ...              ...
# 14757  nipes_12_3_6-30-5-5528-2462763250        1995               50
# 14758  nipes_12_3_6-30-5-5528-2462763250        1996               50
# 14759  nipes_12_3_6-30-5-5528-2462763250        1997               50
# 14760  nipes_12_3_6-30-5-5528-2462763250        1998               50
# 14761  nipes_12_3_6-30-5-5528-2462763250        1999               50
#
#             max       min    median
# 0      0.719426  0.421715  0.522714
# 1      0.823259  0.417996  0.528170
# ...

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.lineplot(data=fit_data,x="generation",y="median",estimator=np.median,color='b')
sns.lineplot(data=fit_data,x="generation",y="max",linestyle=":",estimator=np.max,ci=None,color='b')
sns.lineplot(data=fit_data,x="generation",y="min",linestyle=":",estimator=np.min,ci=None,color='b')
# Out:
# <Axes: xlabel='generation', ylabel='median'>

# %% [markdown]
# # barrel arena task

# %%
b_arena_folder = "/media/leni/DATADRIVE1/are-logs/meim_ds_10659/barrel_arena/"

# %%
fit_lines = []
for folder in os.listdir(b_arena_folder):
    if folder.split("_")[0] != "nipes":
        continue
    print(folder)
    fit_lines += [[folder] + d for d in df.load_objective_values_agg(b_arena_folder + "/" + folder + "/fitnesses.csv")]
fit_data = pd.DataFrame(data=fit_lines,columns=["replicate","generation","population size","max","min","median"])
# Out:
# nipes_12_3_20-55-48-8204-922495122
# nipes_13_3_12-4-15-5123-3226474179
# nipes_13_3_14-58-0-852-3084193118
# nipes_13_3_3-3-27-7622-206507038
# nipes_13_3_5-34-59-9111-1822146970
# nipes_13_3_8-39-7-7638-2267912731
# nipes_13_3_8-4-46-6523-1509916979
# nipes_14_3_1-32-27-7545-3781933464
# nipes_14_3_2-34-2-2023-3503977273
# nipes_14_3_6-51-50-527-2262210164

# %%
print(fit_data)
# Out:
#                                 replicate  generation  population size  \
# 0      nipes_12_3_20-55-48-8204-922495122           0               50
# 1      nipes_12_3_20-55-48-8204-922495122           1               50
# 2      nipes_12_3_20-55-48-8204-922495122           2               50
# 3      nipes_12_3_20-55-48-8204-922495122           3               50
# 4      nipes_12_3_20-55-48-8204-922495122           4               50
# ...                                   ...         ...              ...
# 19695   nipes_14_3_6-51-50-527-2262210164        1995               50
# 19696   nipes_14_3_6-51-50-527-2262210164        1996               50
# 19697   nipes_14_3_6-51-50-527-2262210164        1997               50
# 19698   nipes_14_3_6-51-50-527-2262210164        1998               50
# 19699   nipes_14_3_6-51-50-527-2262210164        1999               50
#
#             max       min    median
# 0      0.485796  0.424479  0.485598
# 1      0.485795  0.485509  0.485634
# ...

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.lineplot(data=fit_data,x="generation",y="median",estimator=np.median,color='b')
sns.lineplot(data=fit_data,x="generation",y="max",linestyle=":",estimator=np.max,ci=None,color='b')
sns.lineplot(data=fit_data,x="generation",y="min",linestyle=":",estimator=np.min,ci=None,color='b')
# Out:
# <Axes: xlabel='generation', ylabel='median'>

# %% [markdown]
# # Barrel obstacles

# %%
b_obs_folder = "/media/leni/DATADRIVE1/are-logs/meim_ds_10659/barrel_obstacles/"

# %%
fit_lines = []
for folder in os.listdir(b_obs_folder):
    if folder.split("_")[0] != "nipes":
        continue
    print(folder)
    fit_lines += [[folder] + d for d in df.load_objective_values_agg(b_obs_folder + "/" + folder + "/fitnesses.csv")]
fit_data = pd.DataFrame(data=fit_lines,columns=["replicate","generation","population size","max","min","median"])
# Out:
# nipes_14_3_10-33-36-6936-3542365924
# nipes_14_3_10-46-35-5729-4026716187
# nipes_14_3_16-57-19-9635-1203626878
# nipes_14_3_17-59-53-3168-1855409520
# nipes_14_3_8-39-51-1618-2705708192
# nipes_15_3_10-59-47-7592-3363514939
# nipes_15_3_13-32-42-2248-1496997422
# nipes_15_3_13-4-44-4607-3077712694
# nipes_15_3_5-53-19-9412-3263897030
# nipes_15_3_6-33-13-3652-2612642872

# %%
print(fit_data)
# Out:
#                                  replicate  generation  population size  \
# 0      nipes_14_3_10-33-36-6936-3542365924           0               50
# 1      nipes_14_3_10-33-36-6936-3542365924           1               50
# 2      nipes_14_3_10-33-36-6936-3542365924           2               50
# 3      nipes_14_3_10-33-36-6936-3542365924           3               50
# 4      nipes_14_3_10-33-36-6936-3542365924           4               50
# ...                                    ...         ...              ...
# 19581   nipes_15_3_6-33-13-3652-2612642872        1995               50
# 19582   nipes_15_3_6-33-13-3652-2612642872        1996               50
# 19583   nipes_15_3_6-33-13-3652-2612642872        1997               50
# 19584   nipes_15_3_6-33-13-3652-2612642872        1998               50
# 19585   nipes_15_3_6-33-13-3652-2612642872        1999               50
#
#             max       min    median
# 0      0.485837  0.484763  0.485614
# ...

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.lineplot(data=fit_data,x="generation",y="median",estimator=np.median,color='b')
sns.lineplot(data=fit_data,x="generation",y="max",linestyle=":",estimator=np.max,ci=None,color='b')
sns.lineplot(data=fit_data,x="generation",y="min",linestyle=":",estimator=np.min,ci=None,color='b')
# Out:
# <Axes: xlabel='generation', ylabel='median'>
