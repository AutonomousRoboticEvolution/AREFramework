# %%
import os
import sys
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import me_data_fcts as df
sys.path.append("../meim/")
import generate_pareto_set as pareto

# %% [markdown]
# # Homeokinesis hyper-parameters

# %%
import matplotlib as mp
mp.__version__
#pd.__version__
#sns.__version__
#np.__version__
#import sklearn as sk
#sk.__version__
# Out:
# '3.9.0'

# %%
exp_folder_hk1 = "/are/logs/hk_hyperparameters/run_2/hk1"
exp_folder_hk2 = "/are/logs/hk_hyperparameters/run_2/hk2"
exp_folder_hk3 = "/are/logs/hk_hyperparameters/run_2/hk3"

# %%
parent_fits = []
for folder in os.listdir(exp_folder_hk1):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk1 + "/" + folder + "/parent_pool.csv")
    ids, parents, fitnesses, evals, deltas = df.load_fitness(exp_folder_hk1 + "/" + folder + "/fitness.csv")
    fits = [[i,p[0],p[1],f,folder] for i, p, f in zip(ids,parents,fitnesses)]
    parent_fits += df.filter_to_parent_pool(fits,parent_ids)
par_fit_data = pd.DataFrame(data=parent_fits,columns=["iteration","robot index","discretized number of robots","number of individual","number new inds","parent 1","parent 2","fitness","replicate"])
par_fit_data["hyperparameter_set"] = "hk_1"
# Out:
# meim_hk_hyperp_1_7_5_18-33-50-122-3814063005
# meim_hk_hyperp_1_7_5_18-33-50-237-1920949462
# meim_hk_hyperp_1_9_5_15-2-31-1637-1196804493
# meim_hk_hyperp_1_7_5_18-33-50-237-2042211106
# meim_hk_hyperp_1_7_5_18-33-50-123-2869319221

# %%
parent_fits = []
for folder in os.listdir(exp_folder_hk2):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk2 + "/" + folder + "/parent_pool.csv")
    ids, parents, fitnesses, evals, deltas = df.load_fitness(exp_folder_hk2 + "/" + folder + "/fitness.csv")
    fits = [[i,p[0],p[1],f,folder] for i, p, f in zip(ids,parents,fitnesses)]
    parent_fits += df.filter_to_parent_pool(fits,parent_ids)
par_fit_data2 = pd.DataFrame(data=parent_fits,columns=["iteration","robot index","discretized number of robots","number of individual","number new inds","parent 1","parent 2","fitness","replicate"])
par_fit_data2["hyperparameter_set"] = "hk_2"
# Out:
# meim_hk_hyperp_2_10_5_9-9-44-4645-2382089663
# meim_hk_hyperp_2_9_5_13-59-42-2766-3465176122
# meim_hk_hyperp_2_9_5_2-32-43-3672-4207039996
# meim_hk_hyperp_2_8_5_16-41-12-2567-2771792939
# meim_hk_hyperp_2_9_5_0-19-43-3368-634190675

# %%
parent_fits = []
for folder in os.listdir(exp_folder_hk3):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk3 + "/" + folder + "/parent_pool.csv")
    ids, parents, fitnesses, evals, deltas = df.load_fitness(exp_folder_hk3 + "/" + folder + "/fitness.csv")
    fits = [[i,p[0],p[1],f,folder] for i, p, f in zip(ids,parents,fitnesses)]
    parent_fits += df.filter_to_parent_pool(fits,parent_ids)
par_fit_data3 = pd.DataFrame(data=parent_fits,columns=["iteration","robot index","discretized number of robots","number of individual","number new inds","parent 1","parent 2","fitness","replicate"])
par_fit_data3["hyperparameter_set"] = "hk_3"
# Out:
# meim_hk_hyperp_3_12_5_0-19-58-8531-3456489584
# meim_hk_hyperp_3_10_5_12-17-38-8021-1948173645
# meim_hk_hyperp_3_11_5_16-41-30-652-3437756950
# meim_hk_hyperp_3_10_5_11-42-15-5062-521233058
# meim_hk_hyperp_3_11_5_16-41-30-767-649639651

# %%
fit_data = pd.concat([par_fit_data,par_fit_data2, par_fit_data3]).reset_index(drop=True)
print(fit_data)
# Out:
#         iteration  robot index  discretized number of robots  \
# 0               0           45                           200
# 1               0           11                           200
# 2               0           12                           200
# 3               0           55                           200
# 4               0            4                           200
# ...           ...          ...                           ...
# 257695        219         9618                          9600
# 257696        219         9720                          9600
# 257697        219         9760                          9600
# 257698        219         9832                          9600
# 257699        219         9981                          9600
#
#         number of individual  number new inds  parent 1  parent 2   fitness  \
# 0                        212              100        -1        -1  0.062500
# 1                        212              100        -1        -1  0.046875
# 2                        212              100        -1        -1  0.062500
# 3                        212              100        -1        -1  0.062500
# 4                        212              100        -1        -1  0.078125
# ...                      ...              ...       ...       ...       ...
# 257695                  9601                1      7436        -1  0.640625
# 257696                  9601                1      7436        -1  0.687500
# 257697                  9601                1      5507        -1  0.640625
# 257698                  9601                1      8886        -1  0.640625
# 257699                  9601                1      8768        -1  0.656250
#
#                                            replicate hyperparameter_set
# 0       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005               hk_1
# 1       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005               hk_1
# 2       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005               hk_1
# 3       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005               hk_1
# 4       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005               hk_1
# ...                                              ...                ...
# 257695  meim_hk_hyperp_3_11_5_16-41-30-767-649639651               hk_3
# 257696  meim_hk_hyperp_3_11_5_16-41-30-767-649639651               hk_3
# 257697  meim_hk_hyperp_3_11_5_16-41-30-767-649639651               hk_3
# 257698  meim_hk_hyperp_3_11_5_16-41-30-767-649639651               hk_3
# 257699  meim_hk_hyperp_3_11_5_16-41-30-767-649639651               hk_3
#
# [257700 rows x 10 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=fit_data,x="iteration",y="fitness",hue="hyperparameter_set", estimator=np.median,color='b')
sns.lineplot(data=fit_data,x="iteration",y="fitness",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='b')
sns.lineplot(data=fit_data,x="iteration",y="fitness",hue="hyperparameter_set", linestyle=":",estimator=np.min,ci=None,color='b')
# Out:
# /tmp/ipykernel_2049/2740145824.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=fit_data,x="iteration",y="fitness",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='b')
# /tmp/ipykernel_2049/2740145824.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=fit_data,x="iteration",y="fitness",hue="hyperparameter_set", linestyle=":",estimator=np.min,ci=None,color='b')
# <Axes: xlabel='iteration', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=fit_data,x="discretized number of robots",y="fitness",hue="hyperparameter_set",estimator=np.median,color='b')
sns.lineplot(data=fit_data,x="discretized number of robots",y="fitness",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='b')
sns.lineplot(data=fit_data,x="discretized number of robots",y="fitness",hue="hyperparameter_set",linestyle=":",estimator=np.min,ci=None,color='b')
ax.set_xticks(range(0,10500,500))
ax.set_xlabel("number of robots")
# Out:
# /tmp/ipykernel_2049/945659457.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=fit_data,x="discretized number of robots",y="fitness",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='b')
# /tmp/ipykernel_2049/945659457.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=fit_data,x="discretized number of robots",y="fitness",hue="hyperparameter_set",linestyle=":",estimator=np.min,ci=None,color='b')
# Text(0.5, 0, 'number of robots')

# %% [markdown]
# # Vector descriptor

# %%
import importlib
importlib.reload(df)
parent_descs = []
for folder in os.listdir(exp_folder_hk1):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk1 + "/" + folder + "/parent_pool.csv")
    ids, parents, fitnesses, evals, deltas = df.load_fitness(exp_folder_hk1 + "/" + folder + "/fitness.csv")
    fits = [[i,p[0],p[1],f,folder] for i, p, f in zip(ids,parents,fitnesses)]
    #print(parent_ids)
    descriptors = df.load_feature_descriptor(exp_folder_hk1 + "/" + folder + "/morph_features.csv")
    #print("main", descriptors)
    descs = [d +[folder] for d in descriptors]
    #print(descs)
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_desc_data1 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","width","depth","height","voxels","wheels","sensors","joints","casters","norm","replicate"])
par_desc_data1["hyperparameter_set"] = "HK1"
# Out:
# meim_hk_hyperp_1_7_5_18-33-50-122-3814063005
# meim_hk_hyperp_1_7_5_18-33-50-237-1920949462
# meim_hk_hyperp_1_9_5_15-2-31-1637-1196804493
# meim_hk_hyperp_1_7_5_18-33-50-237-2042211106
# meim_hk_hyperp_1_7_5_18-33-50-123-2869319221

# %%
parent_descs = []
for folder in os.listdir(exp_folder_hk2):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk2 + "/" + folder + "/parent_pool.csv")
    descriptors = df.load_feature_descriptor(exp_folder_hk2 + "/" + folder + "/morph_features.csv")
    descs = [d +[folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_desc_data2 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","width","depth","height","voxels","wheels","sensors","joints","casters","norm","replicate"])
par_desc_data2["hyperparameter_set"] = "HK2"
# Out:
# meim_hk_hyperp_2_10_5_9-9-44-4645-2382089663
# meim_hk_hyperp_2_9_5_13-59-42-2766-3465176122
# meim_hk_hyperp_2_9_5_2-32-43-3672-4207039996
# meim_hk_hyperp_2_8_5_16-41-12-2567-2771792939
# meim_hk_hyperp_2_9_5_0-19-43-3368-634190675

# %%
parent_descs = []
for folder in os.listdir(exp_folder_hk3):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk3 + "/" + folder + "/parent_pool.csv")
    descriptors = df.load_feature_descriptor(exp_folder_hk3 + "/" + folder + "/morph_features.csv")
    descs = [d +[folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_desc_data3 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","width","depth","height","voxels","wheels","sensors","joints","casters","norm","replicate"])
par_desc_data3["hyperparameter_set"] = "HK3"
# Out:
# meim_hk_hyperp_3_12_5_0-19-58-8531-3456489584
# meim_hk_hyperp_3_10_5_12-17-38-8021-1948173645
# meim_hk_hyperp_3_11_5_16-41-30-652-3437756950
# meim_hk_hyperp_3_10_5_11-42-15-5062-521233058
# meim_hk_hyperp_3_11_5_16-41-30-767-649639651

# %%
desc_data = pd.concat([par_desc_data1,par_desc_data2,par_desc_data3]).reset_index(drop=True)
print(desc_data)
# Out:
#         iteration  robot index  discretized number of robots  \
# 0               0           45                           200
# 1               0           11                           200
# 2               0           12                           200
# 3               0           55                           200
# 4               0            4                           200
# ...           ...          ...                           ...
# 257695        219         9618                          9600
# 257696        219         9720                          9600
# 257697        219         9760                          9600
# 257698        219         9832                          9600
# 257699        219         9981                          9600
#
#         number of individuals  number new inds     width     depth    height  \
# 0                         212              100  0.162182  0.180001  0.383636
# 1                         212              100  0.108001  0.162182  0.419636
# 2                         212              100  0.162182  0.180001  0.347636
# 3                         212              100  0.324000  0.134909  0.311636
# 4                         212              100  0.360000  0.306546  0.205455
# ...                       ...              ...       ...       ...       ...
# 257695                   9601                1  0.261455  0.252364  0.145455
# 257696                   9601                1  0.261454  0.252364  0.145455
# 257697                   9601                1  0.261455  0.261455  0.145455
# 257698                   9601                1  0.261455  0.252364  0.145455
# 257699                   9601                1  0.261455  0.252364  0.145455
#
#           voxels  wheels  sensors  joints  casters      norm  \
# 0       0.489857  0.0625   0.0000   0.000   0.0000  0.670631
# 1       0.526672  0.0625   0.0000   0.000   0.0000  0.703812
# 2       0.762585  0.1250   0.0000   0.000   0.0000  0.881314
# 3       0.410218  0.1250   0.0000   0.000   0.3750  0.738121
# 4       0.338843  0.0000   0.0000   0.125   0.4375  0.766569
# ...          ...     ...      ...     ...      ...       ...
# 257695  0.018032  0.3125   0.0000   0.125   0.0000  0.516536
# 257696  0.018032  0.3125   0.0000   0.125   0.0000  0.516536
# 257697  0.018032  0.2500   0.1250   0.000   0.0000  0.486132
# 257698  0.018032  0.3125   0.0000   0.125   0.0000  0.516536
# 257699  0.018032  0.3125   0.0625   0.000   0.0000  0.505065
#
#                                            replicate hyperparameter_set
# 0       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# 1       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# 2       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# 3       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# 4       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# ...                                              ...                ...
# 257695  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
# 257696  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
# 257697  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
# 257698  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
# 257699  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
#
# [257700 rows x 16 columns]

# %%
new_data_list = []
for rep in desc_data["replicate"].drop_duplicates():
    print(rep)
    tmp_data = desc_data.loc[desc_data["replicate"]==rep]
    ctrl_type = tmp_data["hyperparameter_set"].drop_duplicates().values[0]
    print(ctrl_type)
    for iter in tmp_data["iteration"].drop_duplicates():
        tmp_data2 = tmp_data.loc[tmp_data["iteration"] == iter]
        new_data = pd.DataFrame(tmp_data2.std(numeric_only=True)).transpose()
        new_data.reset_index()
        new_data["replicate"] = rep
        new_data["iteration"] = iter
        new_data["hyperparameter_set"] = ctrl_type
        new_data_list.append(new_data)

std_data = pd.concat(new_data_list)
# Out:
# meim_hk_hyperp_1_7_5_18-33-50-122-3814063005
# HK1
# meim_hk_hyperp_1_7_5_18-33-50-237-1920949462
# HK1
# meim_hk_hyperp_1_9_5_15-2-31-1637-1196804493
# HK1
# meim_hk_hyperp_1_7_5_18-33-50-237-2042211106
# HK1
# meim_hk_hyperp_1_7_5_18-33-50-123-2869319221
# HK1
# meim_hk_hyperp_2_10_5_9-9-44-4645-2382089663
# HK2
# meim_hk_hyperp_2_9_5_13-59-42-2766-3465176122
# HK2
# meim_hk_hyperp_2_9_5_2-32-43-3672-4207039996
# HK2
# meim_hk_hyperp_2_8_5_16-41-12-2567-2771792939
# HK2
# meim_hk_hyperp_2_9_5_0-19-43-3368-634190675
# HK2
# meim_hk_hyperp_3_12_5_0-19-58-8531-3456489584
# HK3
# meim_hk_hyperp_3_10_5_12-17-38-8021-1948173645
# HK3
# meim_hk_hyperp_3_11_5_16-41-30-652-3437756950
# HK3
# meim_hk_hyperp_3_10_5_11-42-15-5062-521233058
# HK3
# meim_hk_hyperp_3_11_5_16-41-30-767-649639651
# HK3

# %%
std_data.index  = [i for i in range(len(std_data))]
print(std_data)
# Out:
#       iteration  robot index  discretized number of robots  \
# 0             0    65.401896                           0.0
# 1             1    79.904470                           0.0
# 2             2    79.723522                           0.0
# 3             3    78.251779                           0.0
# 4             4    77.383670                           0.0
# ...         ...          ...                           ...
# 2572        215  2201.970543                           0.0
# 2573        216  2211.402451                           0.0
# 2574        217  2221.128110                           0.0
# 2575        218  2234.193401                           0.0
# 2576        219  2249.393279                           0.0
#
#       number of individuals  number new inds     width     depth  \
# 0                       0.0              0.0  0.064848  0.077271
# 1                       0.0              0.0  0.061957  0.077868
# 2                       0.0              0.0  0.044316  0.058893
# 3                       0.0              0.0  0.046326  0.058401
# 4                       0.0              0.0  0.025940  0.032171
# ...                     ...              ...       ...       ...
# 2572                    0.0              0.0  0.003073  0.003432
# 2573                    0.0              0.0  0.003073  0.003432
# 2574                    0.0              0.0  0.003073  0.003510
# 2575                    0.0              0.0  0.003073  0.003510
# 2576                    0.0              0.0  0.003073  0.003510
#
#             height        voxels    wheels   sensors    joints   casters  \
# 0     1.051339e-01  2.073695e-01  0.126967  0.106778  0.204510  0.114680
# 1     1.018064e-01  1.987906e-01  0.130104  0.110830  0.199494  0.107895
# 2     9.563520e-02  1.993374e-01  0.133740  0.097594  0.200296  0.081153
# 3     9.671029e-02  2.014218e-01  0.136288  0.098463  0.204043  0.078204
# 4     6.594452e-02  1.106563e-01  0.123098  0.077573  0.205952  0.088066
# ...            ...           ...       ...       ...       ...       ...
# 2572  3.144660e-07  3.486925e-18  0.030327  0.052835  0.058062  0.000000
# 2573  3.144660e-07  3.486925e-18  0.030327  0.052869  0.056895  0.000000
# 2574  3.144660e-07  3.486925e-18  0.030489  0.053537  0.058062  0.000000
# 2575  3.144660e-07  3.486925e-18  0.030327  0.053577  0.058062  0.000000
# 2576  3.144660e-07  3.486925e-18  0.030327  0.053537  0.059179  0.000000
#
#           norm                                     replicate  \
# 0     0.118339  meim_hk_hyperp_1_7_5_18-33-50-122-3814063005
# 1     0.114751  meim_hk_hyperp_1_7_5_18-33-50-122-3814063005
# 2     0.128929  meim_hk_hyperp_1_7_5_18-33-50-122-3814063005
# 3     0.131112  meim_hk_hyperp_1_7_5_18-33-50-122-3814063005
# 4     0.095940  meim_hk_hyperp_1_7_5_18-33-50-122-3814063005
# ...        ...                                           ...
# 2572  0.014194  meim_hk_hyperp_3_11_5_16-41-30-767-649639651
# 2573  0.014202  meim_hk_hyperp_3_11_5_16-41-30-767-649639651
# 2574  0.014383  meim_hk_hyperp_3_11_5_16-41-30-767-649639651
# 2575  0.014188  meim_hk_hyperp_3_11_5_16-41-30-767-649639651
# 2576  0.014181  meim_hk_hyperp_3_11_5_16-41-30-767-649639651
#
#      hyperparameter_set
# 0                   HK1
# 1                   HK1
# 2                   HK1
# 3                   HK1
# 4                   HK1
# ...                 ...
# 2572                HK3
# 2573                HK3
# 2574                HK3
# 2575                HK3
# 2576                HK3
#
# [2577 rows x 16 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=std_data.loc[std_data["hyperparameter_set"] == "HK2"],x="iteration",y="norm",hue="replicate", estimator=None,color='g')
ax.set_ylabel("Morphological diversity no estimator")
# Out:
# Text(0, 0.5, 'Morphological diversity no estimator')

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=std_data,x="iteration",y="norm",hue="hyperparameter_set", estimator=np.median,color='g')
sns.lineplot(data=std_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='g')
sns.lineplot(data=std_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.min,ci=None,color='g')
ax.set_ylabel("Morphological diversity")
# Out:
# /tmp/ipykernel_2049/2416703732.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=std_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='g')
# /tmp/ipykernel_2049/2416703732.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=std_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.min,ci=None,color='g')
# Text(0, 0.5, 'Morphological diversity')

# %%
# Blox plot
# select single robot index by replicate, box ploxt depth, height, voxels, wheels... etc 
#par_desc_data3[(par_desc_data3['robot index'] == 5) & (par_desc_data3['replicate']=='meim_hk_hyperp_3_12_5_0-19-58-8531-3456489584')].drop_duplicates(subset=['robot index','replicate'])
all_robots_desc = desc_data.drop_duplicates(subset=['robot index','replicate'])

# %%
sns.violinplot(all_robots_desc, y='width', hue='hyperparameter_set')
plt.show()
sns.violinplot(all_robots_desc, y='depth', hue='hyperparameter_set')
plt.show()
sns.violinplot(all_robots_desc, y='height', hue='hyperparameter_set')
plt.show()
sns.violinplot(all_robots_desc, y='voxels', hue='hyperparameter_set')
plt.show()
sns.violinplot(all_robots_desc, y='wheels', hue='hyperparameter_set')
plt.show()
sns.violinplot(all_robots_desc, y='sensors', hue='hyperparameter_set')
plt.show()
sns.violinplot(all_robots_desc, y='joints', hue='hyperparameter_set')
plt.show()
sns.violinplot(all_robots_desc, y='casters', hue='hyperparameter_set')
plt.show()

# %% [markdown]
# # Matrix descriptor

# %%
parent_descs = []
for folder in os.listdir(exp_folder_hk1):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk1 + "/" + folder + "/parent_pool.csv")
    descriptors = df.load_component_descriptor(exp_folder_hk1 + "/" + folder + "/morph_descriptor.csv")
    
    descs = [[d[0],d[-1],folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_mdesc_data1 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","norm","replicate"])
par_mdesc_data1["hyperparameter_set"] = "HK1"
# Out:
# meim_hk_hyperp_1_7_5_18-33-50-122-3814063005
# meim_hk_hyperp_1_7_5_18-33-50-237-1920949462
# meim_hk_hyperp_1_9_5_15-2-31-1637-1196804493
# meim_hk_hyperp_1_7_5_18-33-50-237-2042211106
# meim_hk_hyperp_1_7_5_18-33-50-123-2869319221

# %%
parent_descs = []
for folder in os.listdir(exp_folder_hk2):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk2 + "/" + folder + "/parent_pool.csv")
    descriptors = df.load_component_descriptor(exp_folder_hk2 + "/" + folder + "/morph_descriptor.csv")
    
    descs = [[d[0],d[-1],folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_mdesc_data2 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","norm","replicate"])
par_mdesc_data2["hyperparameter_set"] = "HK2"
# Out:
# meim_hk_hyperp_2_10_5_9-9-44-4645-2382089663
# meim_hk_hyperp_2_9_5_13-59-42-2766-3465176122
# meim_hk_hyperp_2_9_5_2-32-43-3672-4207039996
# meim_hk_hyperp_2_8_5_16-41-12-2567-2771792939
# meim_hk_hyperp_2_9_5_0-19-43-3368-634190675

# %%
parent_descs = []
for folder in os.listdir(exp_folder_hk3):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk3 + "/" + folder + "/parent_pool.csv")
    descriptors = df.load_component_descriptor(exp_folder_hk3 + "/" + folder + "/morph_descriptor.csv")
    
    descs = [[d[0],d[-1],folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_mdesc_data3 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","norm","replicate"])
par_mdesc_data3["hyperparameter_set"] = "HK3"
# Out:
# meim_hk_hyperp_3_12_5_0-19-58-8531-3456489584
# meim_hk_hyperp_3_10_5_12-17-38-8021-1948173645
# meim_hk_hyperp_3_11_5_16-41-30-652-3437756950
# meim_hk_hyperp_3_10_5_11-42-15-5062-521233058
# meim_hk_hyperp_3_11_5_16-41-30-767-649639651

# %%
mdesc_data = pd.concat([par_mdesc_data1,par_mdesc_data2,par_mdesc_data3]).reset_index(drop=True)
print(mdesc_data)
# Out:
#         iteration  robot index  discretized number of robots  \
# 0               0           45                           200
# 1               0           11                           200
# 2               0           12                           200
# 3               0           55                           200
# 4               0            4                           200
# ...           ...          ...                           ...
# 257695        219         9618                          9600
# 257696        219         9720                          9600
# 257697        219         9760                          9600
# 257698        219         9832                          9600
# 257699        219         9981                          9600
#
#         number of individuals  number new inds       norm  \
# 0                         212              100   1.000000
# 1                         212              100   1.000000
# 2                         212              100   1.414214
# 3                         212              100   9.899495
# 4                         212              100  11.000000
# ...                       ...              ...        ...
# 257695                   9601                1   3.741657
# 257696                   9601                1   3.741657
# 257697                   9601                1   3.464102
# 257698                   9601                1   3.741657
# 257699                   9601                1   3.000000
#
#                                            replicate hyperparameter_set
# 0       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# 1       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# 2       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# 3       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# 4       meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# ...                                              ...                ...
# 257695  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
# 257696  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
# 257697  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
# 257698  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
# 257699  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
#
# [257700 rows x 8 columns]

# %%
new_data_list = []
for rep in mdesc_data["replicate"].drop_duplicates():
    print(rep)
    tmp_data = mdesc_data.loc[desc_data["replicate"]==rep]
    ctrl_type = tmp_data["hyperparameter_set"].drop_duplicates().values[0]
    print(ctrl_type)
    for iter in tmp_data["iteration"].drop_duplicates():
        tmp_data2 = tmp_data.loc[tmp_data["iteration"] == iter]
        new_data = pd.DataFrame(tmp_data2.std(numeric_only=True)).transpose()
        new_data.reset_index()
        new_data["replicate"] = rep
        new_data["iteration"] = iter
        new_data["hyperparameter_set"] = ctrl_type
        new_data_list.append(new_data)

mstd_data = pd.concat(new_data_list)
# Out:
# meim_hk_hyperp_1_7_5_18-33-50-122-3814063005
# HK1
# meim_hk_hyperp_1_7_5_18-33-50-237-1920949462
# HK1
# meim_hk_hyperp_1_9_5_15-2-31-1637-1196804493
# HK1
# meim_hk_hyperp_1_7_5_18-33-50-237-2042211106
# HK1
# meim_hk_hyperp_1_7_5_18-33-50-123-2869319221
# HK1
# meim_hk_hyperp_2_10_5_9-9-44-4645-2382089663
# HK2
# meim_hk_hyperp_2_9_5_13-59-42-2766-3465176122
# HK2
# meim_hk_hyperp_2_9_5_2-32-43-3672-4207039996
# HK2
# meim_hk_hyperp_2_8_5_16-41-12-2567-2771792939
# HK2
# meim_hk_hyperp_2_9_5_0-19-43-3368-634190675
# HK2
# meim_hk_hyperp_3_12_5_0-19-58-8531-3456489584
# HK3
# meim_hk_hyperp_3_10_5_12-17-38-8021-1948173645
# HK3
# meim_hk_hyperp_3_11_5_16-41-30-652-3437756950
# HK3
# meim_hk_hyperp_3_10_5_11-42-15-5062-521233058
# HK3
# meim_hk_hyperp_3_11_5_16-41-30-767-649639651
# HK3

# %%
mstd_data.index  = [i for i in range(len(mstd_data))]
print(mstd_data)
# Out:
#       iteration  robot index  discretized number of robots  \
# 0             0    65.401896                           0.0
# 1             1    79.904470                           0.0
# 2             2    79.723522                           0.0
# 3             3    78.251779                           0.0
# 4             4    77.383670                           0.0
# ...         ...          ...                           ...
# 2572        215  2201.970543                           0.0
# 2573        216  2211.402451                           0.0
# 2574        217  2221.128110                           0.0
# 2575        218  2234.193401                           0.0
# 2576        219  2249.393279                           0.0
#
#       number of individuals  number new inds      norm  \
# 0                       0.0              0.0  2.366878
# 1                       0.0              0.0  2.131120
# 2                       0.0              0.0  1.949479
# 3                       0.0              0.0  1.916926
# 4                       0.0              0.0  2.133227
# ...                     ...              ...       ...
# 2572                    0.0              0.0  0.387919
# 2573                    0.0              0.0  0.378123
# 2574                    0.0              0.0  0.380128
# 2575                    0.0              0.0  0.379502
# 2576                    0.0              0.0  0.389136
#
#                                          replicate hyperparameter_set
# 0     meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# 1     meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# 2     meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# 3     meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# 4     meim_hk_hyperp_1_7_5_18-33-50-122-3814063005                HK1
# ...                                            ...                ...
# 2572  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
# 2573  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
# 2574  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
# 2575  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
# 2576  meim_hk_hyperp_3_11_5_16-41-30-767-649639651                HK3
#
# [2577 rows x 8 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=mstd_data,x="iteration",y="norm",hue="hyperparameter_set", estimator=np.median,color='g')
sns.lineplot(data=mstd_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='g')
sns.lineplot(data=mstd_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.min,ci=None,color='g')
ax.set_ylabel("Morphological matrix descriptor diversity")
# Out:
# /tmp/ipykernel_717/1731107229.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=mstd_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='g')
# /tmp/ipykernel_717/1731107229.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=mstd_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.min,ci=None,color='g')
# Text(0, 0.5, 'Morphological matrix descriptor diversity')

# %% [markdown]
# # ME FC

# %%
exp_folder = "/media/leni/DATADRIVE1/are-logs/mefc/"

# %%
parent_fits = []
for folder in os.listdir(exp_folder):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder + "/" + folder + "/parents_pool.csv")
    ids, parents, fitnesses, evals, deltas = df.load_fitness(exp_folder + "/" + folder + "/fitness.csv")
    fits = [[i,p[0],p[1],f,folder] for i, p, f in zip(ids,parents,fitnesses)]
    parent_fits += df.filter_to_parent_pool(fits,parent_ids)
par_fit_data = pd.DataFrame(data=parent_fits,columns=["iteration","robot index","number new inds","parent 1","parent 2","fitness","replicate"])
# Out:
# meim_22_3_10-26-37-7769-2279963877
# meim_22_3_10-26-40-740-2350202888
# meim_22_3_10-26-45-5733-2586739213
# meim_22_3_10-26-48-8775-3296345534
# meim_22_3_10-26-48-8808-648423813
# meim_22_3_10-26-51-1735-2541492157
# meim_22_3_10-27-0-446-409001623
# meim_22_3_16-46-47-7376-4018957153

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=par_fit_data,x="iteration",y="fitness",estimator=np.median,color='b')
sns.lineplot(data=par_fit_data,x="iteration",y="fitness",linestyle=":",estimator=np.max,ci=None,color='b')
sns.lineplot(data=par_fit_data,x="iteration",y="fitness",linestyle=":",estimator=np.min,ci=None,color='b')
# Out:
# <Axes: xlabel='iteration', ylabel='fitness'>

# %%
parent_descs = []
for folder in os.listdir(exp_folder):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder + "/" + folder + "/parents_pool.csv")
    descriptors = df.load_descriptor(exp_folder + "/" + folder + "/morph_features.csv")
    descs = [d +[folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_desc_data = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","number new inds","width","depth","height","voxels","wheels","sensors","joints","casters","norm","replicate"])
# Out:
# meim_22_3_10-26-37-7769-2279963877
# meim_22_3_10-26-40-740-2350202888
# meim_22_3_10-26-45-5733-2586739213
# meim_22_3_10-26-48-8775-3296345534
# meim_22_3_10-26-48-8808-648423813
# meim_22_3_10-26-51-1735-2541492157
# meim_22_3_10-27-0-446-409001623
# meim_22_3_16-46-47-7376-4018957153

# %%
fig = plt.gcf()
fig.set_size_inches(40,20)
ax = sns.relplot(data=par_desc_data,kind="line",x="iteration",y="norm",estimator=np.std,color='b',row="replicate")
# Out:
# /home/leni/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:88: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
new_data_list = []
for rep in par_desc_data["replicate"].drop_duplicates():
    print(rep)
    tmp_data = par_desc_data.loc[par_desc_data["replicate"]==rep]
    for iter in tmp_data["iteration"].drop_duplicates():
        tmp_data2 = tmp_data.loc[tmp_data["iteration"] == iter]
        new_data = pd.DataFrame(tmp_data2.std(numeric_only=True)).transpose()
        new_data.reset_index()
        new_data["replicate"] = rep
        new_data["iteration"] = iter
        new_data_list.append(new_data)

std_data = pd.concat(new_data_list)
# Out:
# meim_22_3_10-26-37-7769-2279963877
# meim_22_3_10-26-40-740-2350202888
# meim_22_3_10-26-45-5733-2586739213
# meim_22_3_10-26-48-8775-3296345534
# meim_22_3_10-26-48-8808-648423813
# meim_22_3_10-26-51-1735-2541492157
# meim_22_3_10-27-0-446-409001623
# meim_22_3_16-46-47-7376-4018957153

# %%
#std_data.reset_index()
std_data.index  = [i for i in range(len(std_data))]
print(std_data)
# Out:
#       iteration  robot index  number new inds     width     depth    height  \
# 0             0    59.999370              0.0  0.083648  0.084653  0.111436
# 1             1    72.725422              0.0  0.085624  0.085478  0.110240
# 2             2    78.299789              0.0  0.071787  0.067596  0.104831
# 3             3    79.450560              0.0  0.070796  0.066999  0.106152
# 4             4    85.422174              0.0  0.059241  0.060142  0.106733
# ...         ...          ...              ...       ...       ...       ...
# 1838        212  3280.844382              0.0  0.010411  0.016524  0.030822
# 1839        213  3309.398210              0.0  0.010411  0.016524  0.030822
# 1840        214  3336.323147              0.0  0.010411  0.016524  0.031165
# 1841        215  3362.501228              0.0  0.010711  0.016524  0.031165
# 1842        216  3388.882061              0.0  0.010711  0.016524  0.031165
#
#         voxels    wheels  sensors    joints   casters      norm  \
# 0     0.220457  0.117925      0.0  0.193889  0.133751  0.134259
# 1     0.217361  0.114542      0.0  0.194625  0.133740  0.137393
# 2     0.198411  0.088825      0.0  0.135884  0.118845  0.126209
# 3     0.202459  0.089053      0.0  0.126200  0.118017  0.125818
# 4     0.199537  0.091882      0.0  0.116883  0.117950  0.125313
# ...        ...       ...      ...       ...       ...       ...
# 1838  0.080151  0.032054      0.0  0.066430  0.056446  0.067555
# 1839  0.080151  0.032054      0.0  0.066430  0.056446  0.067555
# 1840  0.080151  0.032054      0.0  0.066430  0.056446  0.067744
# 1841  0.080151  0.032054      0.0  0.066430  0.056446  0.067787
# 1842  0.080151  0.032054      0.0  0.066430  0.056446  0.067787
#
#                                replicate
# 0     meim_22_3_10-26-37-7769-2279963877
# 1     meim_22_3_10-26-37-7769-2279963877
# 2     meim_22_3_10-26-37-7769-2279963877
# 3     meim_22_3_10-26-37-7769-2279963877
# 4     meim_22_3_10-26-37-7769-2279963877
# ...                                  ...
# 1838  meim_22_3_16-46-47-7376-4018957153
# 1839  meim_22_3_16-46-47-7376-4018957153
# 1840  meim_22_3_16-46-47-7376-4018957153
# 1841  meim_22_3_16-46-47-7376-4018957153
# 1842  meim_22_3_16-46-47-7376-4018957153
#
# [1843 rows x 13 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=std_data,x="iteration",y="norm",estimator=np.median,color='g')
sns.lineplot(data=std_data,x="iteration",y="norm",linestyle=":",estimator=np.max,ci=None,color='g')
sns.lineplot(data=std_data,x="iteration",y="norm",linestyle=":",estimator=np.min,ci=None,color='g')
ax.set_ylabel("Morphological diversity")
# Out:
# Text(0, 0.5, 'Morphological diversity')

# %% [markdown]
# # MEIM vs MEFC

# %%
meim_folder = "/media/leni/DATADRIVE1/are-logs/meim/"
mefc_folder = "/media/leni/DATADRIVE1/are-logs/mefc/"

# %% [markdown]
# ## Fitness Values

# %%
parent_fits = []
for folder in os.listdir(meim_folder):
    print(folder)
    parent_ids = df.load_parent_pool(meim_folder + "/" + folder + "/parents_pool.csv")
    ids, parents, fitnesses, evals, deltas = df.load_fitness(meim_folder + "/" + folder + "/fitness.csv")
    fits = [[i,p[0],p[1],f,folder] for i, p, f in zip(ids,parents,fitnesses)]
    parent_fits += df.filter_to_parent_pool(fits,parent_ids)
par_fit_data = pd.DataFrame(data=parent_fits,columns=["iteration","robot index","discretized number of robots","number of individual","number new inds","parent 1","parent 2","fitness","replicate"])
par_fit_data["controller_type"] = "Homeokinesis"
# Out:
# meim_16_3_16-56-39-9868-18373300
# meim_16_3_16-56-42-2870-2796053236
# meim_16_3_16-56-45-5895-1777546940
# meim_16_3_16-56-45-5917-957574002
# meim_16_3_16-56-48-8931-985534567
# meim_16_3_16-56-48-8936-2561894498
# meim_16_3_16-56-51-1885-639115363
# meim_16_3_17-8-55-5548-2215134775
# meim_17_3_11-31-49-9733-2516969209
# meim_17_3_11-37-2-2832-3966900741
# meim_18_3_11-38-15-5621-745283126
# meim_18_3_11-38-18-8916-724015239
# meim_18_3_11-38-21-1936-3632418103
# meim_18_3_11-38-24-4661-1432447149
# meim_18_3_11-38-27-7900-2266432585
# meim_18_3_11-38-30-917-761405749
# meim_18_3_15-22-21-1418-481348034
# meim_18_3_15-22-51-1987-1456279332

# %%
parent_fits = []
for folder in os.listdir(mefc_folder):
    print(folder)
    parent_ids = df.load_parent_pool(mefc_folder + "/" + folder + "/parents_pool.csv")
    ids, parents, fitnesses, evals, deltas = df.load_fitness(mefc_folder + "/" + folder + "/fitness.csv")
    fits = [[i,p[0],p[1],f,folder] for i, p, f in zip(ids,parents,fitnesses)]
    parent_fits += df.filter_to_parent_pool(fits,parent_ids)
par_fit_data2 = pd.DataFrame(data=parent_fits,columns=["iteration","robot index","discretized number of robots","number of individual","number new inds","parent 1","parent 2","fitness","replicate"])
par_fit_data2["controller_type"] = "Fixed Controller"
# Out:
# meim_22_3_10-26-37-7769-2279963877
# meim_22_3_10-26-40-740-2350202888
# meim_22_3_10-26-45-5733-2586739213
# meim_22_3_10-26-48-8775-3296345534
# meim_22_3_10-26-48-8808-648423813
# meim_22_3_10-26-51-1735-2541492157
# meim_22_3_10-27-0-446-409001623
# meim_22_3_16-46-47-7376-4018957153
# meim_23_3_10-21-12-2712-36198185
# meim_23_3_10-21-15-5656-1313689609
# meim_23_3_10-21-19-9642-703440127
# meim_23_3_10-21-22-2697-202336983
# meim_23_3_10-21-3-3665-3559667224
# meim_23_3_10-21-6-6642-2099145537
# meim_23_3_10-21-9-9708-1821580459
# meim_23_3_13-2-25-5699-3641383181

# %%
fit_data = pd.concat([par_fit_data,par_fit_data2]).reset_index(drop=True)
print(fit_data)
# Out:
#         iteration  robot index  discretized number of robots  \
# 0               0           26                           250
# 1               0           59                           250
# 2               0           22                           250
# 3               0           48                           250
# 4               0           51                           250
# ...           ...          ...                           ...
# 965395        193        10374                         10050
# 965396        193        10583                         10050
# 965397        193        10949                         10050
# 965398        193        11153                         10050
# 965399        193        11237                         10050
#
#         number of individual  number new inds  parent 1  parent 2   fitness  \
# 0                        242              100        -1        -1  0.046875
# 1                        242              100        -1        -1  0.062500
# 2                        242              100        -1        -1  0.093750
# 3                        242              100        -1        -1  0.093750
# 4                        242              100        -1        -1  0.046875
# ...                      ...              ...       ...       ...       ...
# 965395                 10036                1      3485        -1  0.343750
# 965396                 10036                1     10020        -1  0.328125
# 965397                 10036                1     10020        -1  0.343750
# 965398                 10036                1      6453        -1  0.328125
# 965399                 10036                1      5357        -1  0.343750
#
#                                 replicate   controller_type
# 0        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 1        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 2        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 3        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 4        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# ...                                   ...               ...
# 965395  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 965396  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 965397  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 965398  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 965399  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
#
# [965400 rows x 10 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=fit_data,x="iteration",y="fitness",hue="controller_type",estimator=np.median,color='b')
sns.lineplot(data=fit_data,x="iteration",y="fitness",hue="controller_type",linestyle=":",estimator=np.max,ci=None,color='b')
sns.lineplot(data=fit_data,x="iteration",y="fitness",hue="controller_type",linestyle=":",estimator=np.min,ci=None,color='b')
# Out:
# <Axes: xlabel='iteration', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=fit_data,x="discretized number of robots",y="fitness",hue="controller_type",estimator=np.median,color='b')
sns.lineplot(data=fit_data,x="discretized number of robots",y="fitness",hue="controller_type",linestyle=":",estimator=np.max,ci=None,color='b')
sns.lineplot(data=fit_data,x="discretized number of robots",y="fitness",hue="controller_type",linestyle=":",estimator=np.min,ci=None,color='b')
ax.set_xticks(range(0,10500,500))
ax.set_xlabel("number of robots")
# Out:
# Text(0.5, 0, 'number of robots')

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=fit_data,x="iteration",y="number new inds",hue="controller_type",estimator=np.median,color='b')
sns.lineplot(data=fit_data,x="iteration",y="number new inds",hue="controller_type",linestyle=":",estimator=np.max,ci=None,color='b')
sns.lineplot(data=fit_data,x="iteration",y="number new inds",hue="controller_type",linestyle=":",estimator=np.min,ci=None,color='b')
# Out:
# <Axes: xlabel='iteration', ylabel='number new inds'>

# %% [markdown]
# ## Diversity
# ### Feature descriptor

# %%
parent_descs = []
for folder in os.listdir(meim_folder):
    print(folder)
    parent_ids = df.load_parent_pool(meim_folder + "/" + folder + "/parents_pool.csv")
    descriptors = df.load_feature_descriptor(meim_folder + "/" + folder + "/morph_features.csv")
    descs = [d +[folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_desc_data = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","width","depth","height","voxels","wheels","sensors","joints","casters","norm","replicate"])
par_desc_data["controller_type"] = "Homeokinesis"
# Out:
# meim_16_3_16-56-39-9868-18373300
# meim_16_3_16-56-42-2870-2796053236
# meim_16_3_16-56-45-5895-1777546940
# meim_16_3_16-56-45-5917-957574002
# meim_16_3_16-56-48-8931-985534567
# meim_16_3_16-56-48-8936-2561894498
# meim_16_3_16-56-51-1885-639115363
# meim_16_3_17-8-55-5548-2215134775
# meim_17_3_11-31-49-9733-2516969209
# meim_17_3_11-37-2-2832-3966900741
# meim_18_3_11-38-15-5621-745283126
# meim_18_3_11-38-18-8916-724015239
# meim_18_3_11-38-21-1936-3632418103
# meim_18_3_11-38-24-4661-1432447149
# meim_18_3_11-38-27-7900-2266432585
# meim_18_3_11-38-30-917-761405749
# meim_18_3_15-22-21-1418-481348034
# meim_18_3_15-22-51-1987-1456279332

# %%
parent_descs = []
for folder in os.listdir(mefc_folder):
    print(folder)
    parent_ids = df.load_parent_pool(mefc_folder + "/" + folder + "/parents_pool.csv")
    descriptors = df.load_feature_descriptor(mefc_folder + "/" + folder + "/morph_features.csv")
    descs = [d +[folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_desc_data2 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","width","depth","height","voxels","wheels","sensors","joints","casters","norm","replicate"])
par_desc_data2["controller_type"] = "Fixed Controller"
# Out:
# meim_22_3_10-26-37-7769-2279963877
# meim_22_3_10-26-40-740-2350202888
# meim_22_3_10-26-45-5733-2586739213
# meim_22_3_10-26-48-8775-3296345534
# meim_22_3_10-26-48-8808-648423813
# meim_22_3_10-26-51-1735-2541492157
# meim_22_3_10-27-0-446-409001623
# meim_22_3_16-46-47-7376-4018957153
# meim_23_3_10-21-12-2712-36198185
# meim_23_3_10-21-15-5656-1313689609
# meim_23_3_10-21-19-9642-703440127
# meim_23_3_10-21-22-2697-202336983
# meim_23_3_10-21-3-3665-3559667224
# meim_23_3_10-21-6-6642-2099145537
# meim_23_3_10-21-9-9708-1821580459
# meim_23_3_13-2-25-5699-3641383181

# %%
desc_data = pd.concat([par_desc_data,par_desc_data2]).reset_index(drop=True)
print(desc_data)
# Out:
#         iteration  robot index  discretized number of robots  \
# 0               0           26                           250
# 1               0           59                           250
# 2               0           22                           250
# 3               0           48                           250
# 4               0           51                           250
# ...           ...          ...                           ...
# 965395        193        10374                         10050
# 965396        193        10583                         10050
# 965397        193        10949                         10050
# 965398        193        11153                         10050
# 965399        193        11237                         10050
#
#         number of individuals  number new inds     width     depth    height  \
# 0                         242              100  0.162182  0.179999  0.419636
# 1                         242              100  0.180001  0.162184  0.145455
# 2                         242              100  0.135273  0.360001  0.347636
# 3                         242              100  0.270546  0.261455  0.145455
# 4                         242              100  0.270546  0.270545  0.145455
# ...                       ...              ...       ...       ...       ...
# 965395                  10036                1  0.270546  0.270546  0.145455
# 965396                  10036                1  0.270545  0.360000  0.167636
# 965397                  10036                1  0.270546  0.360000  0.167636
# 965398                  10036                1  0.270545  0.288000  0.145455
# 965399                  10036                1  0.270546  0.288000  0.203636
#
#           voxels  wheels  sensors  joints  casters      norm  \
# 0       0.571751  0.0625      0.0   0.000   0.0000  0.752065
# 1       0.429752  0.0625      0.0   0.000   0.0000  0.518126
# 2       0.486852  0.2500      0.0   0.125   0.1250  0.774290
# 3       0.018032  0.1875      0.0   0.000   0.1875  0.483062
# 4       0.018032  0.0625      0.0   0.000   0.3125  0.519071
# ...          ...     ...      ...     ...      ...       ...
# 965395  0.018032  0.0000      0.0   0.375   0.1875  0.586220
# 965396  0.253193  0.0000      0.0   0.500   0.2500  0.779425
# 965397  0.253193  0.0000      0.0   0.500   0.2500  0.779425
# 965398  0.253193  0.0000      0.0   0.500   0.1250  0.712059
# 965399  0.253193  0.0000      0.0   0.500   0.2500  0.757769
#
#                                 replicate   controller_type
# 0        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 1        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 2        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 3        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 4        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# ...                                   ...               ...
# 965395  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 965396  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 965397  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 965398  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 965399  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
#
# [965400 rows x 16 columns]

# %%
new_data_list = []
for rep in desc_data["replicate"].drop_duplicates():
    print(rep)
    tmp_data = desc_data.loc[desc_data["replicate"]==rep]
    ctrl_type = tmp_data["controller_type"].drop_duplicates().values[0]
    print(ctrl_type)
    for iter in tmp_data["iteration"].drop_duplicates():
        tmp_data2 = tmp_data.loc[tmp_data["iteration"] == iter]
        new_data = pd.DataFrame(tmp_data2.std(numeric_only=True)).transpose()
        new_data.reset_index()
        new_data["replicate"] = rep
        new_data["iteration"] = iter
        new_data["controller_type"] = ctrl_type
        new_data_list.append(new_data)

std_data = pd.concat(new_data_list)
# Out:
# meim_16_3_16-56-39-9868-18373300
# Homeokinesis
# meim_16_3_16-56-42-2870-2796053236
# Homeokinesis
# meim_16_3_16-56-45-5895-1777546940
# Homeokinesis
# meim_16_3_16-56-45-5917-957574002
# Homeokinesis
# meim_16_3_16-56-48-8931-985534567
# Homeokinesis
# meim_16_3_16-56-48-8936-2561894498
# Homeokinesis
# meim_16_3_16-56-51-1885-639115363
# Homeokinesis
# meim_16_3_17-8-55-5548-2215134775
# Homeokinesis
# meim_17_3_11-31-49-9733-2516969209
# Homeokinesis
# meim_17_3_11-37-2-2832-3966900741
# Homeokinesis
# meim_18_3_11-38-15-5621-745283126
# Homeokinesis
# meim_18_3_11-38-18-8916-724015239
# Homeokinesis
# meim_18_3_11-38-21-1936-3632418103
# Homeokinesis
# meim_18_3_11-38-24-4661-1432447149
# Homeokinesis
# meim_18_3_11-38-27-7900-2266432585
# Homeokinesis
# meim_18_3_11-38-30-917-761405749
# Homeokinesis
# meim_18_3_15-22-21-1418-481348034
# Homeokinesis
# meim_18_3_15-22-51-1987-1456279332
# Homeokinesis
# meim_22_3_10-26-37-7769-2279963877
# Fixed Controller
# meim_22_3_10-26-40-740-2350202888
# Fixed Controller
# meim_22_3_10-26-45-5733-2586739213
# Fixed Controller
# meim_22_3_10-26-48-8775-3296345534
# Fixed Controller
# meim_22_3_10-26-48-8808-648423813
# Fixed Controller
# meim_22_3_10-26-51-1735-2541492157
# Fixed Controller
# meim_22_3_10-27-0-446-409001623
# Fixed Controller
# meim_22_3_16-46-47-7376-4018957153
# Fixed Controller
# meim_23_3_10-21-12-2712-36198185
# Fixed Controller
# meim_23_3_10-21-15-5656-1313689609
# Fixed Controller
# meim_23_3_10-21-19-9642-703440127
# Fixed Controller
# meim_23_3_10-21-22-2697-202336983
# Fixed Controller
# meim_23_3_10-21-3-3665-3559667224
# Fixed Controller
# meim_23_3_10-21-6-6642-2099145537
# Fixed Controller
# meim_23_3_10-21-9-9708-1821580459
# Fixed Controller
# meim_23_3_13-2-25-5699-3641383181
# Fixed Controller

# %%
std_data.index  = [i for i in range(len(std_data))]
print(std_data)
# Out:
#       iteration  robot index  discretized number of robots  \
# 0             0    66.250558                           0.0
# 1             1    72.039054                           0.0
# 2             2    75.375967                           0.0
# 3             3    77.263746                           0.0
# 4             4    78.657197                           0.0
# ...         ...          ...                           ...
# 9649        189  2855.308548                           0.0
# 9650        190  2877.387653                           0.0
# 9651        191  2903.182470                           0.0
# 9652        192  2929.524294                           0.0
# 9653        193  2955.442167                           0.0
#
#       number of individuals  number new inds     width     depth    height  \
# 0                       0.0              0.0  0.126623  0.122700  0.154484
# 1                       0.0              0.0  0.126623  0.122700  0.154484
# 2                       0.0              0.0  0.126623  0.122700  0.154484
# 3                       0.0              0.0  0.126623  0.122700  0.154484
# 4                       0.0              0.0  0.125617  0.121392  0.153958
# ...                     ...              ...       ...       ...       ...
# 9649                    0.0              0.0  0.019351  0.029075  0.080719
# 9650                    0.0              0.0  0.019351  0.029753  0.080823
# 9651                    0.0              0.0  0.019351  0.030399  0.080925
# 9652                    0.0              0.0  0.019351  0.030297  0.079195
# 9653                    0.0              0.0  0.019351  0.030297  0.078961
#
#         voxels    wheels  sensors    joints   casters      norm  \
# 0     0.233501  0.120137      0.0  0.195317  0.124119  0.320203
# 1     0.233501  0.120137      0.0  0.195317  0.124119  0.320203
# 2     0.233501  0.120137      0.0  0.195317  0.124119  0.320203
# 3     0.233501  0.120137      0.0  0.195317  0.124119  0.320203
# 4     0.233597  0.119843      0.0  0.195317  0.124119  0.315915
# ...        ...       ...      ...       ...       ...       ...
# 9649  0.100186  0.021931      0.0  0.057227  0.055604  0.084312
# 9650  0.100186  0.021931      0.0  0.057227  0.055604  0.084423
# 9651  0.100186  0.021931      0.0  0.057227  0.055604  0.084534
# 9652  0.100186  0.021931      0.0  0.057227  0.056183  0.083783
# 9653  0.100186  0.021931      0.0  0.057227  0.055604  0.083839
#
#                               replicate   controller_type
# 0      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 1      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 2      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 3      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 4      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# ...                                 ...               ...
# 9649  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 9650  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 9651  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 9652  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 9653  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
#
# [9654 rows x 16 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=std_data,x="iteration",y="norm",hue="controller_type",estimator=np.median)
sns.lineplot(data=std_data,x="iteration",y="norm",hue="controller_type",linestyle=":",estimator=np.max,ci=None)
sns.lineplot(data=std_data,x="iteration",y="norm",hue="controller_type",linestyle=":",estimator=np.min,ci=None)
ax.set_ylabel("Morphological diversity")
# Out:
# Text(0, 0.5, 'Morphological diversity')

# %%
new_data_list = []
for rep in desc_data["replicate"].drop_duplicates():
    print(rep)
    tmp_data = desc_data.loc[desc_data["replicate"]==rep]
    ctrl_type = tmp_data["controller_type"].drop_duplicates().values[0]
    print(ctrl_type)
    for iter in tmp_data["discretized number of robots"].drop_duplicates():
        tmp_data2 = tmp_data.loc[tmp_data["discretized number of robots"] == iter]
        new_data = pd.DataFrame(tmp_data2.std(numeric_only=True)).transpose()
        new_data.reset_index()
        new_data["replicate"] = rep
        new_data["discretized number of robots"] = iter
        new_data["controller_type"] = ctrl_type
        new_data_list.append(new_data)

std_data = pd.concat(new_data_list)
std_data.index  = [i for i in range(len(std_data))]
print(std_data)
# Out:
# meim_16_3_16-56-39-9868-18373300
# Homeokinesis
# meim_16_3_16-56-42-2870-2796053236
# Homeokinesis
# meim_16_3_16-56-45-5895-1777546940
# Homeokinesis
# meim_16_3_16-56-45-5917-957574002
# Homeokinesis
# meim_16_3_16-56-48-8931-985534567
# Homeokinesis
# meim_16_3_16-56-48-8936-2561894498
# Homeokinesis
# meim_16_3_16-56-51-1885-639115363
# Homeokinesis
# meim_16_3_17-8-55-5548-2215134775
# Homeokinesis
# meim_17_3_11-31-49-9733-2516969209
# Homeokinesis
# meim_17_3_11-37-2-2832-3966900741
# Homeokinesis
# meim_18_3_11-38-15-5621-745283126
# Homeokinesis
# meim_18_3_11-38-18-8916-724015239
# Homeokinesis
# meim_18_3_11-38-21-1936-3632418103
# Homeokinesis
# meim_18_3_11-38-24-4661-1432447149
# Homeokinesis
# meim_18_3_11-38-27-7900-2266432585
# Homeokinesis
# meim_18_3_11-38-30-917-761405749
# Homeokinesis
# meim_18_3_15-22-21-1418-481348034
# Homeokinesis
# meim_18_3_15-22-51-1987-1456279332
# Homeokinesis
# meim_22_3_10-26-37-7769-2279963877
# Fixed Controller
# meim_22_3_10-26-40-740-2350202888
# Fixed Controller
# meim_22_3_10-26-45-5733-2586739213
# Fixed Controller
# meim_22_3_10-26-48-8775-3296345534
# Fixed Controller
# meim_22_3_10-26-48-8808-648423813
# Fixed Controller
# meim_22_3_10-26-51-1735-2541492157
# Fixed Controller
# meim_22_3_10-27-0-446-409001623
# Fixed Controller
# meim_22_3_16-46-47-7376-4018957153
# Fixed Controller
# meim_23_3_10-21-12-2712-36198185
# Fixed Controller
# meim_23_3_10-21-15-5656-1313689609
# Fixed Controller
# meim_23_3_10-21-19-9642-703440127
# Fixed Controller
# meim_23_3_10-21-22-2697-202336983
# Fixed Controller
# meim_23_3_10-21-3-3665-3559667224
# Fixed Controller
# meim_23_3_10-21-6-6642-2099145537
# Fixed Controller
# meim_23_3_10-21-9-9708-1821580459
# Fixed Controller
# meim_23_3_13-2-25-5699-3641383181
# Fixed Controller
#       iteration  robot index  discretized number of robots  \
# 0      0.000000    66.250558                           250
# 1      3.096371    80.737630                           300
# 2      4.715617    95.946298                           350
# 3      2.873719   107.765249                           400
# 4      1.119434   119.317657                           450
# ...         ...          ...                           ...
# 4760   0.000000  2611.255835                          9750
# 4761   0.000000  2635.559146                          9800
# 4762   0.000000  2681.697946                          9900
# 4763   0.000000  2704.374165                         10000
# 4764   2.873719  2837.086790                         10050
#
#       number of individuals  number new inds     width     depth    height  \
# 0                  0.000000         0.000000  0.126623  0.122700  0.154484
# 1                  4.721922         8.821278  0.116383  0.110596  0.142699
# 2                 10.648528         3.202456  0.094642  0.090311  0.122575
# 3                 15.299807         2.538985  0.062598  0.059399  0.100139
# 4                 14.704696         1.480872  0.050112  0.049631  0.089926
# ...                     ...              ...       ...       ...       ...
# 4760               0.000000         0.000000  0.029735  0.029187  0.088796
# 4761               0.000000         0.000000  0.026795  0.028591  0.087473
# 4762               0.000000         0.000000  0.026795  0.029291  0.085362
# 4763               0.000000         0.000000  0.023411  0.029291  0.083686
# 4764               0.000000         0.300150  0.019264  0.029696  0.080985
#
#         voxels    wheels  sensors    joints   casters      norm  \
# 0     0.233501  0.120137      0.0  0.195317  0.124119  0.320203
# 1     0.225857  0.116726      0.0  0.203943  0.119626  0.280742
# 2     0.213057  0.115496      0.0  0.202086  0.120268  0.211086
# 3     0.192191  0.120710      0.0  0.181144  0.108322  0.136573
# 4     0.176917  0.128213      0.0  0.180653  0.105463  0.126214
# ...        ...       ...      ...       ...       ...       ...
# 4760  0.101152  0.021931      0.0  0.056519  0.055704  0.086028
# 4761  0.101932  0.021931      0.0  0.057227  0.055658  0.086335
# 4762  0.101932  0.021931      0.0  0.057227  0.056250  0.085682
# 4763  0.101067  0.021171      0.0  0.057227  0.056310  0.085108
# 4764  0.099103  0.021460      0.0  0.056691  0.055506  0.083682
#
#                               replicate   controller_type
# 0      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 1      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 2      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 3      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 4      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# ...                                 ...               ...
# 4760  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 4761  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 4762  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 4763  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 4764  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
#
# [4765 rows x 16 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=std_data,x="discretized number of robots",y="norm",hue="controller_type",estimator=np.median)
sns.lineplot(data=std_data,x="discretized number of robots",y="norm",hue="controller_type",linestyle=":",estimator=np.max,ci=None)
sns.lineplot(data=std_data,x="discretized number of robots",y="norm",hue="controller_type",linestyle=":",estimator=np.min,ci=None)
ax.set_ylabel("Morphological diversity")
# Out:
# Text(0, 0.5, 'Morphological diversity')

# %% [markdown]
# ### Organ-Matrix Descriptor

# %%
parent_descs = []
for folder in os.listdir(meim_folder):
    print(folder)
    parent_ids = df.load_parent_pool(meim_folder + "/" + folder + "/parents_pool.csv")
    descriptors = df.load_component_descriptor(meim_folder + "/" + folder + "/morph_descriptor.csv")
    
    descs = [[d[0],d[-1],folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_desc_data = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","norm","replicate"])
par_desc_data["controller_type"] = "Homeokinesis"
# Out:
# meim_16_3_16-56-39-9868-18373300
# meim_16_3_16-56-42-2870-2796053236
# meim_16_3_16-56-45-5895-1777546940
# meim_16_3_16-56-45-5917-957574002
# meim_16_3_16-56-48-8931-985534567
# meim_16_3_16-56-48-8936-2561894498
# meim_16_3_16-56-51-1885-639115363
# meim_16_3_17-8-55-5548-2215134775
# meim_17_3_11-31-49-9733-2516969209
# meim_17_3_11-37-2-2832-3966900741
# meim_18_3_11-38-15-5621-745283126
# meim_18_3_11-38-18-8916-724015239
# meim_18_3_11-38-21-1936-3632418103
# meim_18_3_11-38-24-4661-1432447149
# meim_18_3_11-38-27-7900-2266432585
# meim_18_3_11-38-30-917-761405749
# meim_18_3_15-22-21-1418-481348034
# meim_18_3_15-22-51-1987-1456279332

# %%
parent_descs = []
for folder in os.listdir(mefc_folder):
    print(folder)
    parent_ids = df.load_parent_pool(mefc_folder + "/" + folder + "/parents_pool.csv")
    descriptors = df.load_component_descriptor(mefc_folder + "/" + folder + "/morph_descriptor.csv")
    
    descs = [[d[0],d[-1],folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_desc_data2 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","norm","replicate"])
par_desc_data2["controller_type"] = "Fixed Controller"
# Out:
# meim_22_3_10-26-37-7769-2279963877
# meim_22_3_10-26-40-740-2350202888
# meim_22_3_10-26-45-5733-2586739213
# meim_22_3_10-26-48-8775-3296345534
# meim_22_3_10-26-48-8808-648423813
# meim_22_3_10-26-51-1735-2541492157
# meim_22_3_10-27-0-446-409001623
# meim_22_3_16-46-47-7376-4018957153
# meim_23_3_10-21-12-2712-36198185
# meim_23_3_10-21-15-5656-1313689609
# meim_23_3_10-21-19-9642-703440127
# meim_23_3_10-21-22-2697-202336983
# meim_23_3_10-21-3-3665-3559667224
# meim_23_3_10-21-6-6642-2099145537
# meim_23_3_10-21-9-9708-1821580459
# meim_23_3_13-2-25-5699-3641383181

# %%
desc_data = pd.concat([par_desc_data,par_desc_data2]).reset_index(drop=True)
print(desc_data)
# Out:
#         iteration  robot index  discretized number of robots  \
# 0               0           26                           250
# 1               0           59                           250
# 2               0           22                           250
# 3               0           48                           250
# 4               0           51                           250
# ...           ...          ...                           ...
# 965395        193        10374                         10050
# 965396        193        10583                         10050
# 965397        193        10949                         10050
# 965398        193        11153                         10050
# 965399        193        11237                         10050
#
#         number of individuals  number new inds       norm  \
# 0                         242              100   1.000000
# 1                         242              100   1.000000
# 2                         242              100   6.708204
# 3                         242              100   7.141428
# 4                         242              100   9.000000
# ...                       ...              ...        ...
# 965395                  10036                1   8.660254
# 965396                  10036                1  10.000000
# 965397                  10036                1  10.000000
# 965398                  10036                1   8.246211
# 965399                  10036                1  10.000000
#
#                                 replicate   controller_type
# 0        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 1        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 2        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 3        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 4        meim_16_3_16-56-39-9868-18373300      Homeokinesis
# ...                                   ...               ...
# 965395  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 965396  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 965397  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 965398  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 965399  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
#
# [965400 rows x 8 columns]

# %%
new_data_list = []
for rep in desc_data["replicate"].drop_duplicates():
    print(rep)
    tmp_data = desc_data.loc[desc_data["replicate"]==rep]
    ctrl_type = tmp_data["controller_type"].drop_duplicates().values[0]
    print(ctrl_type)
    for iter in tmp_data["iteration"].drop_duplicates():
        tmp_data2 = tmp_data.loc[tmp_data["iteration"] == iter]
        new_data = pd.DataFrame(tmp_data2.std(numeric_only=True)).transpose()
        new_data.reset_index()
        new_data["replicate"] = rep
        new_data["iteration"] = iter
        new_data["controller_type"] = ctrl_type
        new_data_list.append(new_data)

std_data = pd.concat(new_data_list)
# Out:
# meim_16_3_16-56-39-9868-18373300
# Homeokinesis
# meim_16_3_16-56-42-2870-2796053236
# Homeokinesis
# meim_16_3_16-56-45-5895-1777546940
# Homeokinesis
# meim_16_3_16-56-45-5917-957574002
# Homeokinesis
# meim_16_3_16-56-48-8931-985534567
# Homeokinesis
# meim_16_3_16-56-48-8936-2561894498
# Homeokinesis
# meim_16_3_16-56-51-1885-639115363
# Homeokinesis
# meim_16_3_17-8-55-5548-2215134775
# Homeokinesis
# meim_17_3_11-31-49-9733-2516969209
# Homeokinesis
# meim_17_3_11-37-2-2832-3966900741
# Homeokinesis
# meim_18_3_11-38-15-5621-745283126
# Homeokinesis
# meim_18_3_11-38-18-8916-724015239
# Homeokinesis
# meim_18_3_11-38-21-1936-3632418103
# Homeokinesis
# meim_18_3_11-38-24-4661-1432447149
# Homeokinesis
# meim_18_3_11-38-27-7900-2266432585
# Homeokinesis
# meim_18_3_11-38-30-917-761405749
# Homeokinesis
# meim_18_3_15-22-21-1418-481348034
# Homeokinesis
# meim_18_3_15-22-51-1987-1456279332
# Homeokinesis
# meim_22_3_10-26-37-7769-2279963877
# Fixed Controller
# meim_22_3_10-26-40-740-2350202888
# Fixed Controller
# meim_22_3_10-26-45-5733-2586739213
# Fixed Controller
# meim_22_3_10-26-48-8775-3296345534
# Fixed Controller
# meim_22_3_10-26-48-8808-648423813
# Fixed Controller
# meim_22_3_10-26-51-1735-2541492157
# Fixed Controller
# meim_22_3_10-27-0-446-409001623
# Fixed Controller
# meim_22_3_16-46-47-7376-4018957153
# Fixed Controller
# meim_23_3_10-21-12-2712-36198185
# Fixed Controller
# meim_23_3_10-21-15-5656-1313689609
# Fixed Controller
# meim_23_3_10-21-19-9642-703440127
# Fixed Controller
# meim_23_3_10-21-22-2697-202336983
# Fixed Controller
# meim_23_3_10-21-3-3665-3559667224
# Fixed Controller
# meim_23_3_10-21-6-6642-2099145537
# Fixed Controller
# meim_23_3_10-21-9-9708-1821580459
# Fixed Controller
# meim_23_3_13-2-25-5699-3641383181
# Fixed Controller

# %%
std_data.index  = [i for i in range(len(std_data))]
print(std_data)
# Out:
#       iteration  robot index  discretized number of robots  \
# 0             0    66.250558                           0.0
# 1             1    72.039054                           0.0
# 2             2    75.375967                           0.0
# 3             3    77.263746                           0.0
# 4             4    78.657197                           0.0
# ...         ...          ...                           ...
# 9649        189  2855.308548                           0.0
# 9650        190  2877.387653                           0.0
# 9651        191  2903.182470                           0.0
# 9652        192  2929.524294                           0.0
# 9653        193  2955.442167                           0.0
#
#       number of individuals  number new inds      norm  \
# 0                       0.0              0.0  3.613594
# 1                       0.0              0.0  3.613594
# 2                       0.0              0.0  3.613594
# 3                       0.0              0.0  3.613594
# 4                       0.0              0.0  3.602159
# ...                     ...              ...       ...
# 9649                    0.0              0.0  0.856327
# 9650                    0.0              0.0  0.856327
# 9651                    0.0              0.0  0.856327
# 9652                    0.0              0.0  0.861279
# 9653                    0.0              0.0  0.856327
#
#                               replicate   controller_type
# 0      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 1      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 2      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 3      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 4      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# ...                                 ...               ...
# 9649  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 9650  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 9651  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 9652  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 9653  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
#
# [9654 rows x 8 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=std_data,x="iteration",y="norm",hue="controller_type",estimator=np.median)
sns.lineplot(data=std_data,x="iteration",y="norm",hue="controller_type",linestyle=":",estimator=np.max,ci=None)
sns.lineplot(data=std_data,x="iteration",y="norm",hue="controller_type",linestyle=":",estimator=np.min,ci=None)
ax.set_ylabel("Morphological diversity")
# Out:
# Text(0, 0.5, 'Morphological diversity')

# %%
new_data_list = []
for rep in desc_data["replicate"].drop_duplicates():
    print(rep)
    tmp_data = desc_data.loc[desc_data["replicate"]==rep]
    ctrl_type = tmp_data["controller_type"].drop_duplicates().values[0]
    print(ctrl_type)
    for iter in tmp_data["discretized number of robots"].drop_duplicates():
        tmp_data2 = tmp_data.loc[tmp_data["discretized number of robots"] == iter]
        new_data = pd.DataFrame(tmp_data2.std(numeric_only=True)).transpose()
        new_data.reset_index()
        new_data["replicate"] = rep
        new_data["discretized number of robots"] = iter
        new_data["controller_type"] = ctrl_type
        new_data_list.append(new_data)

std_data = pd.concat(new_data_list)
std_data.index  = [i for i in range(len(std_data))]
print(std_data)
# Out:
# meim_16_3_16-56-39-9868-18373300
# Homeokinesis
# meim_16_3_16-56-42-2870-2796053236
# Homeokinesis
# meim_16_3_16-56-45-5895-1777546940
# Homeokinesis
# meim_16_3_16-56-45-5917-957574002
# Homeokinesis
# meim_16_3_16-56-48-8931-985534567
# Homeokinesis
# meim_16_3_16-56-48-8936-2561894498
# Homeokinesis
# meim_16_3_16-56-51-1885-639115363
# Homeokinesis
# meim_16_3_17-8-55-5548-2215134775
# Homeokinesis
# meim_17_3_11-31-49-9733-2516969209
# Homeokinesis
# meim_17_3_11-37-2-2832-3966900741
# Homeokinesis
# meim_18_3_11-38-15-5621-745283126
# Homeokinesis
# meim_18_3_11-38-18-8916-724015239
# Homeokinesis
# meim_18_3_11-38-21-1936-3632418103
# Homeokinesis
# meim_18_3_11-38-24-4661-1432447149
# Homeokinesis
# meim_18_3_11-38-27-7900-2266432585
# Homeokinesis
# meim_18_3_11-38-30-917-761405749
# Homeokinesis
# meim_18_3_15-22-21-1418-481348034
# Homeokinesis
# meim_18_3_15-22-51-1987-1456279332
# Homeokinesis
# meim_22_3_10-26-37-7769-2279963877
# Fixed Controller
# meim_22_3_10-26-40-740-2350202888
# Fixed Controller
# meim_22_3_10-26-45-5733-2586739213
# Fixed Controller
# meim_22_3_10-26-48-8775-3296345534
# Fixed Controller
# meim_22_3_10-26-48-8808-648423813
# Fixed Controller
# meim_22_3_10-26-51-1735-2541492157
# Fixed Controller
# meim_22_3_10-27-0-446-409001623
# Fixed Controller
# meim_22_3_16-46-47-7376-4018957153
# Fixed Controller
# meim_23_3_10-21-12-2712-36198185
# Fixed Controller
# meim_23_3_10-21-15-5656-1313689609
# Fixed Controller
# meim_23_3_10-21-19-9642-703440127
# Fixed Controller
# meim_23_3_10-21-22-2697-202336983
# Fixed Controller
# meim_23_3_10-21-3-3665-3559667224
# Fixed Controller
# meim_23_3_10-21-6-6642-2099145537
# Fixed Controller
# meim_23_3_10-21-9-9708-1821580459
# Fixed Controller
# meim_23_3_13-2-25-5699-3641383181
# Fixed Controller
#       iteration  robot index  discretized number of robots  \
# 0      0.000000    66.250558                           250
# 1      3.096371    80.737630                           300
# 2      4.715617    95.946298                           350
# 3      2.873719   107.765249                           400
# 4      1.119434   119.317657                           450
# ...         ...          ...                           ...
# 4760   0.000000  2611.255835                          9750
# 4761   0.000000  2635.559146                          9800
# 4762   0.000000  2681.697946                          9900
# 4763   0.000000  2704.374165                         10000
# 4764   2.873719  2837.086790                         10050
#
#       number of individuals  number new inds      norm  \
# 0                  0.000000         0.000000  3.613594
# 1                  4.721922         8.821278  3.340187
# 2                 10.648528         3.202456  2.810850
# 3                 15.299807         2.538985  2.062120
# 4                 14.704696         1.480872  2.219855
# ...                     ...              ...       ...
# 4760               0.000000         0.000000  0.862946
# 4761               0.000000         0.000000  0.863830
# 4762               0.000000         0.000000  0.868900
# 4763               0.000000         0.000000  0.871107
# 4764               0.000000         0.300150  0.854232
#
#                               replicate   controller_type
# 0      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 1      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 2      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 3      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# 4      meim_16_3_16-56-39-9868-18373300      Homeokinesis
# ...                                 ...               ...
# 4760  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 4761  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 4762  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 4763  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
# 4764  meim_23_3_13-2-25-5699-3641383181  Fixed Controller
#
# [4765 rows x 8 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=std_data,x="discretized number of robots",y="norm",hue="controller_type",estimator=np.median)
sns.lineplot(data=std_data,x="discretized number of robots",y="norm",hue="controller_type",linestyle=":",estimator=np.max,ci=None)
sns.lineplot(data=std_data,x="discretized number of robots",y="norm",hue="controller_type",linestyle=":",estimator=np.min,ci=None)
ax.set_ylabel("Morphological diversity")
ax.set_xlabel("number of robots")
ax.set_xticks(range(0,10500,500))
# Out:
# [<matplotlib.axis.XTick at 0x70415a711d20>,
#  <matplotlib.axis.XTick at 0x70415a711ed0>,
#  <matplotlib.axis.XTick at 0x70415c449e70>,
#  <matplotlib.axis.XTick at 0x70418276a800>,
#  <matplotlib.axis.XTick at 0x704182793a00>,
#  <matplotlib.axis.XTick at 0x7041827c7460>,
#  <matplotlib.axis.XTick at 0x7041827c5390>,
#  <matplotlib.axis.XTick at 0x70415ccd60b0>,
#  <matplotlib.axis.XTick at 0x70415a710ee0>,
#  <matplotlib.axis.XTick at 0x70415c5bc550>,
#  <matplotlib.axis.XTick at 0x70415c5bfd30>,
#  <matplotlib.axis.XTick at 0x70415a726560>,
#  <matplotlib.axis.XTick at 0x70415a736920>,
#  <matplotlib.axis.XTick at 0x70415a7272e0>,
#  <matplotlib.axis.XTick at 0x70415c5bd360>,
#  <matplotlib.axis.XTick at 0x70415a724760>,
#  <matplotlib.axis.XTick at 0x70415c40ca60>,
#  <matplotlib.axis.XTick at 0x70415d903070>,
#  <matplotlib.axis.XTick at 0x704182793280>,
#  <matplotlib.axis.XTick at 0x70415c5bf490>,
#  <matplotlib.axis.XTick at 0x70415d903f70>]

# %% [markdown]
# ## Pareto Front

# %%
pareto_datas = []
for folder in os.listdir(mefc_folder):
    if(folder.split("_")[0] != "meim"):
        continue
    exp_folder = mefc_folder + "/" + folder
    pareto_set = pd.read_csv(exp_folder + "/pareto_set.csv")
    pareto_set["replicate"] = folder
    pareto_set["controller type"] = "Fixed Controller"
    pareto_datas.append(pareto_set)

pareto_data = pd.concat(pareto_datas)
pareto_data = pareto_data.reset_index(drop=True)
print(pareto_data)
# Out:
#       fitness   sparsity     id                           replicate  \
# 0    0.234375  10.266667    954  meim_22_3_10-26-37-7769-2279963877
# 1    0.296875   8.333333   3407  meim_22_3_10-26-37-7769-2279963877
# 2    0.328125   5.400000   5937  meim_22_3_10-26-37-7769-2279963877
# 3    0.421875   0.000000   6176  meim_22_3_10-26-37-7769-2279963877
# 4    0.265625   9.400000   6616  meim_22_3_10-26-37-7769-2279963877
# ..        ...        ...    ...                                 ...
# 111  0.265625   9.333333   3706   meim_23_3_13-2-25-5699-3641383181
# 112  0.343750   7.933333   4634   meim_23_3_13-2-25-5699-3641383181
# 113  0.296875   9.266667   4854   meim_23_3_13-2-25-5699-3641383181
# 114  0.359375   1.933333  10359   meim_23_3_13-2-25-5699-3641383181
# 115  0.250000  10.133333  10385   meim_23_3_13-2-25-5699-3641383181
#
#       controller type
# 0    Fixed Controller
# 1    Fixed Controller
# 2    Fixed Controller
# 3    Fixed Controller
# 4    Fixed Controller
# ..                ...
# 111  Fixed Controller
# 112  Fixed Controller
# 113  Fixed Controller
# 114  Fixed Controller
# 115  Fixed Controller
#
# [116 rows x 5 columns]

# %%
print(pareto_data.iloc[pareto_data["fitness"].idxmax()])
# Out:
# fitness                                      0.453125
# sparsity                                          0.0
# id                                               5267
# replicate          meim_22_3_10-26-45-5733-2586739213
# controller type                      Fixed Controller
# Name: 22, dtype: object

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.lineplot(data=pareto_data,marker="o",x="sparsity",y="fitness",hue="replicate")
# Out:
# <Axes: xlabel='sparsity', ylabel='fitness'>

# %%
pareto_datas = []
for folder in os.listdir(meim_folder):
    if(folder.split("_")[0] != "meim"):
        continue
    exp_folder = meim_folder + "/" + folder
    pareto_set = pd.read_csv(exp_folder + "/pareto_set.csv")
    pareto_set["replicate"] = folder
    pareto_set["controller type"] = "Homeokinesis"
    pareto_datas.append(pareto_set)

pareto_data2 = pd.concat(pareto_datas)
pareto_data2 = pareto_data2.reset_index(drop=True)
print(pareto_data2)
# Out:
#       fitness  sparsity     id                           replicate  \
# 0    0.656250  4.200000   1737    meim_16_3_16-56-39-9868-18373300
# 1    0.750000  0.866667   3079    meim_16_3_16-56-39-9868-18373300
# 2    0.671875  3.866667   4076    meim_16_3_16-56-39-9868-18373300
# 3    0.703125  1.266667   5289    meim_16_3_16-56-39-9868-18373300
# 4    0.546875  8.400000   5482    meim_16_3_16-56-39-9868-18373300
# ..        ...       ...    ...                                 ...
# 122  0.640625  7.133333   2007  meim_18_3_15-22-51-1987-1456279332
# 123  0.671875  2.800000   5410  meim_18_3_15-22-51-1987-1456279332
# 124  0.656250  3.133333   5544  meim_18_3_15-22-51-1987-1456279332
# 125  0.781250  0.000000   8853  meim_18_3_15-22-51-1987-1456279332
# 126  0.718750  2.266667  10222  meim_18_3_15-22-51-1987-1456279332
#
#     controller type
# 0      Homeokinesis
# 1      Homeokinesis
# 2      Homeokinesis
# 3      Homeokinesis
# 4      Homeokinesis
# ..              ...
# 122    Homeokinesis
# 123    Homeokinesis
# 124    Homeokinesis
# 125    Homeokinesis
# 126    Homeokinesis
#
# [127 rows x 5 columns]

# %%
print(pareto_data2.iloc[pareto_data2["fitness"].idxmax()])
# Out:
# fitness                                        0.875
# sparsity                                    2.266667
# id                                              9007
# replicate          meim_18_3_11-38-15-5621-745283126
# controller type                         Homeokinesis
# Name: 77, dtype: object

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.lineplot(data=pareto_data2,marker="o",x="sparsity",y="fitness",hue="replicate")
# Out:
# <Axes: xlabel='sparsity', ylabel='fitness'>

# %%
pareto_all_data = pd.concat([pareto_data,pareto_data2]).reset_index(drop=True)

# %%
fig = plt.gcf()
fig.set_size_inches(20,20)
ax = sns.scatterplot(data=pareto_all_data,x="sparsity",y="fitness",hue="controller type")
ax.set_ylim([0,1])
ax.set_xticks(np.arange(0,11.5,0.5))
# Out:
# [<matplotlib.axis.XTick at 0x70415a1ed360>,
#  <matplotlib.axis.XTick at 0x70415a1ed330>,
#  <matplotlib.axis.XTick at 0x70415a1ec220>,
#  <matplotlib.axis.XTick at 0x70415a1a60b0>,
#  <matplotlib.axis.XTick at 0x70415a1a69b0>,
#  <matplotlib.axis.XTick at 0x70415a1a7190>,
#  <matplotlib.axis.XTick at 0x70415a1a7970>,
#  <matplotlib.axis.XTick at 0x70415a1a7340>,
#  <matplotlib.axis.XTick at 0x70415a1ed240>,
#  <matplotlib.axis.XTick at 0x70414e5b2bc0>,
#  <matplotlib.axis.XTick at 0x70414e5a88e0>,
#  <matplotlib.axis.XTick at 0x70414e5a8850>,
#  <matplotlib.axis.XTick at 0x70415a1a52a0>,
#  <matplotlib.axis.XTick at 0x70414e5a9180>,
#  <matplotlib.axis.XTick at 0x70414e5a9b40>,
#  <matplotlib.axis.XTick at 0x70414e5aa560>,
#  <matplotlib.axis.XTick at 0x70414e5aaf20>,
#  <matplotlib.axis.XTick at 0x70415a1a4fd0>,
#  <matplotlib.axis.XTick at 0x70414e5a9570>,
#  <matplotlib.axis.XTick at 0x70414e5abbe0>,
#  <matplotlib.axis.XTick at 0x70414e5744c0>,
#  <matplotlib.axis.XTick at 0x70414e574ca0>,
#  <matplotlib.axis.XTick at 0x70414e575480>]

# %% [markdown]
# ## Trajectory

# %%
traj = df.load_trajectory("/media/leni/DATADRIVE1/are-logs/mefc/meim_23_3_10-21-6-6642-2099145537/traj_10533")
traj_data = pd.DataFrame(data=traj,columns=["t","x","y","z"])

# %%
fig = plt.gcf()
fig.set_size_inches(10,10)
ax = sns.lineplot(data=traj_data,x="x",y="y",sort=False)
ax.set_xlim([-1,1])
ax.set_ylim([-1,1])
# Out:
# (-1.0, 1.0)

# %%
traj = df.load_trajectory("/media/leni/DATADRIVE1/are-logs/meim/meim_18_3_11-38-15-5621-745283126/traj_9007")
traj_data = pd.DataFrame(data=traj,columns=["t","x","y","z"])

# %%
fig = plt.gcf()
fig.set_size_inches(10,10)
ax = sns.scatterplot(data=traj_data,x="x",y="y",hue="t")
ax.set_xlim([-1,1])
ax.set_ylim([-1,1])
# Out:
# (-1.0, 1.0)

# %% [markdown]
# # TSNE
# Run "Vector Descriptor" to have par_desc_datax filled with data

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tdesc_data1 = par_desc_data1.drop_duplicates(subset=['robot index', 'replicate'])
tdesc_data1 = par_desc_data1[["width","depth","height","voxels","wheels","sensors","joints","casters"]]
tsne_results1 = tsne.fit_transform(tdesc_data1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 76400 samples in 0.067s...
# [t-SNE] Computed neighbors for 76400 samples in 6.291s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 76400
# [t-SNE] Computed conditional probabilities for sample 2000 / 76400
# [t-SNE] Computed conditional probabilities for sample 3000 / 76400
# [t-SNE] Computed conditional probabilities for sample 4000 / 76400
# [t-SNE] Computed conditional probabilities for sample 5000 / 76400
# [t-SNE] Computed conditional probabilities for sample 6000 / 76400
# [t-SNE] Computed conditional probabilities for sample 7000 / 76400
# [t-SNE] Computed conditional probabilities for sample 8000 / 76400
# [t-SNE] Computed conditional probabilities for sample 9000 / 76400
# [t-SNE] Computed conditional probabilities for sample 10000 / 76400
# [t-SNE] Computed conditional probabilities for sample 11000 / 76400
# [t-SNE] Computed conditional probabilities for sample 12000 / 76400
# [t-SNE] Computed conditional probabilities for sample 13000 / 76400
# [t-SNE] Computed conditional probabilities for sample 14000 / 76400
# [t-SNE] Computed conditional probabilities for sample 15000 / 76400
# [t-SNE] Computed conditional probabilities for sample 16000 / 76400
# [t-SNE] Computed conditional probabilities for sample 17000 / 76400
# [t-SNE] Computed conditional probabilities for sample 18000 / 76400
# [t-SNE] Computed conditional probabilities for sample 19000 / 76400
# [t-SNE] Computed conditional probabilities for sample 20000 / 76400
# [t-SNE] Computed conditional probabilities for sample 21000 / 76400
# [t-SNE] Computed conditional probabilities for sample 22000 / 76400
# [t-SNE] Computed conditional probabilities for sample 23000 / 76400
# [t-SNE] Computed conditional probabilities for sample 24000 / 76400
# [t-SNE] Computed conditional probabilities for sample 25000 / 76400
# [t-SNE] Computed conditional probabilities for sample 26000 / 76400
# [t-SNE] Computed conditional probabilities for sample 27000 / 76400
# [t-SNE] Computed conditional probabilities for sample 28000 / 76400
# [t-SNE] Computed conditional probabilities for sample 29000 / 76400
# [t-SNE] Computed conditional probabilities for sample 30000 / 76400
# [t-SNE] Computed conditional probabilities for sample 31000 / 76400
# [t-SNE] Computed conditional probabilities for sample 32000 / 76400
# [t-SNE] Computed conditional probabilities for sample 33000 / 76400
# [t-SNE] Computed conditional probabilities for sample 34000 / 76400
# [t-SNE] Computed conditional probabilities for sample 35000 / 76400
# [t-SNE] Computed conditional probabilities for sample 36000 / 76400
# [t-SNE] Computed conditional probabilities for sample 37000 / 76400
# [t-SNE] Computed conditional probabilities for sample 38000 / 76400
# [t-SNE] Computed conditional probabilities for sample 39000 / 76400
# [t-SNE] Computed conditional probabilities for sample 40000 / 76400
# [t-SNE] Computed conditional probabilities for sample 41000 / 76400
# [t-SNE] Computed conditional probabilities for sample 42000 / 76400
# [t-SNE] Computed conditional probabilities for sample 43000 / 76400
# [t-SNE] Computed conditional probabilities for sample 44000 / 76400
# [t-SNE] Computed conditional probabilities for sample 45000 / 76400
# [t-SNE] Computed conditional probabilities for sample 46000 / 76400
# [t-SNE] Computed conditional probabilities for sample 47000 / 76400
# [t-SNE] Computed conditional probabilities for sample 48000 / 76400
# [t-SNE] Computed conditional probabilities for sample 49000 / 76400
# [t-SNE] Computed conditional probabilities for sample 50000 / 76400
# [t-SNE] Computed conditional probabilities for sample 51000 / 76400
# [t-SNE] Computed conditional probabilities for sample 52000 / 76400
# [t-SNE] Computed conditional probabilities for sample 53000 / 76400
# [t-SNE] Computed conditional probabilities for sample 54000 / 76400
# [t-SNE] Computed conditional probabilities for sample 55000 / 76400
# [t-SNE] Computed conditional probabilities for sample 56000 / 76400
# [t-SNE] Computed conditional probabilities for sample 57000 / 76400
# [t-SNE] Computed conditional probabilities for sample 58000 / 76400
# [t-SNE] Computed conditional probabilities for sample 59000 / 76400
# [t-SNE] Computed conditional probabilities for sample 60000 / 76400
# [t-SNE] Computed conditional probabilities for sample 61000 / 76400
# [t-SNE] Computed conditional probabilities for sample 62000 / 76400
# [t-SNE] Computed conditional probabilities for sample 63000 / 76400
# [t-SNE] Computed conditional probabilities for sample 64000 / 76400
# [t-SNE] Computed conditional probabilities for sample 65000 / 76400
# [t-SNE] Computed conditional probabilities for sample 66000 / 76400
# [t-SNE] Computed conditional probabilities for sample 67000 / 76400
# [t-SNE] Computed conditional probabilities for sample 68000 / 76400
# [t-SNE] Computed conditional probabilities for sample 69000 / 76400
# [t-SNE] Computed conditional probabilities for sample 70000 / 76400
# [t-SNE] Computed conditional probabilities for sample 71000 / 76400
# [t-SNE] Computed conditional probabilities for sample 72000 / 76400
# [t-SNE] Computed conditional probabilities for sample 73000 / 76400
# [t-SNE] Computed conditional probabilities for sample 74000 / 76400
# [t-SNE] Computed conditional probabilities for sample 75000 / 76400
# [t-SNE] Computed conditional probabilities for sample 76000 / 76400
# [t-SNE] Computed conditional probabilities for sample 76400 / 76400
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.344093
# [t-SNE] KL divergence after 300 iterations: 2.336318

# %%
tdesc_data2 = par_desc_data2.drop_duplicates(subset=['robot index', 'replicate'])
tdesc_data2 = par_desc_data2[["width","depth","height","voxels","wheels","sensors","joints","casters"]]
tsne_results2 = tsne.fit_transform(tdesc_data2)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 88200 samples in 0.070s...
# [t-SNE] Computed neighbors for 88200 samples in 17.272s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 88200
# [t-SNE] Computed conditional probabilities for sample 2000 / 88200
# [t-SNE] Computed conditional probabilities for sample 3000 / 88200
# [t-SNE] Computed conditional probabilities for sample 4000 / 88200
# [t-SNE] Computed conditional probabilities for sample 5000 / 88200
# [t-SNE] Computed conditional probabilities for sample 6000 / 88200
# [t-SNE] Computed conditional probabilities for sample 7000 / 88200
# [t-SNE] Computed conditional probabilities for sample 8000 / 88200
# [t-SNE] Computed conditional probabilities for sample 9000 / 88200
# [t-SNE] Computed conditional probabilities for sample 10000 / 88200
# [t-SNE] Computed conditional probabilities for sample 11000 / 88200
# [t-SNE] Computed conditional probabilities for sample 12000 / 88200
# [t-SNE] Computed conditional probabilities for sample 13000 / 88200
# [t-SNE] Computed conditional probabilities for sample 14000 / 88200
# [t-SNE] Computed conditional probabilities for sample 15000 / 88200
# [t-SNE] Computed conditional probabilities for sample 16000 / 88200
# [t-SNE] Computed conditional probabilities for sample 17000 / 88200
# [t-SNE] Computed conditional probabilities for sample 18000 / 88200
# [t-SNE] Computed conditional probabilities for sample 19000 / 88200
# [t-SNE] Computed conditional probabilities for sample 20000 / 88200
# [t-SNE] Computed conditional probabilities for sample 21000 / 88200
# [t-SNE] Computed conditional probabilities for sample 22000 / 88200
# [t-SNE] Computed conditional probabilities for sample 23000 / 88200
# [t-SNE] Computed conditional probabilities for sample 24000 / 88200
# [t-SNE] Computed conditional probabilities for sample 25000 / 88200
# [t-SNE] Computed conditional probabilities for sample 26000 / 88200
# [t-SNE] Computed conditional probabilities for sample 27000 / 88200
# [t-SNE] Computed conditional probabilities for sample 28000 / 88200
# [t-SNE] Computed conditional probabilities for sample 29000 / 88200
# [t-SNE] Computed conditional probabilities for sample 30000 / 88200
# [t-SNE] Computed conditional probabilities for sample 31000 / 88200
# [t-SNE] Computed conditional probabilities for sample 32000 / 88200
# [t-SNE] Computed conditional probabilities for sample 33000 / 88200
# [t-SNE] Computed conditional probabilities for sample 34000 / 88200
# [t-SNE] Computed conditional probabilities for sample 35000 / 88200
# [t-SNE] Computed conditional probabilities for sample 36000 / 88200
# [t-SNE] Computed conditional probabilities for sample 37000 / 88200
# [t-SNE] Computed conditional probabilities for sample 38000 / 88200
# [t-SNE] Computed conditional probabilities for sample 39000 / 88200
# [t-SNE] Computed conditional probabilities for sample 40000 / 88200
# [t-SNE] Computed conditional probabilities for sample 41000 / 88200
# [t-SNE] Computed conditional probabilities for sample 42000 / 88200
# [t-SNE] Computed conditional probabilities for sample 43000 / 88200
# [t-SNE] Computed conditional probabilities for sample 44000 / 88200
# [t-SNE] Computed conditional probabilities for sample 45000 / 88200
# [t-SNE] Computed conditional probabilities for sample 46000 / 88200
# [t-SNE] Computed conditional probabilities for sample 47000 / 88200
# [t-SNE] Computed conditional probabilities for sample 48000 / 88200
# [t-SNE] Computed conditional probabilities for sample 49000 / 88200
# [t-SNE] Computed conditional probabilities for sample 50000 / 88200
# [t-SNE] Computed conditional probabilities for sample 51000 / 88200
# [t-SNE] Computed conditional probabilities for sample 52000 / 88200
# [t-SNE] Computed conditional probabilities for sample 53000 / 88200
# [t-SNE] Computed conditional probabilities for sample 54000 / 88200
# [t-SNE] Computed conditional probabilities for sample 55000 / 88200
# [t-SNE] Computed conditional probabilities for sample 56000 / 88200
# [t-SNE] Computed conditional probabilities for sample 57000 / 88200
# [t-SNE] Computed conditional probabilities for sample 58000 / 88200
# [t-SNE] Computed conditional probabilities for sample 59000 / 88200
# [t-SNE] Computed conditional probabilities for sample 60000 / 88200
# [t-SNE] Computed conditional probabilities for sample 61000 / 88200
# [t-SNE] Computed conditional probabilities for sample 62000 / 88200
# [t-SNE] Computed conditional probabilities for sample 63000 / 88200
# [t-SNE] Computed conditional probabilities for sample 64000 / 88200
# [t-SNE] Computed conditional probabilities for sample 65000 / 88200
# [t-SNE] Computed conditional probabilities for sample 66000 / 88200
# [t-SNE] Computed conditional probabilities for sample 67000 / 88200
# [t-SNE] Computed conditional probabilities for sample 68000 / 88200
# [t-SNE] Computed conditional probabilities for sample 69000 / 88200
# [t-SNE] Computed conditional probabilities for sample 70000 / 88200
# [t-SNE] Computed conditional probabilities for sample 71000 / 88200
# [t-SNE] Computed conditional probabilities for sample 72000 / 88200
# [t-SNE] Computed conditional probabilities for sample 73000 / 88200
# [t-SNE] Computed conditional probabilities for sample 74000 / 88200
# [t-SNE] Computed conditional probabilities for sample 75000 / 88200
# [t-SNE] Computed conditional probabilities for sample 76000 / 88200
# [t-SNE] Computed conditional probabilities for sample 77000 / 88200
# [t-SNE] Computed conditional probabilities for sample 78000 / 88200
# [t-SNE] Computed conditional probabilities for sample 79000 / 88200
# [t-SNE] Computed conditional probabilities for sample 80000 / 88200
# [t-SNE] Computed conditional probabilities for sample 81000 / 88200
# [t-SNE] Computed conditional probabilities for sample 82000 / 88200
# [t-SNE] Computed conditional probabilities for sample 83000 / 88200
# [t-SNE] Computed conditional probabilities for sample 84000 / 88200
# [t-SNE] Computed conditional probabilities for sample 85000 / 88200
# [t-SNE] Computed conditional probabilities for sample 86000 / 88200
# [t-SNE] Computed conditional probabilities for sample 87000 / 88200
# [t-SNE] Computed conditional probabilities for sample 88000 / 88200
# [t-SNE] Computed conditional probabilities for sample 88200 / 88200
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 37.601620
# [t-SNE] KL divergence after 300 iterations: 0.205557

# %%
tdesc_data3 = par_desc_data3.drop_duplicates(subset=['robot index', 'replicate'])
tdesc_data3 = par_desc_data3[["width","depth","height","voxels","wheels","sensors","joints","casters"]]
tsne_results3 = tsne.fit_transform(tdesc_data3)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 93100 samples in 0.065s...
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# [t-SNE] Computed neighbors for 93100 samples in 11.564s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 93100
# [t-SNE] Computed conditional probabilities for sample 2000 / 93100
# [t-SNE] Computed conditional probabilities for sample 3000 / 93100
# [t-SNE] Computed conditional probabilities for sample 4000 / 93100
# [t-SNE] Computed conditional probabilities for sample 5000 / 93100
# [t-SNE] Computed conditional probabilities for sample 6000 / 93100
# [t-SNE] Computed conditional probabilities for sample 7000 / 93100
# [t-SNE] Computed conditional probabilities for sample 8000 / 93100
# [t-SNE] Computed conditional probabilities for sample 9000 / 93100
# [t-SNE] Computed conditional probabilities for sample 10000 / 93100
# [t-SNE] Computed conditional probabilities for sample 11000 / 93100
# [t-SNE] Computed conditional probabilities for sample 12000 / 93100
# [t-SNE] Computed conditional probabilities for sample 13000 / 93100
# [t-SNE] Computed conditional probabilities for sample 14000 / 93100
# [t-SNE] Computed conditional probabilities for sample 15000 / 93100
# [t-SNE] Computed conditional probabilities for sample 16000 / 93100
# [t-SNE] Computed conditional probabilities for sample 17000 / 93100
# [t-SNE] Computed conditional probabilities for sample 18000 / 93100
# [t-SNE] Computed conditional probabilities for sample 19000 / 93100
# [t-SNE] Computed conditional probabilities for sample 20000 / 93100
# [t-SNE] Computed conditional probabilities for sample 21000 / 93100
# [t-SNE] Computed conditional probabilities for sample 22000 / 93100
# [t-SNE] Computed conditional probabilities for sample 23000 / 93100
# [t-SNE] Computed conditional probabilities for sample 24000 / 93100
# [t-SNE] Computed conditional probabilities for sample 25000 / 93100
# [t-SNE] Computed conditional probabilities for sample 26000 / 93100
# [t-SNE] Computed conditional probabilities for sample 27000 / 93100
# [t-SNE] Computed conditional probabilities for sample 28000 / 93100
# [t-SNE] Computed conditional probabilities for sample 29000 / 93100
# [t-SNE] Computed conditional probabilities for sample 30000 / 93100
# [t-SNE] Computed conditional probabilities for sample 31000 / 93100
# [t-SNE] Computed conditional probabilities for sample 32000 / 93100
# [t-SNE] Computed conditional probabilities for sample 33000 / 93100
# [t-SNE] Computed conditional probabilities for sample 34000 / 93100
# [t-SNE] Computed conditional probabilities for sample 35000 / 93100
# [t-SNE] Computed conditional probabilities for sample 36000 / 93100
# [t-SNE] Computed conditional probabilities for sample 37000 / 93100
# [t-SNE] Computed conditional probabilities for sample 38000 / 93100
# [t-SNE] Computed conditional probabilities for sample 39000 / 93100
# [t-SNE] Computed conditional probabilities for sample 40000 / 93100
# [t-SNE] Computed conditional probabilities for sample 41000 / 93100
# [t-SNE] Computed conditional probabilities for sample 42000 / 93100
# [t-SNE] Computed conditional probabilities for sample 43000 / 93100
# [t-SNE] Computed conditional probabilities for sample 44000 / 93100
# [t-SNE] Computed conditional probabilities for sample 45000 / 93100
# [t-SNE] Computed conditional probabilities for sample 46000 / 93100
# [t-SNE] Computed conditional probabilities for sample 47000 / 93100
# [t-SNE] Computed conditional probabilities for sample 48000 / 93100
# [t-SNE] Computed conditional probabilities for sample 49000 / 93100
# [t-SNE] Computed conditional probabilities for sample 50000 / 93100
# [t-SNE] Computed conditional probabilities for sample 51000 / 93100
# [t-SNE] Computed conditional probabilities for sample 52000 / 93100
# [t-SNE] Computed conditional probabilities for sample 53000 / 93100
# [t-SNE] Computed conditional probabilities for sample 54000 / 93100
# [t-SNE] Computed conditional probabilities for sample 55000 / 93100
# [t-SNE] Computed conditional probabilities for sample 56000 / 93100
# [t-SNE] Computed conditional probabilities for sample 57000 / 93100
# [t-SNE] Computed conditional probabilities for sample 58000 / 93100
# [t-SNE] Computed conditional probabilities for sample 59000 / 93100
# [t-SNE] Computed conditional probabilities for sample 60000 / 93100
# [t-SNE] Computed conditional probabilities for sample 61000 / 93100
# [t-SNE] Computed conditional probabilities for sample 62000 / 93100
# [t-SNE] Computed conditional probabilities for sample 63000 / 93100
# [t-SNE] Computed conditional probabilities for sample 64000 / 93100
# [t-SNE] Computed conditional probabilities for sample 65000 / 93100
# [t-SNE] Computed conditional probabilities for sample 66000 / 93100
# [t-SNE] Computed conditional probabilities for sample 67000 / 93100
# [t-SNE] Computed conditional probabilities for sample 68000 / 93100
# [t-SNE] Computed conditional probabilities for sample 69000 / 93100
# [t-SNE] Computed conditional probabilities for sample 70000 / 93100
# [t-SNE] Computed conditional probabilities for sample 71000 / 93100
# [t-SNE] Computed conditional probabilities for sample 72000 / 93100
# [t-SNE] Computed conditional probabilities for sample 73000 / 93100
# [t-SNE] Computed conditional probabilities for sample 74000 / 93100
# [t-SNE] Computed conditional probabilities for sample 75000 / 93100
# [t-SNE] Computed conditional probabilities for sample 76000 / 93100
# [t-SNE] Computed conditional probabilities for sample 77000 / 93100
# [t-SNE] Computed conditional probabilities for sample 78000 / 93100
# [t-SNE] Computed conditional probabilities for sample 79000 / 93100
# [t-SNE] Computed conditional probabilities for sample 80000 / 93100
# [t-SNE] Computed conditional probabilities for sample 81000 / 93100
# [t-SNE] Computed conditional probabilities for sample 82000 / 93100
# [t-SNE] Computed conditional probabilities for sample 83000 / 93100
# [t-SNE] Computed conditional probabilities for sample 84000 / 93100
# [t-SNE] Computed conditional probabilities for sample 85000 / 93100
# [t-SNE] Computed conditional probabilities for sample 86000 / 93100
# [t-SNE] Computed conditional probabilities for sample 87000 / 93100
# [t-SNE] Computed conditional probabilities for sample 88000 / 93100
# [t-SNE] Computed conditional probabilities for sample 89000 / 93100
# [t-SNE] Computed conditional probabilities for sample 90000 / 93100
# [t-SNE] Computed conditional probabilities for sample 91000 / 93100
# [t-SNE] Computed conditional probabilities for sample 92000 / 93100
# [t-SNE] Computed conditional probabilities for sample 93000 / 93100
# [t-SNE] Computed conditional probabilities for sample 93100 / 93100
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 38.764046
# [t-SNE] KL divergence after 300 iterations: 0.549988

# %%
df_tsne_results1 = pd.DataFrame(tsne_results1)
df_tsne_results1['hyperparameter_set']='HK1'
df_tsne_results2 = pd.DataFrame(tsne_results2)
df_tsne_results2['hyperparameter_set']='HK2'
df_tsne_results3 = pd.DataFrame(tsne_results3)
df_tsne_results3['hyperparameter_set']='HK3'
df_tsne_all = [df_tsne_results1, df_tsne_results2, df_tsne_results3]
df_tsne_all = pd.concat(df_tsne_all)

# %%
df_tsne_all
# Out:
#                0          1 hyperparameter_set
# 0     -12.820260   5.470415                HK1
# 1     -12.720481   5.415352                HK1
# 2     -12.635103   5.265517                HK1
# 3     -14.034122   9.380343                HK1
# 4     -14.367009   9.527159                HK1
# ...          ...        ...                ...
# 93095 -21.456720 -12.156096                HK3
# 93096  -0.052622  -8.008297                HK3
# 93097  -8.959142   0.039151                HK3
# 93098 -21.456720 -12.156096                HK3
# 93099   0.428567   7.231520                HK3
#
# [257700 rows x 3 columns]

# %%
plt.figure(figsize=(16,10))
plt.xlim(-50, 50)
plt.ylim(-50, 50)
sns.scatterplot(
    x=0, y=1,
    hue="hyperparameter_set",
    palette=sns.color_palette("hls", 10),
    data=df_tsne_all,
    legend="full",
    alpha=0.8
)
# Out:
# /tmp/ipykernel_681/3442840014.py:4: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.scatterplot(
# <Axes: xlabel='0', ylabel='1'>
