# %%
import os
import sys
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import me_data_fcts as df
#sys.path.append("../meim/")
#import generate_pareto_set as pareto

# %% [markdown]
# # Homeokinesis hyper-parameters

# %%
#import matplotlib as mp
#mp.__version__
#pd.__version__
sns.__version__
#np.__version__
#import sklearn as sk
#sk.__version__
# Out:
# '0.13.2'

# %%
exp_folder_hk1 = "/media/leni/DATADRIVE1/are-logs/meim/hk1"
exp_folder_hk2 = "/media/leni/DATADRIVE1/are-logs/meim/hk2"
exp_folder_hk3 = "/media/leni/DATADRIVE1/are-logs/meim/hk3"

# %%
parent_fits = []
for folder in os.listdir(exp_folder_hk1):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk1 + "/" + folder + "/parent_pool.csv")
    ids, parents, fitnesses, evals, deltas = df.load_fitness(exp_folder_hk1 + "/" + folder + "/fitness.csv")
    fits = [[i,p[0],p[1],f,folder] for i, p, f in zip(ids,parents,fitnesses)]
    parent_fits += df.filter_to_parent_pool(fits,parent_ids)
par_fit_data = pd.DataFrame(data=parent_fits,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","parent 1","parent 2","fitness","replicate"])
par_fit_data["hyperparameter_set"] = "HK1"
# Out:
# meim_27_5_15-10-2-2349-9368381
# meim_29_5_1-55-5-5292-2884637899
# meim_29_5_5-38-57-7874-1851306331
# meim_29_5_5-49-22-2263-2384223522
# meim_3_6_0-26-10-611-1109137532
# meim_3_6_16-55-58-8947-1045327510
# meim_3_6_19-47-41-1691-827713751
# meim_3_6_23-12-26-6795-148076296
# meim_4_6_3-32-59-9270-1223487217

# %%
parent_fits = []
for folder in os.listdir(exp_folder_hk2):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk2 + "/" + folder + "/parent_pool.csv")
    ids, parents, fitnesses, evals, deltas = df.load_fitness(exp_folder_hk2 + "/" + folder + "/fitness.csv")
    fits = [[i,p[0],p[1],f,folder] for i, p, f in zip(ids,parents,fitnesses)]
    parent_fits += df.filter_to_parent_pool(fits,parent_ids)
par_fit_data2 = pd.DataFrame(data=parent_fits,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","parent 1","parent 2","fitness","replicate"])
par_fit_data2["hyperparameter_set"] = "HK2"
# Out:
# meim_1_6_18-20-1-1387-212458571
# meim_27_5_15-10-18-8327-3481239136
# meim_27_5_15-10-2-2349-9368381
# meim_29_5_10-48-53-3340-1957022478
# meim_29_5_9-29-2-2804-955521464
# meim_2_6_4-33-44-4843-3538744330
# meim_4_6_16-57-52-2568-3868717056
# meim_5_6_11-11-36-6740-4188294914
# meim_5_6_11-6-12-2602-436118892

# %%
parent_fits = []
for folder in os.listdir(exp_folder_hk3):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk3 + "/" + folder + "/parent_pool.csv")
    ids, parents, fitnesses, evals, deltas = df.load_fitness(exp_folder_hk3 + "/" + folder + "/fitness.csv")
    fits = [[i,p[0],p[1],f,folder] for i, p, f in zip(ids,parents,fitnesses)]
    parent_fits += df.filter_to_parent_pool(fits,parent_ids)
par_fit_data3 = pd.DataFrame(data=parent_fits,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","parent 1","parent 2","fitness","replicate"])
par_fit_data3["hyperparameter_set"] = "HK3"
# Out:
# meim_4_6_16-59-49-9078-3493767385
# meim_4_6_16-59-52-2124-2763705642
# meim_5_6_10-50-42-2727-1635008145
# meim_5_6_11-17-16-6981-221913695
# meim_5_6_7-15-41-1686-20808547
# meim_6_6_0-23-4-4901-3236490257
# meim_6_6_1-7-36-6550-3419932571
# meim_6_6_5-13-15-5219-3432938375

# %%
fit_data = pd.concat([par_fit_data,par_fit_data2, par_fit_data3]).reset_index(drop=True)
print(fit_data)
# Out:
#         iteration  robot index  discretized number of robots  \
# 0               0           55                           200
# 1               0           48                           200
# 2               0            4                           200
# 3               0           61                           200
# 4               0           14                           200
# ...           ...          ...                           ...
# 638695        266        10026                         10000
# 638696        266        10117                         10000
# 638697        266        10188                         10000
# 638698        266        10151                         10000
# 638699        266        10153                         10000
#
#         number of individuals  number new inds  parent 1  parent 2   fitness  \
# 0                         192              100        -1        -1  0.046875
# 1                         192              100        -1        -1  0.046875
# 2                         192              100        -1        -1  0.062500
# 3                         192              100        -1        -1  0.046875
# 4                         192              100        -1        -1  0.140625
# ...                       ...              ...       ...       ...       ...
# 638695                  10019                3      7441        -1  0.671875
# 638696                  10019                3      5346        -1  0.718750
# 638697                  10019                3      2610        -1  0.671875
# 638698                  10019                3      2792        -1  0.671875
# 638699                  10019                3      9536        -1  0.718750
#
#                                replicate hyperparameter_set
# 0         meim_27_5_15-10-2-2349-9368381                HK1
# 1         meim_27_5_15-10-2-2349-9368381                HK1
# 2         meim_27_5_15-10-2-2349-9368381                HK1
# 3         meim_27_5_15-10-2-2349-9368381                HK1
# 4         meim_27_5_15-10-2-2349-9368381                HK1
# ...                                  ...                ...
# 638695  meim_6_6_5-13-15-5219-3432938375                HK3
# 638696  meim_6_6_5-13-15-5219-3432938375                HK3
# 638697  meim_6_6_5-13-15-5219-3432938375                HK3
# 638698  meim_6_6_5-13-15-5219-3432938375                HK3
# 638699  meim_6_6_5-13-15-5219-3432938375                HK3
#
# [638700 rows x 10 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=fit_data,x="iteration",y="fitness",hue="hyperparameter_set", estimator=np.median,color='b')
sns.lineplot(data=fit_data,x="iteration",y="fitness",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='b')
sns.lineplot(data=fit_data,x="iteration",y="fitness",hue="hyperparameter_set", linestyle=":",estimator=np.min,ci=None,color='b')
# Out:
# /tmp/ipykernel_2049262/2740145824.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=fit_data,x="iteration",y="fitness",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='b')
# /tmp/ipykernel_2049262/2740145824.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=fit_data,x="iteration",y="fitness",hue="hyperparameter_set", linestyle=":",estimator=np.min,ci=None,color='b')
# <Axes: xlabel='iteration', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=fit_data,x="discretized number of robots",y="fitness",hue="hyperparameter_set",estimator=np.median,color='b')
sns.lineplot(data=fit_data,x="discretized number of robots",y="fitness",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='b')
sns.lineplot(data=fit_data,x="discretized number of robots",y="fitness",hue="hyperparameter_set",linestyle=":",estimator=np.min,ci=None,color='b')
ax.set_xticks(range(0,10500,500))
ax.set_xlabel("number of robots")
# Out:
# /tmp/ipykernel_2049262/945659457.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=fit_data,x="discretized number of robots",y="fitness",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='b')
# /tmp/ipykernel_2049262/945659457.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=fit_data,x="discretized number of robots",y="fitness",hue="hyperparameter_set",linestyle=":",estimator=np.min,ci=None,color='b')
# Text(0.5, 0, 'number of robots')

# %% [markdown]
# # Vector descriptor

# %%
import importlib
importlib.reload(df)
parent_descs = []
for folder in os.listdir(exp_folder_hk1):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk1 + "/" + folder + "/parent_pool.csv")
    ids, parents, fitnesses, evals, deltas = df.load_fitness(exp_folder_hk1 + "/" + folder + "/fitness.csv")
    fits = [[i,p[0],p[1],f,folder] for i, p, f in zip(ids,parents,fitnesses)]
    #print(parent_ids)
    descriptors = df.load_feature_descriptor(exp_folder_hk1 + "/" + folder + "/morph_features.csv")
    #print("main", descriptors)
    descs = [d +[folder] for d in descriptors]
    #print(descs)
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_desc_data1 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","width","depth","height","voxels","wheels","sensors","joints","casters","norm","replicate"])
par_desc_data1["hyperparameter_set"] = "HK1"
# Out:
# meim_27_5_15-10-2-2349-9368381
# meim_29_5_1-55-5-5292-2884637899
# meim_29_5_5-38-57-7874-1851306331
# meim_29_5_5-49-22-2263-2384223522
# meim_3_6_0-26-10-611-1109137532
# meim_3_6_16-55-58-8947-1045327510
# meim_3_6_19-47-41-1691-827713751
# meim_3_6_23-12-26-6795-148076296
# meim_4_6_3-32-59-9270-1223487217

# %%
parent_descs = []
for folder in os.listdir(exp_folder_hk2):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk2 + "/" + folder + "/parent_pool.csv")
    descriptors = df.load_feature_descriptor(exp_folder_hk2 + "/" + folder + "/morph_features.csv")
    descs = [d +[folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_desc_data2 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","width","depth","height","voxels","wheels","sensors","joints","casters","norm","replicate"])
par_desc_data2["hyperparameter_set"] = "HK2"
# Out:
# meim_1_6_18-20-1-1387-212458571
# meim_27_5_15-10-18-8327-3481239136
# meim_27_5_15-10-2-2349-9368381
# meim_29_5_10-48-53-3340-1957022478
# meim_29_5_9-29-2-2804-955521464
# meim_2_6_4-33-44-4843-3538744330
# meim_4_6_16-57-52-2568-3868717056
# meim_5_6_11-11-36-6740-4188294914
# meim_5_6_11-6-12-2602-436118892

# %%
parent_descs = []
for folder in os.listdir(exp_folder_hk3):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk3 + "/" + folder + "/parent_pool.csv")
    descriptors = df.load_feature_descriptor(exp_folder_hk3 + "/" + folder + "/morph_features.csv")
    descs = [d +[folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_desc_data3 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","width","depth","height","voxels","wheels","sensors","joints","casters","norm","replicate"])
par_desc_data3["hyperparameter_set"] = "HK3"
# Out:
# meim_4_6_16-59-49-9078-3493767385
# meim_4_6_16-59-52-2124-2763705642
# meim_5_6_10-50-42-2727-1635008145
# meim_5_6_11-17-16-6981-221913695
# meim_5_6_7-15-41-1686-20808547
# meim_6_6_0-23-4-4901-3236490257
# meim_6_6_1-7-36-6550-3419932571
# meim_6_6_5-13-15-5219-3432938375

# %%
desc_data = pd.concat([par_desc_data1,par_desc_data2,par_desc_data3]).reset_index(drop=True)
print(desc_data)
# Out:
#         iteration  robot index  discretized number of robots  \
# 0               0           55                           200
# 1               0           48                           200
# 2               0            4                           200
# 3               0           61                           200
# 4               0           14                           200
# ...           ...          ...                           ...
# 638695        266        10026                         10000
# 638696        266        10117                         10000
# 638697        266        10188                         10000
# 638698        266        10151                         10000
# 638699        266        10153                         10000
#
#         number of individuals  number new inds     width     depth    height  \
# 0                         192              100  0.171273  0.036000  0.385455
# 1                         192              100  0.180000  0.243273  0.421455
# 2                         192              100  0.360000  0.171273  0.421455
# 3                         192              100  0.171273  0.288000  0.421455
# 4                         192              100  0.171273  0.288000  0.205455
# ...                       ...              ...       ...       ...       ...
# 638695                  10019                3  0.252364  0.261455  0.145455
# 638696                  10019                3  0.261454  0.261455  0.145455
# 638697                  10019                3  0.261455  0.261455  0.145455
# 638698                  10019                3  0.270545  0.261455  0.145455
# 638699                  10019                3  0.252364  0.261455  0.145454
#
#           voxels  wheels  sensors  joints  casters      norm  \
# 0       0.676935  0.0000   0.0000   0.125   0.0000  0.808129
# 1       0.481593  0.0000   0.0000   0.125   0.0625  0.721574
# 2       0.560481  0.0000   0.0000   0.125   0.1250  0.825801
# 3       0.477836  0.0000   0.0000   0.125   0.1250  0.741269
# 4       0.613824  0.0000   0.0000   0.500   0.0000  0.883895
# ...          ...     ...      ...     ...      ...       ...
# 638695  0.018032  0.3125   0.0000   0.125   0.0000  0.516536
# 638696  0.018032  0.2500   0.0000   0.125   0.0625  0.490133
# 638697  0.018032  0.2500   0.0000   0.125   0.0625  0.490134
# 638698  0.018032  0.2500   0.1875   0.000   0.0000  0.510580
# 638699  0.018032  0.3125   0.0000   0.125   0.0000  0.516536
#
#                                replicate hyperparameter_set
# 0         meim_27_5_15-10-2-2349-9368381                HK1
# 1         meim_27_5_15-10-2-2349-9368381                HK1
# 2         meim_27_5_15-10-2-2349-9368381                HK1
# 3         meim_27_5_15-10-2-2349-9368381                HK1
# 4         meim_27_5_15-10-2-2349-9368381                HK1
# ...                                  ...                ...
# 638695  meim_6_6_5-13-15-5219-3432938375                HK3
# 638696  meim_6_6_5-13-15-5219-3432938375                HK3
# 638697  meim_6_6_5-13-15-5219-3432938375                HK3
# 638698  meim_6_6_5-13-15-5219-3432938375                HK3
# 638699  meim_6_6_5-13-15-5219-3432938375                HK3
#
# [638700 rows x 16 columns]

# %%
new_data_list = []
for rep in desc_data["replicate"].drop_duplicates():
    print(rep)
    tmp_data = desc_data.loc[desc_data["replicate"]==rep]
    ctrl_type = tmp_data["hyperparameter_set"].drop_duplicates().values[0]
    print(ctrl_type)
    for iter in tmp_data["iteration"].drop_duplicates():
        tmp_data2 = tmp_data.loc[tmp_data["iteration"] == iter]
        new_data = pd.DataFrame(tmp_data2.std(numeric_only=True)).transpose()
        new_data.reset_index()
        new_data["replicate"] = rep
        new_data["iteration"] = iter
        new_data["hyperparameter_set"] = ctrl_type
        new_data_list.append(new_data)

std_data = pd.concat(new_data_list)
# Out:
# meim_27_5_15-10-2-2349-9368381
# HK1
# meim_29_5_1-55-5-5292-2884637899
# HK1
# meim_29_5_5-38-57-7874-1851306331
# HK1
# meim_29_5_5-49-22-2263-2384223522
# HK1
# meim_3_6_0-26-10-611-1109137532
# HK1
# meim_3_6_16-55-58-8947-1045327510
# HK1
# meim_3_6_19-47-41-1691-827713751
# HK1
# meim_3_6_23-12-26-6795-148076296
# HK1
# meim_4_6_3-32-59-9270-1223487217
# HK1
# meim_1_6_18-20-1-1387-212458571
# HK2
# meim_27_5_15-10-18-8327-3481239136
# HK2
# meim_29_5_10-48-53-3340-1957022478
# HK2
# meim_29_5_9-29-2-2804-955521464
# HK2
# meim_2_6_4-33-44-4843-3538744330
# HK2
# meim_4_6_16-57-52-2568-3868717056
# HK2
# meim_5_6_11-11-36-6740-4188294914
# HK2
# meim_5_6_11-6-12-2602-436118892
# HK2
# meim_4_6_16-59-49-9078-3493767385
# HK3
# meim_4_6_16-59-52-2124-2763705642
# HK3
# meim_5_6_10-50-42-2727-1635008145
# HK3
# meim_5_6_11-17-16-6981-221913695
# HK3
# meim_5_6_7-15-41-1686-20808547
# HK3
# meim_6_6_0-23-4-4901-3236490257
# HK3
# meim_6_6_1-7-36-6550-3419932571
# HK3
# meim_6_6_5-13-15-5219-3432938375
# HK3

# %%
std_data.index  = [i for i in range(len(std_data))]
print(std_data)
# Out:
#       iteration  robot index  discretized number of robots  \
# 0             0    53.253779                           0.0
# 1             1    54.733254                           0.0
# 2             2    59.935492                           0.0
# 3             3    65.145215                           0.0
# 4             4    67.400982                           0.0
# ...         ...          ...                           ...
# 6129        262  2480.731214                           0.0
# 6130        263  2507.074210                           0.0
# 6131        264  2536.291723                           0.0
# 6132        265  2573.910849                           0.0
# 6133        266  2681.063607                           0.0
#
#       number of individuals  number new inds     width     depth  \
# 0                       0.0              0.0  0.068397  0.073700
# 1                       0.0              0.0  0.068209  0.073013
# 2                       0.0              0.0  0.067470  0.070850
# 3                       0.0              0.0  0.063811  0.065909
# 4                       0.0              0.0  0.064479  0.065909
# ...                     ...              ...       ...       ...
# 6129                    0.0              0.0  0.006729  0.002837
# 6130                    0.0              0.0  0.006729  0.002837
# 6131                    0.0              0.0  0.006729  0.002837
# 6132                    0.0              0.0  0.006696  0.002837
# 6133                    0.0              0.0  0.006636  0.002837
#
#             height        voxels    wheels   sensors    joints   casters  \
# 0     1.132629e-01  2.278555e-01  0.125351  0.097116  0.197229  0.105731
# 1     1.135025e-01  2.293372e-01  0.128009  0.097116  0.197229  0.100439
# 2     1.136135e-01  2.305579e-01  0.134530  0.095847  0.198233  0.100767
# 3     1.124790e-01  2.305371e-01  0.145601  0.095855  0.201170  0.099551
# 4     1.116190e-01  2.299665e-01  0.145601  0.095855  0.200204  0.102106
# ...            ...           ...       ...       ...       ...       ...
# 6129  3.265986e-07  3.486925e-18  0.040098  0.073499  0.058441  0.027553
# 6130  3.265986e-07  3.486925e-18  0.040098  0.073499  0.058441  0.027553
# 6131  3.265986e-07  3.486925e-18  0.040098  0.073499  0.058441  0.027553
# 6132  3.265986e-07  3.486925e-18  0.040143  0.073499  0.058441  0.027887
# 6133  3.379977e-07  3.486925e-18  0.040098  0.072982  0.058441  0.027887
#
#           norm                         replicate hyperparameter_set
# 0     0.134438    meim_27_5_15-10-2-2349-9368381                HK1
# 1     0.134864    meim_27_5_15-10-2-2349-9368381                HK1
# 2     0.135724    meim_27_5_15-10-2-2349-9368381                HK1
# 3     0.140301    meim_27_5_15-10-2-2349-9368381                HK1
# 4     0.140252    meim_27_5_15-10-2-2349-9368381                HK1
# ...        ...                               ...                ...
# 6129  0.019123  meim_6_6_5-13-15-5219-3432938375                HK3
# 6130  0.019123  meim_6_6_5-13-15-5219-3432938375                HK3
# 6131  0.019123  meim_6_6_5-13-15-5219-3432938375                HK3
# 6132  0.019261  meim_6_6_5-13-15-5219-3432938375                HK3
# 6133  0.019253  meim_6_6_5-13-15-5219-3432938375                HK3
#
# [6134 rows x 16 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=std_data.loc[std_data["hyperparameter_set"] == "HK1"],x="iteration",y="norm",hue="replicate", estimator=None,color='g')
ax.set_ylabel("Morphological diversity no estimator")
# Out:
# Text(0, 0.5, 'Morphological diversity no estimator')

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=std_data.loc[std_data["hyperparameter_set"] == "HK2"],x="iteration",y="norm",hue="replicate", estimator=None,color='g')
ax.set_ylabel("Morphological diversity no estimator")
# Out:
# Text(0, 0.5, 'Morphological diversity no estimator')

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=std_data.loc[std_data["hyperparameter_set"] == "HK3"],x="iteration",y="norm",hue="replicate", estimator=None,color='g')
ax.set_ylabel("Morphological diversity no estimator")
# Out:
# Text(0, 0.5, 'Morphological diversity no estimator')

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=std_data,x="iteration",y="norm",hue="hyperparameter_set", estimator=np.median,color='g')
sns.lineplot(data=std_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='g')
sns.lineplot(data=std_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.min,ci=None,color='g')
ax.set_ylabel("Morphological diversity")
# Out:
# /tmp/ipykernel_2049262/2416703732.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=std_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='g')
# /tmp/ipykernel_2049262/2416703732.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=std_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.min,ci=None,color='g')
# Text(0, 0.5, 'Morphological diversity')

# %% [markdown]
# # Components distribution

# %%
all_data = pd.merge(desc_data,fit_data,how="left",on=["iteration","robot index","replicate","discretized number of robots","number of individuals","number new inds","hyperparameter_set"])
all_data = all_data.drop_duplicates(subset=['robot index','replicate'])
print(all_data)
# Out:
#         iteration  robot index  discretized number of robots  \
# 0               0           55                           200
# 1               0           48                           200
# 2               0            4                           200
# 3               0           61                           200
# 4               0           14                           200
# ...           ...          ...                           ...
# 638499        264        10026                         10000
# 638599        265        10117                         10000
# 638697        266        10188                         10000
# 638698        266        10151                         10000
# 638699        266        10153                         10000
#
#         number of individuals  number new inds     width     depth    height  \
# 0                         192              100  0.171273  0.036000  0.385455
# 1                         192              100  0.180000  0.243273  0.421455
# 2                         192              100  0.360000  0.171273  0.421455
# 3                         192              100  0.171273  0.288000  0.421455
# 4                         192              100  0.171273  0.288000  0.205455
# ...                       ...              ...       ...       ...       ...
# 638499                  10019                1  0.252364  0.261455  0.145455
# 638599                  10019                1  0.261454  0.261455  0.145455
# 638697                  10019                3  0.261455  0.261455  0.145455
# 638698                  10019                3  0.270545  0.261455  0.145455
# 638699                  10019                3  0.252364  0.261455  0.145454
#
#           voxels  wheels  sensors  joints  casters      norm  \
# 0       0.676935  0.0000   0.0000   0.125   0.0000  0.808129
# 1       0.481593  0.0000   0.0000   0.125   0.0625  0.721574
# 2       0.560481  0.0000   0.0000   0.125   0.1250  0.825801
# 3       0.477836  0.0000   0.0000   0.125   0.1250  0.741269
# 4       0.613824  0.0000   0.0000   0.500   0.0000  0.883895
# ...          ...     ...      ...     ...      ...       ...
# 638499  0.018032  0.3125   0.0000   0.125   0.0000  0.516536
# 638599  0.018032  0.2500   0.0000   0.125   0.0625  0.490133
# 638697  0.018032  0.2500   0.0000   0.125   0.0625  0.490134
# 638698  0.018032  0.2500   0.1875   0.000   0.0000  0.510580
# 638699  0.018032  0.3125   0.0000   0.125   0.0000  0.516536
#
#                                replicate hyperparameter_set  parent 1  \
# 0         meim_27_5_15-10-2-2349-9368381                HK1        -1
# 1         meim_27_5_15-10-2-2349-9368381                HK1        -1
# 2         meim_27_5_15-10-2-2349-9368381                HK1        -1
# 3         meim_27_5_15-10-2-2349-9368381                HK1        -1
# 4         meim_27_5_15-10-2-2349-9368381                HK1        -1
# ...                                  ...                ...       ...
# 638499  meim_6_6_5-13-15-5219-3432938375                HK3      7441
# 638599  meim_6_6_5-13-15-5219-3432938375                HK3      5346
# 638697  meim_6_6_5-13-15-5219-3432938375                HK3      2610
# 638698  meim_6_6_5-13-15-5219-3432938375                HK3      2792
# 638699  meim_6_6_5-13-15-5219-3432938375                HK3      9536
#
#         parent 2   fitness
# 0             -1  0.046875
# 1             -1  0.046875
# 2             -1  0.062500
# 3             -1  0.046875
# 4             -1  0.140625
# ...          ...       ...
# 638499        -1  0.671875
# 638599        -1  0.718750
# 638697        -1  0.671875
# 638698        -1  0.671875
# 638699        -1  0.718750
#
# [20721 rows x 19 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)

sns.countplot(data=all_data,x="sensors",hue="hyperparameter_set",orient="v",alpha=0.5)
ax = plt.twinx()
sns.boxplot(data=all_data,x="sensors",y="fitness",hue="hyperparameter_set",ax=ax,fill=False)
# Out:
# <Axes: xlabel='sensors', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)

sns.countplot(data=all_data,x="wheels",hue="hyperparameter_set",orient="v",alpha=0.5)
ax = plt.twinx()
sns.boxplot(data=all_data,x="wheels",y="fitness",hue="hyperparameter_set",ax=ax,fill=False)
# Out:
# <Axes: xlabel='wheels', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)

sns.countplot(data=all_data,x="joints",hue="hyperparameter_set",orient="v",alpha=0.5)
ax = plt.twinx()
sns.boxplot(data=all_data,x="joints",y="fitness",hue="hyperparameter_set",ax=ax,fill=False)
# Out:
# <Axes: xlabel='joints', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)

sns.countplot(data=all_data,x="casters",hue="hyperparameter_set",orient="v",alpha=0.5)
ax = plt.twinx()
sns.boxplot(data=all_data,x="casters",y="fitness",hue="hyperparameter_set",ax=ax,fill=False)
# Out:
# <Axes: xlabel='casters', ylabel='fitness'>

# %%
new_data_list = []
for rep in all_data["replicate"].drop_duplicates():
    print(rep)
    tmp_data = all_data.loc[desc_data["replicate"]==rep]
    ctrl_type = tmp_data["hyperparameter_set"].drop_duplicates().values[0]
    print(ctrl_type)
    for iter in tmp_data["iteration"].drop_duplicates():
        tmp_data2 = tmp_data.loc[tmp_data["iteration"] == iter]
        new_data = pd.DataFrame(tmp_data2.median(numeric_only=True)).transpose()
        new_data.reset_index()
        new_data["replicate"] = rep
        new_data["iteration"] = iter
        new_data["hyperparameter_set"] = ctrl_type
        new_data_list.append(new_data)

med_data = pd.concat(new_data_list)
# Out:
# meim_27_5_15-10-2-2349-9368381
# HK1
# meim_29_5_1-55-5-5292-2884637899
# HK1
# meim_29_5_5-38-57-7874-1851306331
# HK1
# meim_29_5_5-49-22-2263-2384223522
# HK1
# meim_3_6_0-26-10-611-1109137532
# HK1
# meim_3_6_16-55-58-8947-1045327510
# HK1
# meim_3_6_19-47-41-1691-827713751
# HK1
# meim_3_6_23-12-26-6795-148076296
# HK1
# meim_4_6_3-32-59-9270-1223487217
# HK1
# meim_1_6_18-20-1-1387-212458571
# HK2
# meim_27_5_15-10-18-8327-3481239136
# HK2
# meim_29_5_10-48-53-3340-1957022478
# HK2
# meim_29_5_9-29-2-2804-955521464
# HK2
# meim_2_6_4-33-44-4843-3538744330
# HK2
# meim_4_6_16-57-52-2568-3868717056
# HK2
# meim_5_6_11-11-36-6740-4188294914
# HK2
# meim_5_6_11-6-12-2602-436118892
# HK2
# meim_4_6_16-59-49-9078-3493767385
# HK3
# meim_4_6_16-59-52-2124-2763705642
# HK3
# meim_5_6_10-50-42-2727-1635008145
# HK3
# meim_5_6_11-17-16-6981-221913695
# HK3
# meim_5_6_7-15-41-1686-20808547
# HK3
# meim_6_6_0-23-4-4901-3236490257
# HK3
# meim_6_6_1-7-36-6550-3419932571
# HK3
# meim_6_6_5-13-15-5219-3432938375
# HK3

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)

sns.countplot(data=med_data,x="sensors",hue="hyperparameter_set",orient="v",alpha=0.5)
ax = plt.twinx()
sns.boxplot(data=med_data,x="sensors",y="fitness",hue="hyperparameter_set",ax=ax,fill=False)
# Out:
# <Axes: xlabel='sensors', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)

sns.countplot(data=med_data,x="wheels",hue="hyperparameter_set",orient="v",alpha=0.5)
ax = plt.twinx()
sns.boxplot(data=med_data,x="wheels",y="fitness",hue="hyperparameter_set",ax=ax,fill=False)
# Out:
# <Axes: xlabel='wheels', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)

sns.countplot(data=med_data,x="joints",hue="hyperparameter_set",orient="v",alpha=0.5)
ax = plt.twinx()
sns.boxplot(data=med_data,x="joints",y="fitness",hue="hyperparameter_set",ax=ax,fill=False)
# Out:
# <Axes: xlabel='joints', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.relplot(data=all_data,x="sensors",y="wheels",size="fitness",row="hyperparameter_set",sizes=(10,200))
# Out:
# /home/leni/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.relplot(data=all_data,x="sensors",y="joints",size="fitness",row="hyperparameter_set",sizes=(10,200))
# Out:
# /home/leni/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.relplot(data=all_data,x="wheels",y="joints",size="fitness",row="hyperparameter_set",sizes=(10,200))
# Out:
# /home/leni/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
new_data_list = []
for rep in desc_data["replicate"].drop_duplicates():
    print(rep)
    tmp_data = desc_data.loc[desc_data["replicate"]==rep]
    ctrl_type = tmp_data["hyperparameter_set"].drop_duplicates().values[0]
    print(ctrl_type)
    for iter in tmp_data["discretized number of robots"].drop_duplicates():
        tmp_data2 = tmp_data.loc[tmp_data["discretized number of robots"] == iter]
        new_data = pd.DataFrame(tmp_data2.std(numeric_only=True)).transpose()
        new_data.reset_index()
        new_data["replicate"] = rep
        new_data["discretized number of robots"] = iter
        new_data["hyperparameter_set"] = ctrl_type
        new_data_list.append(new_data)

std_data = pd.concat(new_data_list)
# Out:
# meim_27_5_15-10-2-2349-9368381
# HK1
# meim_29_5_1-55-5-5292-2884637899
# HK1
# meim_29_5_5-38-57-7874-1851306331
# HK1
# meim_29_5_5-49-22-2263-2384223522
# HK1
# meim_3_6_0-26-10-611-1109137532
# HK1
# meim_3_6_16-55-58-8947-1045327510
# HK1
# meim_3_6_19-47-41-1691-827713751
# HK1
# meim_3_6_23-12-26-6795-148076296
# HK1
# meim_4_6_3-32-59-9270-1223487217
# HK1
# meim_1_6_18-20-1-1387-212458571
# HK2
# meim_27_5_15-10-18-8327-3481239136
# HK2
# meim_29_5_10-48-53-3340-1957022478
# HK2
# meim_29_5_9-29-2-2804-955521464
# HK2
# meim_2_6_4-33-44-4843-3538744330
# HK2
# meim_4_6_16-57-52-2568-3868717056
# HK2
# meim_5_6_11-11-36-6740-4188294914
# HK2
# meim_5_6_11-6-12-2602-436118892
# HK2
# meim_4_6_16-59-49-9078-3493767385
# HK3
# meim_4_6_16-59-52-2124-2763705642
# HK3
# meim_5_6_10-50-42-2727-1635008145
# HK3
# meim_5_6_11-17-16-6981-221913695
# HK3
# meim_5_6_7-15-41-1686-20808547
# HK3
# meim_6_6_0-23-4-4901-3236490257
# HK3
# meim_6_6_1-7-36-6550-3419932571
# HK3
# meim_6_6_5-13-15-5219-3432938375
# HK3

# %%
print(std_data)
# Out:
#     iteration  robot index  discretized number of robots  \
# 0    0.000000    53.253779                           200
# 0    0.817178    60.247537                           250
# 0    0.817178    80.203737                           300
# 0    0.817178    92.424168                           350
# 0    0.000000    93.657013                           450
# ..        ...          ...                           ...
# 0    0.000000  2359.998057                          9200
# 0    0.000000  2392.065877                          9500
# 0    0.000000  2409.063113                          9550
# 0    0.000000  2480.731214                          9850
# 0    1.119434  2567.506718                         10000
#
#     number of individuals  number new inds     width     depth        height  \
# 0                0.000000         0.000000  0.068397  0.073700  1.132629e-01
# 0                4.246181         2.056519  0.066420  0.069886  1.134362e-01
# 0                0.471798        15.590760  0.050643  0.052269  9.527808e-02
# 0                0.000000        18.871914  0.018768  0.016289  3.879009e-02
# 0                0.000000         0.000000  0.018791  0.016261  3.885502e-02
# ..                    ...              ...       ...       ...           ...
# 0                0.000000         0.000000  0.006729  0.002837  3.015113e-07
# 0                0.000000         0.000000  0.006667  0.002837  3.144660e-07
# 0                0.000000         0.000000  0.006667  0.002837  3.144660e-07
# 0                0.000000         0.000000  0.006729  0.002837  3.265986e-07
# 0               17.342199         0.867110  0.006673  0.002826  3.282730e-07
#
#           voxels    wheels   sensors    joints   casters      norm  \
# 0   2.278555e-01  0.125351  0.097116  0.197229  0.105731  0.134438
# 0   2.305606e-01  0.136412  0.096148  0.198564  0.100154  0.137098
# 0   2.049782e-01  0.146339  0.085461  0.197464  0.101802  0.131467
# 0   6.183920e-02  0.118196  0.078848  0.171674  0.059648  0.066480
# 0   6.194269e-02  0.116717  0.080572  0.167189  0.058358  0.066025
# ..           ...       ...       ...       ...       ...       ...
# 0   3.486925e-18  0.039147  0.073499  0.058441  0.027553  0.018623
# 0   3.486925e-18  0.039102  0.071895  0.057227  0.027553  0.018624
# 0   3.486925e-18  0.039102  0.071895  0.057227  0.027553  0.018624
# 0   3.486925e-18  0.040098  0.073499  0.058441  0.027553  0.019123
# 0   3.473792e-18  0.039959  0.073095  0.058221  0.027618  0.019118
#
#                            replicate hyperparameter_set
# 0     meim_27_5_15-10-2-2349-9368381                HK1
# 0     meim_27_5_15-10-2-2349-9368381                HK1
# 0     meim_27_5_15-10-2-2349-9368381                HK1
# 0     meim_27_5_15-10-2-2349-9368381                HK1
# 0     meim_27_5_15-10-2-2349-9368381                HK1
# ..                               ...                ...
# 0   meim_6_6_5-13-15-5219-3432938375                HK3
# 0   meim_6_6_5-13-15-5219-3432938375                HK3
# 0   meim_6_6_5-13-15-5219-3432938375                HK3
# 0   meim_6_6_5-13-15-5219-3432938375                HK3
# 0   meim_6_6_5-13-15-5219-3432938375                HK3
#
# [3221 rows x 16 columns]

# %%
# Blox plot
# select single robot index by replicate, box ploxt depth, height, voxels, wheels... etc 
#par_desc_data3[(par_desc_data3['robot index'] == 5) & (par_desc_data3['replicate']=='meim_hk_hyperp_3_12_5_0-19-58-8531-3456489584')].drop_duplicates(subset=['robot index','replicate'])
all_robots_desc = desc_data.drop_duplicates(subset=['robot index','replicate'])

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.violinplot(data=all_robots_desc, x='width', hue='hyperparameter_set',split=True,inner="quarter")
plt.show()
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.violinplot(data=all_robots_desc, x='depth', hue='hyperparameter_set',split=True,inner="quarter")
plt.show()
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.violinplot(data=all_robots_desc, x='height', hue='hyperparameter_set',split=True,inner="quarter")
plt.show()
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.violinplot(data=all_robots_desc, x='voxels', hue='hyperparameter_set',split=True,inner="quarter")
plt.show()
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.violinplot(data=all_robots_desc, x='wheels', hue='hyperparameter_set',split=True,inner="quarter")
plt.show()
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.violinplot(data=all_robots_desc, x='sensors', hue='hyperparameter_set',split=True,inner="quarter")
plt.show()
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.violinplot(data=all_robots_desc, x='joints', hue='hyperparameter_set',split=True,inner="quarter")
plt.show()
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.violinplot(data=all_robots_desc, x='casters', hue='hyperparameter_set',split=True,inner="quarter")
plt.show()

# %% [markdown]
# # Robots selection

# %%
pareto_datas = []
selected_robots = []
for folder in os.listdir(exp_folder_hk1):
    if(folder.split("_")[0] != "meim"):
        continue
    exp_folder = exp_folder_hk1 + "/" + folder
    pareto_set = pd.read_csv(exp_folder + "/pareto_set_L2.csv")
    pareto_set["replicate"] = folder
    pareto_set["hyperparameter_set"] = "HK1"
    f_idx = (np.abs(pareto_set["fitness"] - pareto_set["fitness"].median()).argmin())
    s_idx = (np.abs(pareto_set["sparsity"] - pareto_set["sparsity"].median()).argmin())
    median_idx = 0
    if f_idx != s_idx and pareto_set.iloc[f_idx]["fitness"] > pareto_set.iloc[s_idx]["fitness"]:
            median_idx = f_idx
    else:
        median_idx = s_idx
    selected_robots.append(pd.concat([pareto_set.iloc[[pareto_set['fitness'].idxmax()]],
                                      pareto_set.iloc[[pareto_set['sparsity'].idxmax()]],
                                      pareto_set.iloc[[median_idx]]]))
    pareto_datas.append(pareto_set)

pareto_data_hk1 = pd.concat(pareto_datas)
pareto_data_hk1 = pareto_data_hk1.reset_index(drop=True)
selected_robots_hk1 = pd.concat(selected_robots)
print(selected_robots_hk1)
# Out:
#     fitness  sparsity     id                          replicate  \
# 6  0.828125  0.000000   7307     meim_27_5_15-10-2-2349-9368381
# 0  0.531250  2.800000    345     meim_27_5_15-10-2-2349-9368381
# 5  0.609375  2.200000   6514     meim_27_5_15-10-2-2349-9368381
# 1  0.843750  0.000000   5364   meim_29_5_1-55-5-5292-2884637899
# 0  0.500000  5.466667    451   meim_29_5_1-55-5-5292-2884637899
# 3  0.718750  2.733333   5876   meim_29_5_1-55-5-5292-2884637899
# 2  0.828125  0.000000   1569  meim_29_5_5-38-57-7874-1851306331
# 1  0.609375  2.800000   1196  meim_29_5_5-38-57-7874-1851306331
# 0  0.640625  2.200000    232  meim_29_5_5-38-57-7874-1851306331
# 0  0.843750  0.000000   2576  meim_29_5_5-49-22-2263-2384223522
# 3  0.531250  5.533333   5340  meim_29_5_5-49-22-2263-2384223522
# 1  0.640625  5.266667   3292  meim_29_5_5-49-22-2263-2384223522
# 7  0.812500  0.000000   6391    meim_3_6_0-26-10-611-1109137532
# 3  0.531250  5.133333   3352    meim_3_6_0-26-10-611-1109137532
# 2  0.703125  2.666667   3341    meim_3_6_0-26-10-611-1109137532
# 2  0.828125  0.000000   5492  meim_3_6_16-55-58-8947-1045327510
# 5  0.546875  3.666667   8612  meim_3_6_16-55-58-8947-1045327510
# 1  0.687500  1.066667   2008  meim_3_6_16-55-58-8947-1045327510
# 1  0.812500  0.000000   5747   meim_3_6_19-47-41-1691-827713751
# 7  0.578125  3.200000   9757   meim_3_6_19-47-41-1691-827713751
# 0  0.640625  1.600000   5155   meim_3_6_19-47-41-1691-827713751
# 0  0.828125  0.000000   4845   meim_3_6_23-12-26-6795-148076296
# 3  0.640625  4.666667   9496   meim_3_6_23-12-26-6795-148076296
# 1  0.656250  0.866667   5344   meim_3_6_23-12-26-6795-148076296
# 2  0.812500  0.000000   5053   meim_4_6_3-32-59-9270-1223487217
# 1  0.515625  2.600000    692   meim_4_6_3-32-59-9270-1223487217
# 5  0.687500  1.200000  11192   meim_4_6_3-32-59-9270-1223487217
#
#   hyperparameter_set
# 6                HK1
# 0                HK1
# 5                HK1
# 1                HK1
# 0                HK1
# 3                HK1
# 2                HK1
# 1                HK1
# 0                HK1
# 0                HK1
# 3                HK1
# 1                HK1
# 7                HK1
# 3                HK1
# 2                HK1
# 2                HK1
# 5                HK1
# 1                HK1
# 1                HK1
# 7                HK1
# 0                HK1
# 0                HK1
# 3                HK1
# 1                HK1
# 2                HK1
# 1                HK1
# 5                HK1

# %%
pareto_datas = []
selected_robots = []
for folder in os.listdir(exp_folder_hk2):
    if(folder.split("_")[0] != "meim"):
        continue
    exp_folder = exp_folder_hk2 + "/" + folder
    pareto_set = pd.read_csv(exp_folder + "/pareto_set_L2.csv")
    pareto_set["replicate"] = folder
    pareto_set["hyperparameter_set"] = "HK2"
    f_idx = (np.abs(pareto_set["fitness"] - pareto_set["fitness"].median()).argmin())
    s_idx = (np.abs(pareto_set["sparsity"] - pareto_set["sparsity"].median()).argmin())
    median_idx = 0
    if f_idx != s_idx and pareto_set.iloc[f_idx]["fitness"] > pareto_set.iloc[s_idx]["fitness"]:
            median_idx = f_idx
    else:
        median_idx = s_idx
    selected_robots.append(pd.concat([pareto_set.iloc[[pareto_set['fitness'].idxmax()]],
                                      pareto_set.iloc[[pareto_set['sparsity'].idxmax()]],
                                      pareto_set.iloc[[median_idx]]]))
    pareto_datas.append(pareto_set)

pareto_data_hk2 = pd.concat(pareto_datas)
pareto_data_hk2 = pareto_data_hk2.reset_index(drop=True)
selected_robots_hk2 = pd.concat(selected_robots)
print(selected_robots_hk2)
# Out:
#     fitness  sparsity     id                           replicate  \
# 4  0.859375  0.000000   5611     meim_1_6_18-20-1-1387-212458571
# 1  0.531250  6.533333   3234     meim_1_6_18-20-1-1387-212458571
# 3  0.750000  0.933333   5032     meim_1_6_18-20-1-1387-212458571
# 4  0.843750  0.000000   3302  meim_27_5_15-10-18-8327-3481239136
# 0  0.640625  5.600000   1030  meim_27_5_15-10-18-8327-3481239136
# 2  0.718750  1.600000   1247  meim_27_5_15-10-18-8327-3481239136
# 6  0.828125  0.000000   7307      meim_27_5_15-10-2-2349-9368381
# 0  0.531250  2.800000    345      meim_27_5_15-10-2-2349-9368381
# 5  0.609375  2.200000   6514      meim_27_5_15-10-2-2349-9368381
# 3  0.859375  0.000000   5145  meim_29_5_10-48-53-3340-1957022478
# 4  0.562500  5.533333   5525  meim_29_5_10-48-53-3340-1957022478
# 0  0.703125  4.600000    499  meim_29_5_10-48-53-3340-1957022478
# 5  0.875000  0.000000   9684     meim_29_5_9-29-2-2804-955521464
# 6  0.531250  9.266667   9814     meim_29_5_9-29-2-2804-955521464
# 2  0.765625  6.533333   6304     meim_29_5_9-29-2-2804-955521464
# 4  0.843750  0.000000   4494    meim_2_6_4-33-44-4843-3538744330
# 0  0.531250  6.533333    235    meim_2_6_4-33-44-4843-3538744330
# 7  0.718750  1.533333  10579    meim_2_6_4-33-44-4843-3538744330
# 0  0.828125  0.000000   2647   meim_4_6_16-57-52-2568-3868717056
# 5  0.609375  5.600000  10610   meim_4_6_16-57-52-2568-3868717056
# 4  0.750000  1.866667   9396   meim_4_6_16-57-52-2568-3868717056
# 2  0.859375  0.000000   3144   meim_5_6_11-11-36-6740-4188294914
# 4  0.609375  3.733333   6472   meim_5_6_11-11-36-6740-4188294914
# 1  0.656250  1.600000    984   meim_5_6_11-11-36-6740-4188294914
# 4  0.843750  0.000000   2255     meim_5_6_11-6-12-2602-436118892
# 2  0.578125  5.600000   2200     meim_5_6_11-6-12-2602-436118892
# 3  0.750000  0.466667   2216     meim_5_6_11-6-12-2602-436118892
#
#   hyperparameter_set
# 4                HK2
# 1                HK2
# 3                HK2
# 4                HK2
# 0                HK2
# 2                HK2
# 6                HK2
# 0                HK2
# 5                HK2
# 3                HK2
# 4                HK2
# 0                HK2
# 5                HK2
# 6                HK2
# 2                HK2
# 4                HK2
# 0                HK2
# 7                HK2
# 0                HK2
# 5                HK2
# 4                HK2
# 2                HK2
# 4                HK2
# 1                HK2
# 4                HK2
# 2                HK2
# 3                HK2

# %%
pareto_datas = []
selected_robots = []
for folder in os.listdir(exp_folder_hk3):
    if(folder.split("_")[0] != "meim"):
        continue
    exp_folder = exp_folder_hk3 + "/" + folder
    pareto_set = pd.read_csv(exp_folder + "/pareto_set_L2.csv")
    pareto_set["replicate"] = folder
    pareto_set["hyperparameter_set"] = "HK3"
    f_idx = (np.abs(pareto_set["fitness"] - pareto_set["fitness"].median()).argmin())
    s_idx = (np.abs(pareto_set["sparsity"] - pareto_set["sparsity"].median()).argmin())
    median_idx = 0
    if f_idx != s_idx and pareto_set.iloc[f_idx]["fitness"] > pareto_set.iloc[s_idx]["fitness"]:
            median_idx = f_idx
    else:
        median_idx = s_idx
    selected_robots.append(pd.concat([pareto_set.iloc[[pareto_set['fitness'].idxmax()]],
                                      pareto_set.iloc[[pareto_set['sparsity'].idxmax()]],
                                      pareto_set.iloc[[median_idx]]]))
    pareto_datas.append(pareto_set)

pareto_data_hk3 = pd.concat(pareto_datas)
pareto_data_hk3 = pareto_data_hk3.reset_index(drop=True)
selected_robots_hk3 = pd.concat(selected_robots)
print(selected_robots_hk3)
# Out:
#     fitness  sparsity    id                          replicate  \
# 0  0.750000  0.000000  1549  meim_4_6_16-59-49-9078-3493767385
# 5  0.562500  5.533333  9160  meim_4_6_16-59-49-9078-3493767385
# 1  0.625000  4.066667  1607  meim_4_6_16-59-49-9078-3493767385
# 0  0.781250  0.000000  1742  meim_4_6_16-59-52-2124-2763705642
# 3  0.500000  2.800000  6358  meim_4_6_16-59-52-2124-2763705642
# 4  0.640625  1.733333  8767  meim_4_6_16-59-52-2124-2763705642
# 3  0.718750  0.000000  6187  meim_5_6_10-50-42-2727-1635008145
# 1  0.500000  2.800000  2229  meim_5_6_10-50-42-2727-1635008145
# 4  0.609375  2.266667  9518  meim_5_6_10-50-42-2727-1635008145
# 2  0.765625  0.000000  4283   meim_5_6_11-17-16-6981-221913695
# 1  0.500000  3.666667  1226   meim_5_6_11-17-16-6981-221913695
# 0  0.671875  3.133333   390   meim_5_6_11-17-16-6981-221913695
# 0  0.796875  0.000000  4211     meim_5_6_7-15-41-1686-20808547
# 3  0.593750  4.666667  5319     meim_5_6_7-15-41-1686-20808547
# 2  0.640625  2.800000  5143     meim_5_6_7-15-41-1686-20808547
# 2  0.781250  0.000000  2299    meim_6_6_0-23-4-4901-3236490257
# 1  0.515625  3.466667  1348    meim_6_6_0-23-4-4901-3236490257
# 3  0.640625  1.600000  3146    meim_6_6_0-23-4-4901-3236490257
# 1  0.812500  0.000000  3859    meim_6_6_1-7-36-6550-3419932571
# 4  0.500000  2.800000  9102    meim_6_6_1-7-36-6550-3419932571
# 3  0.609375  1.600000  8052    meim_6_6_1-7-36-6550-3419932571
# 1  0.796875  0.000000  2792   meim_6_6_5-13-15-5219-3432938375
# 0  0.500000  4.666667   993   meim_6_6_5-13-15-5219-3432938375
# 2  0.703125  1.466667  6377   meim_6_6_5-13-15-5219-3432938375
#
#   hyperparameter_set
# 0                HK3
# 5                HK3
# 1                HK3
# 0                HK3
# 3                HK3
# 4                HK3
# 3                HK3
# 1                HK3
# 4                HK3
# 2                HK3
# 1                HK3
# 0                HK3
# 0                HK3
# 3                HK3
# 2                HK3
# 2                HK3
# 1                HK3
# 3                HK3
# 1                HK3
# 4                HK3
# 3                HK3
# 1                HK3
# 0                HK3
# 2                HK3

# %%
pareto_data = pd.concat([pareto_data_hk1,pareto_data_hk2,pareto_data_hk3])
selected_robots = pd.concat([selected_robots_hk1,selected_robots_hk2,selected_robots_hk3])
print(selected_robots)
# Out:
#      fitness  sparsity    id                         replicate  \
# 6   0.828125  0.000000  7307    meim_27_5_15-10-2-2349-9368381
# 0   0.531250  2.800000   345    meim_27_5_15-10-2-2349-9368381
# 5   0.609375  2.200000  6514    meim_27_5_15-10-2-2349-9368381
# 1   0.843750  0.000000  5364  meim_29_5_1-55-5-5292-2884637899
# 0   0.500000  5.466667   451  meim_29_5_1-55-5-5292-2884637899
# ..       ...       ...   ...                               ...
# 4   0.500000  2.800000  9102   meim_6_6_1-7-36-6550-3419932571
# 3   0.609375  1.600000  8052   meim_6_6_1-7-36-6550-3419932571
# 1   0.796875  0.000000  2792  meim_6_6_5-13-15-5219-3432938375
# 0   0.500000  4.666667   993  meim_6_6_5-13-15-5219-3432938375
# 2   0.703125  1.466667  6377  meim_6_6_5-13-15-5219-3432938375
#
#    hyperparameter_set
# 6                 HK1
# 0                 HK1
# 5                 HK1
# 1                 HK1
# 0                 HK1
# ..                ...
# 4                 HK3
# 3                 HK3
# 1                 HK3
# 0                 HK3
# 2                 HK3
#
# [78 rows x 5 columns]

# %%
pareto_all_data = pd.merge(all_data,pareto_data,how="inner",left_on=["robot index","hyperparameter_set","fitness"],right_on=["id","hyperparameter_set","fitness"])
selected_robots_data = pd.merge(all_data,selected_robots,how="inner",left_on=["robot index","hyperparameter_set","fitness"],right_on=["id","hyperparameter_set","fitness"])

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)

sns.countplot(data=pareto_all_data,x="sensors",hue="hyperparameter_set",orient="v",alpha=0.5)
ax = plt.twinx()
sns.boxplot(data=pareto_all_data,x="sensors",y="fitness",hue="hyperparameter_set",ax=ax,fill=False)
# Out:
# <Axes: xlabel='sensors', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)

sns.countplot(data=selected_robots_data,x="sensors",hue="hyperparameter_set",orient="v",alpha=0.5)
ax = plt.twinx()
sns.boxplot(data=selected_robots_data,x="sensors",y="fitness",hue="hyperparameter_set",ax=ax,fill=False)
# Out:
# <Axes: xlabel='sensors', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)

sns.countplot(data=pareto_all_data,x="wheels",hue="hyperparameter_set",orient="v",alpha=0.5)
ax = plt.twinx()
sns.boxplot(data=pareto_all_data,x="wheels",y="fitness",hue="hyperparameter_set",ax=ax,fill=False)
# Out:
# <Axes: xlabel='wheels', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)

sns.countplot(data=selected_robots_data,x="wheels",hue="hyperparameter_set",orient="v",alpha=0.5)
ax = plt.twinx()
sns.boxplot(data=selected_robots_data,x="wheels",y="fitness",hue="hyperparameter_set",ax=ax,fill=False)
# Out:
# <Axes: xlabel='wheels', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)

sns.countplot(data=pareto_all_data,x="joints",hue="hyperparameter_set",orient="v",alpha=0.5)
ax = plt.twinx()
sns.boxplot(data=pareto_all_data,x="joints",y="fitness",hue="hyperparameter_set",ax=ax,fill=False)
# Out:
# <Axes: xlabel='joints', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)

sns.countplot(data=selected_robots_data,x="joints",hue="hyperparameter_set",orient="v",alpha=0.5)
ax = plt.twinx()
sns.boxplot(data=selected_robots_data,x="joints",y="fitness",hue="hyperparameter_set",ax=ax,fill=False)
# Out:
# <Axes: xlabel='joints', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.scatterplot(data=pareto_data,marker="o",x="sparsity",y="fitness",hue="hyperparameter_set")
# Out:
# <Axes: xlabel='sparsity', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
sns.scatterplot(data=selected_robots,marker="o",x="sparsity",y="fitness",hue="hyperparameter_set")
# Out:
# <Axes: xlabel='sparsity', ylabel='fitness'>

# %% [markdown]
# # Matrix descriptor

# %%
parent_descs = []
for folder in os.listdir(exp_folder_hk1):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk1 + "/" + folder + "/parent_pool.csv")
    descriptors = df.load_component_descriptor(exp_folder_hk1 + "/" + folder + "/morph_descriptor.csv")
    
    descs = [[d[0],d[-1],folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_mdesc_data1 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","norm","replicate"])
par_mdesc_data1["hyperparameter_set"] = "HK1"
# Out:
# meim_27_5_15-10-2-2349-9368381
# meim_29_5_1-55-5-5292-2884637899
# meim_29_5_5-38-57-7874-1851306331
# meim_29_5_5-49-22-2263-2384223522
# meim_3_6_0-26-10-611-1109137532
# meim_3_6_16-55-58-8947-1045327510
# meim_3_6_19-47-41-1691-827713751
# meim_3_6_23-12-26-6795-148076296
# meim_4_6_3-32-59-9270-1223487217

# %%
parent_descs = []
for folder in os.listdir(exp_folder_hk2):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk2 + "/" + folder + "/parent_pool.csv")
    descriptors = df.load_component_descriptor(exp_folder_hk2 + "/" + folder + "/morph_descriptor.csv")
    
    descs = [[d[0],d[-1],folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_mdesc_data2 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","norm","replicate"])
par_mdesc_data2["hyperparameter_set"] = "HK2"
# Out:
# meim_1_6_18-20-1-1387-212458571
# meim_27_5_15-10-18-8327-3481239136
# meim_27_5_15-10-2-2349-9368381
# meim_29_5_10-48-53-3340-1957022478
# meim_29_5_9-29-2-2804-955521464
# meim_2_6_4-33-44-4843-3538744330
# meim_4_6_16-57-52-2568-3868717056
# meim_5_6_11-11-36-6740-4188294914
# meim_5_6_11-6-12-2602-436118892

# %%
parent_descs = []
for folder in os.listdir(exp_folder_hk3):
    print(folder)
    parent_ids = df.load_parent_pool(exp_folder_hk3 + "/" + folder + "/parent_pool.csv")
    descriptors = df.load_component_descriptor(exp_folder_hk3 + "/" + folder + "/morph_descriptor.csv")
    
    descs = [[d[0],d[-1],folder] for d in descriptors]
    parent_descs += df.filter_to_parent_pool(descs,parent_ids)

par_mdesc_data3 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","norm","replicate"])
par_mdesc_data3["hyperparameter_set"] = "HK3"
# Out:
# meim_4_6_16-59-49-9078-3493767385
# meim_4_6_16-59-52-2124-2763705642
# meim_5_6_10-50-42-2727-1635008145
# meim_5_6_11-17-16-6981-221913695
# meim_5_6_7-15-41-1686-20808547
# meim_6_6_0-23-4-4901-3236490257
# meim_6_6_1-7-36-6550-3419932571
# meim_6_6_5-13-15-5219-3432938375

# %%
mdesc_data = pd.concat([par_mdesc_data1,par_mdesc_data2,par_mdesc_data3]).reset_index(drop=True)
print(mdesc_data)
# Out:
#         iteration  robot index  discretized number of robots  \
# 0               0           55                           200
# 1               0           48                           200
# 2               0            4                           200
# 3               0           61                           200
# 4               0           14                           200
# ...           ...          ...                           ...
# 638695        266        10026                         10000
# 638696        266        10117                         10000
# 638697        266        10188                         10000
# 638698        266        10151                         10000
# 638699        266        10153                         10000
#
#         number of individuals  number new inds      norm  \
# 0                         192              100  3.000000
# 1                         192              100  5.000000
# 2                         192              100  6.403124
# 3                         192              100  6.403124
# 4                         192              100  6.000000
# ...                       ...              ...       ...
# 638695                  10019                3  3.741657
# 638696                  10019                3  5.385165
# 638697                  10019                3  5.385165
# 638698                  10019                3  4.000000
# 638699                  10019                3  3.741657
#
#                                replicate hyperparameter_set
# 0         meim_27_5_15-10-2-2349-9368381                HK1
# 1         meim_27_5_15-10-2-2349-9368381                HK1
# 2         meim_27_5_15-10-2-2349-9368381                HK1
# 3         meim_27_5_15-10-2-2349-9368381                HK1
# 4         meim_27_5_15-10-2-2349-9368381                HK1
# ...                                  ...                ...
# 638695  meim_6_6_5-13-15-5219-3432938375                HK3
# 638696  meim_6_6_5-13-15-5219-3432938375                HK3
# 638697  meim_6_6_5-13-15-5219-3432938375                HK3
# 638698  meim_6_6_5-13-15-5219-3432938375                HK3
# 638699  meim_6_6_5-13-15-5219-3432938375                HK3
#
# [638700 rows x 8 columns]

# %%
new_data_list = []
for rep in mdesc_data["replicate"].drop_duplicates():
    print(rep)
    tmp_data = mdesc_data.loc[desc_data["replicate"]==rep]
    ctrl_type = tmp_data["hyperparameter_set"].drop_duplicates().values[0]
    print(ctrl_type)
    for iter in tmp_data["iteration"].drop_duplicates():
        tmp_data2 = tmp_data.loc[tmp_data["iteration"] == iter]
        new_data = pd.DataFrame(tmp_data2.std(numeric_only=True)).transpose()
        new_data.reset_index()
        new_data["replicate"] = rep
        new_data["iteration"] = iter
        new_data["hyperparameter_set"] = ctrl_type
        new_data_list.append(new_data)

mstd_data = pd.concat(new_data_list)
# Out:
# meim_27_5_15-10-2-2349-9368381
# HK1
# meim_29_5_1-55-5-5292-2884637899
# HK1
# meim_29_5_5-38-57-7874-1851306331
# HK1
# meim_29_5_5-49-22-2263-2384223522
# HK1
# meim_3_6_0-26-10-611-1109137532
# HK1
# meim_3_6_16-55-58-8947-1045327510
# HK1
# meim_3_6_19-47-41-1691-827713751
# HK1
# meim_3_6_23-12-26-6795-148076296
# HK1
# meim_4_6_3-32-59-9270-1223487217
# HK1
# meim_1_6_18-20-1-1387-212458571
# HK2
# meim_27_5_15-10-18-8327-3481239136
# HK2
# meim_29_5_10-48-53-3340-1957022478
# HK2
# meim_29_5_9-29-2-2804-955521464
# HK2
# meim_2_6_4-33-44-4843-3538744330
# HK2
# meim_4_6_16-57-52-2568-3868717056
# HK2
# meim_5_6_11-11-36-6740-4188294914
# HK2
# meim_5_6_11-6-12-2602-436118892
# HK2
# meim_4_6_16-59-49-9078-3493767385
# HK3
# meim_4_6_16-59-52-2124-2763705642
# HK3
# meim_5_6_10-50-42-2727-1635008145
# HK3
# meim_5_6_11-17-16-6981-221913695
# HK3
# meim_5_6_7-15-41-1686-20808547
# HK3
# meim_6_6_0-23-4-4901-3236490257
# HK3
# meim_6_6_1-7-36-6550-3419932571
# HK3
# meim_6_6_5-13-15-5219-3432938375
# HK3

# %%
mstd_data.index  = [i for i in range(len(mstd_data))]
print(mstd_data)
# Out:
#       iteration  robot index  discretized number of robots  \
# 0             0    53.253779                           0.0
# 1             1    54.733254                           0.0
# 2             2    59.935492                           0.0
# 3             3    65.145215                           0.0
# 4             4    67.400982                           0.0
# ...         ...          ...                           ...
# 6129        262  2480.731214                           0.0
# 6130        263  2507.074210                           0.0
# 6131        264  2536.291723                           0.0
# 6132        265  2573.910849                           0.0
# 6133        266  2681.063607                           0.0
#
#       number of individuals  number new inds      norm  \
# 0                       0.0              0.0  2.317152
# 1                       0.0              0.0  2.313897
# 2                       0.0              0.0  2.393702
# 3                       0.0              0.0  2.503182
# 4                       0.0              0.0  2.518826
# ...                     ...              ...       ...
# 6129                    0.0              0.0  0.715255
# 6130                    0.0              0.0  0.715255
# 6131                    0.0              0.0  0.715255
# 6132                    0.0              0.0  0.720371
# 6133                    0.0              0.0  0.722538
#
#                              replicate hyperparameter_set
# 0       meim_27_5_15-10-2-2349-9368381                HK1
# 1       meim_27_5_15-10-2-2349-9368381                HK1
# 2       meim_27_5_15-10-2-2349-9368381                HK1
# 3       meim_27_5_15-10-2-2349-9368381                HK1
# 4       meim_27_5_15-10-2-2349-9368381                HK1
# ...                                ...                ...
# 6129  meim_6_6_5-13-15-5219-3432938375                HK3
# 6130  meim_6_6_5-13-15-5219-3432938375                HK3
# 6131  meim_6_6_5-13-15-5219-3432938375                HK3
# 6132  meim_6_6_5-13-15-5219-3432938375                HK3
# 6133  meim_6_6_5-13-15-5219-3432938375                HK3
#
# [6134 rows x 8 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=mstd_data,x="iteration",y="norm",hue="hyperparameter_set", estimator=np.median,color='g')
sns.lineplot(data=mstd_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='g')
sns.lineplot(data=mstd_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.min,ci=None,color='g')
ax.set_ylabel("Morphological matrix descriptor diversity")
# Out:
# /tmp/ipykernel_2049262/1731107229.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=mstd_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.max,ci=None,color='g')
# /tmp/ipykernel_2049262/1731107229.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=mstd_data,x="iteration",y="norm",hue="hyperparameter_set",linestyle=":",estimator=np.min,ci=None,color='g')
# Text(0, 0.5, 'Morphological matrix descriptor diversity')

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=mstd_data.loc[mstd_data["hyperparameter_set"] == "HK1"],x="iteration",y="norm",hue="replicate", estimator=np.median,color='g')
ax.set_ylabel("Morphological matrix descriptor diversity")
# Out:
# Text(0, 0.5, 'Morphological matrix descriptor diversity')

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=mstd_data.loc[mstd_data["hyperparameter_set"] == "HK2"],x="iteration",y="norm",hue="replicate", estimator=np.median,color='g')
ax.set_ylabel("Morphological matrix descriptor diversity")
# Out:
# Text(0, 0.5, 'Morphological matrix descriptor diversity')

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=mstd_data.loc[mstd_data["hyperparameter_set"] == "HK3"],x="iteration",y="norm",hue="replicate", estimator=np.median,color='g')
ax.set_ylabel("Morphological matrix descriptor diversity")
# Out:
# Text(0, 0.5, 'Morphological matrix descriptor diversity')

# %% [markdown]
# # TSNE
# Run "Vector Descriptor" to have par_desc_datax filled with data

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tdesc_data1 = par_desc_data1.drop_duplicates(subset=['robot index', 'replicate'])
tdesc_data1 = par_desc_data1[["width","depth","height","voxels","wheels","sensors","joints","casters"]]
tsne_results1 = tsne.fit_transform(tdesc_data1)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 227100 samples in 0.222s...
# [t-SNE] Computed neighbors for 227100 samples in 54.245s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 227100
# [t-SNE] Computed conditional probabilities for sample 2000 / 227100
# [t-SNE] Computed conditional probabilities for sample 3000 / 227100
# [t-SNE] Computed conditional probabilities for sample 4000 / 227100
# [t-SNE] Computed conditional probabilities for sample 5000 / 227100
# [t-SNE] Computed conditional probabilities for sample 6000 / 227100
# [t-SNE] Computed conditional probabilities for sample 7000 / 227100
# [t-SNE] Computed conditional probabilities for sample 8000 / 227100
# [t-SNE] Computed conditional probabilities for sample 9000 / 227100
# [t-SNE] Computed conditional probabilities for sample 10000 / 227100
# [t-SNE] Computed conditional probabilities for sample 11000 / 227100
# [t-SNE] Computed conditional probabilities for sample 12000 / 227100
# [t-SNE] Computed conditional probabilities for sample 13000 / 227100
# [t-SNE] Computed conditional probabilities for sample 14000 / 227100
# [t-SNE] Computed conditional probabilities for sample 15000 / 227100
# [t-SNE] Computed conditional probabilities for sample 16000 / 227100
# [t-SNE] Computed conditional probabilities for sample 17000 / 227100
# [t-SNE] Computed conditional probabilities for sample 18000 / 227100
# [t-SNE] Computed conditional probabilities for sample 19000 / 227100
# [t-SNE] Computed conditional probabilities for sample 20000 / 227100
# [t-SNE] Computed conditional probabilities for sample 21000 / 227100
# [t-SNE] Computed conditional probabilities for sample 22000 / 227100
# [t-SNE] Computed conditional probabilities for sample 23000 / 227100
# [t-SNE] Computed conditional probabilities for sample 24000 / 227100
# [t-SNE] Computed conditional probabilities for sample 25000 / 227100
# [t-SNE] Computed conditional probabilities for sample 26000 / 227100
# [t-SNE] Computed conditional probabilities for sample 27000 / 227100
# [t-SNE] Computed conditional probabilities for sample 28000 / 227100
# [t-SNE] Computed conditional probabilities for sample 29000 / 227100
# [t-SNE] Computed conditional probabilities for sample 30000 / 227100
# [t-SNE] Computed conditional probabilities for sample 31000 / 227100
# [t-SNE] Computed conditional probabilities for sample 32000 / 227100
# [t-SNE] Computed conditional probabilities for sample 33000 / 227100
# [t-SNE] Computed conditional probabilities for sample 34000 / 227100
# [t-SNE] Computed conditional probabilities for sample 35000 / 227100
# [t-SNE] Computed conditional probabilities for sample 36000 / 227100
# [t-SNE] Computed conditional probabilities for sample 37000 / 227100
# [t-SNE] Computed conditional probabilities for sample 38000 / 227100
# [t-SNE] Computed conditional probabilities for sample 39000 / 227100
# [t-SNE] Computed conditional probabilities for sample 40000 / 227100
# [t-SNE] Computed conditional probabilities for sample 41000 / 227100
# [t-SNE] Computed conditional probabilities for sample 42000 / 227100
# [t-SNE] Computed conditional probabilities for sample 43000 / 227100
# [t-SNE] Computed conditional probabilities for sample 44000 / 227100
# [t-SNE] Computed conditional probabilities for sample 45000 / 227100
# [t-SNE] Computed conditional probabilities for sample 46000 / 227100
# [t-SNE] Computed conditional probabilities for sample 47000 / 227100
# [t-SNE] Computed conditional probabilities for sample 48000 / 227100
# [t-SNE] Computed conditional probabilities for sample 49000 / 227100
# [t-SNE] Computed conditional probabilities for sample 50000 / 227100
# [t-SNE] Computed conditional probabilities for sample 51000 / 227100
# [t-SNE] Computed conditional probabilities for sample 52000 / 227100
# [t-SNE] Computed conditional probabilities for sample 53000 / 227100
# [t-SNE] Computed conditional probabilities for sample 54000 / 227100
# [t-SNE] Computed conditional probabilities for sample 55000 / 227100
# [t-SNE] Computed conditional probabilities for sample 56000 / 227100
# [t-SNE] Computed conditional probabilities for sample 57000 / 227100
# [t-SNE] Computed conditional probabilities for sample 58000 / 227100
# [t-SNE] Computed conditional probabilities for sample 59000 / 227100
# [t-SNE] Computed conditional probabilities for sample 60000 / 227100
# [t-SNE] Computed conditional probabilities for sample 61000 / 227100
# [t-SNE] Computed conditional probabilities for sample 62000 / 227100
# [t-SNE] Computed conditional probabilities for sample 63000 / 227100
# [t-SNE] Computed conditional probabilities for sample 64000 / 227100
# [t-SNE] Computed conditional probabilities for sample 65000 / 227100
# [t-SNE] Computed conditional probabilities for sample 66000 / 227100
# [t-SNE] Computed conditional probabilities for sample 67000 / 227100
# [t-SNE] Computed conditional probabilities for sample 68000 / 227100
# [t-SNE] Computed conditional probabilities for sample 69000 / 227100
# [t-SNE] Computed conditional probabilities for sample 70000 / 227100
# [t-SNE] Computed conditional probabilities for sample 71000 / 227100
# [t-SNE] Computed conditional probabilities for sample 72000 / 227100
# [t-SNE] Computed conditional probabilities for sample 73000 / 227100
# [t-SNE] Computed conditional probabilities for sample 74000 / 227100
# [t-SNE] Computed conditional probabilities for sample 75000 / 227100
# [t-SNE] Computed conditional probabilities for sample 76000 / 227100
# [t-SNE] Computed conditional probabilities for sample 77000 / 227100
# [t-SNE] Computed conditional probabilities for sample 78000 / 227100
# [t-SNE] Computed conditional probabilities for sample 79000 / 227100
# [t-SNE] Computed conditional probabilities for sample 80000 / 227100
# [t-SNE] Computed conditional probabilities for sample 81000 / 227100
# [t-SNE] Computed conditional probabilities for sample 82000 / 227100
# [t-SNE] Computed conditional probabilities for sample 83000 / 227100
# [t-SNE] Computed conditional probabilities for sample 84000 / 227100
# [t-SNE] Computed conditional probabilities for sample 85000 / 227100
# [t-SNE] Computed conditional probabilities for sample 86000 / 227100
# [t-SNE] Computed conditional probabilities for sample 87000 / 227100
# [t-SNE] Computed conditional probabilities for sample 88000 / 227100
# [t-SNE] Computed conditional probabilities for sample 89000 / 227100
# [t-SNE] Computed conditional probabilities for sample 90000 / 227100
# [t-SNE] Computed conditional probabilities for sample 91000 / 227100
# [t-SNE] Computed conditional probabilities for sample 92000 / 227100
# [t-SNE] Computed conditional probabilities for sample 93000 / 227100
# [t-SNE] Computed conditional probabilities for sample 94000 / 227100
# [t-SNE] Computed conditional probabilities for sample 95000 / 227100
# [t-SNE] Computed conditional probabilities for sample 96000 / 227100
# [t-SNE] Computed conditional probabilities for sample 97000 / 227100
# [t-SNE] Computed conditional probabilities for sample 98000 / 227100
# [t-SNE] Computed conditional probabilities for sample 99000 / 227100
# [t-SNE] Computed conditional probabilities for sample 100000 / 227100
# [t-SNE] Computed conditional probabilities for sample 101000 / 227100
# [t-SNE] Computed conditional probabilities for sample 102000 / 227100
# [t-SNE] Computed conditional probabilities for sample 103000 / 227100
# [t-SNE] Computed conditional probabilities for sample 104000 / 227100
# [t-SNE] Computed conditional probabilities for sample 105000 / 227100
# [t-SNE] Computed conditional probabilities for sample 106000 / 227100
# [t-SNE] Computed conditional probabilities for sample 107000 / 227100
# [t-SNE] Computed conditional probabilities for sample 108000 / 227100
# [t-SNE] Computed conditional probabilities for sample 109000 / 227100
# [t-SNE] Computed conditional probabilities for sample 110000 / 227100
# [t-SNE] Computed conditional probabilities for sample 111000 / 227100
# [t-SNE] Computed conditional probabilities for sample 112000 / 227100
# [t-SNE] Computed conditional probabilities for sample 113000 / 227100
# [t-SNE] Computed conditional probabilities for sample 114000 / 227100
# [t-SNE] Computed conditional probabilities for sample 115000 / 227100
# [t-SNE] Computed conditional probabilities for sample 116000 / 227100
# [t-SNE] Computed conditional probabilities for sample 117000 / 227100
# [t-SNE] Computed conditional probabilities for sample 118000 / 227100
# [t-SNE] Computed conditional probabilities for sample 119000 / 227100
# [t-SNE] Computed conditional probabilities for sample 120000 / 227100
# [t-SNE] Computed conditional probabilities for sample 121000 / 227100
# [t-SNE] Computed conditional probabilities for sample 122000 / 227100
# [t-SNE] Computed conditional probabilities for sample 123000 / 227100
# [t-SNE] Computed conditional probabilities for sample 124000 / 227100
# [t-SNE] Computed conditional probabilities for sample 125000 / 227100
# [t-SNE] Computed conditional probabilities for sample 126000 / 227100
# [t-SNE] Computed conditional probabilities for sample 127000 / 227100
# [t-SNE] Computed conditional probabilities for sample 128000 / 227100
# [t-SNE] Computed conditional probabilities for sample 129000 / 227100
# [t-SNE] Computed conditional probabilities for sample 130000 / 227100
# [t-SNE] Computed conditional probabilities for sample 131000 / 227100
# [t-SNE] Computed conditional probabilities for sample 132000 / 227100
# [t-SNE] Computed conditional probabilities for sample 133000 / 227100
# [t-SNE] Computed conditional probabilities for sample 134000 / 227100
# [t-SNE] Computed conditional probabilities for sample 135000 / 227100
# [t-SNE] Computed conditional probabilities for sample 136000 / 227100
# [t-SNE] Computed conditional probabilities for sample 137000 / 227100
# [t-SNE] Computed conditional probabilities for sample 138000 / 227100
# [t-SNE] Computed conditional probabilities for sample 139000 / 227100
# [t-SNE] Computed conditional probabilities for sample 140000 / 227100
# [t-SNE] Computed conditional probabilities for sample 141000 / 227100
# [t-SNE] Computed conditional probabilities for sample 142000 / 227100
# [t-SNE] Computed conditional probabilities for sample 143000 / 227100
# [t-SNE] Computed conditional probabilities for sample 144000 / 227100
# [t-SNE] Computed conditional probabilities for sample 145000 / 227100
# [t-SNE] Computed conditional probabilities for sample 146000 / 227100
# [t-SNE] Computed conditional probabilities for sample 147000 / 227100
# [t-SNE] Computed conditional probabilities for sample 148000 / 227100
# [t-SNE] Computed conditional probabilities for sample 149000 / 227100
# [t-SNE] Computed conditional probabilities for sample 150000 / 227100
# [t-SNE] Computed conditional probabilities for sample 151000 / 227100
# [t-SNE] Computed conditional probabilities for sample 152000 / 227100
# [t-SNE] Computed conditional probabilities for sample 153000 / 227100
# [t-SNE] Computed conditional probabilities for sample 154000 / 227100
# [t-SNE] Computed conditional probabilities for sample 155000 / 227100
# [t-SNE] Computed conditional probabilities for sample 156000 / 227100
# [t-SNE] Computed conditional probabilities for sample 157000 / 227100
# [t-SNE] Computed conditional probabilities for sample 158000 / 227100
# [t-SNE] Computed conditional probabilities for sample 159000 / 227100
# [t-SNE] Computed conditional probabilities for sample 160000 / 227100
# [t-SNE] Computed conditional probabilities for sample 161000 / 227100
# [t-SNE] Computed conditional probabilities for sample 162000 / 227100
# [t-SNE] Computed conditional probabilities for sample 163000 / 227100
# [t-SNE] Computed conditional probabilities for sample 164000 / 227100
# [t-SNE] Computed conditional probabilities for sample 165000 / 227100
# [t-SNE] Computed conditional probabilities for sample 166000 / 227100
# [t-SNE] Computed conditional probabilities for sample 167000 / 227100
# [t-SNE] Computed conditional probabilities for sample 168000 / 227100
# [t-SNE] Computed conditional probabilities for sample 169000 / 227100
# [t-SNE] Computed conditional probabilities for sample 170000 / 227100
# [t-SNE] Computed conditional probabilities for sample 171000 / 227100
# [t-SNE] Computed conditional probabilities for sample 172000 / 227100
# [t-SNE] Computed conditional probabilities for sample 173000 / 227100
# [t-SNE] Computed conditional probabilities for sample 174000 / 227100
# [t-SNE] Computed conditional probabilities for sample 175000 / 227100
# [t-SNE] Computed conditional probabilities for sample 176000 / 227100
# [t-SNE] Computed conditional probabilities for sample 177000 / 227100
# [t-SNE] Computed conditional probabilities for sample 178000 / 227100
# [t-SNE] Computed conditional probabilities for sample 179000 / 227100
# [t-SNE] Computed conditional probabilities for sample 180000 / 227100
# [t-SNE] Computed conditional probabilities for sample 181000 / 227100
# [t-SNE] Computed conditional probabilities for sample 182000 / 227100
# [t-SNE] Computed conditional probabilities for sample 183000 / 227100
# [t-SNE] Computed conditional probabilities for sample 184000 / 227100
# [t-SNE] Computed conditional probabilities for sample 185000 / 227100
# [t-SNE] Computed conditional probabilities for sample 186000 / 227100
# [t-SNE] Computed conditional probabilities for sample 187000 / 227100
# [t-SNE] Computed conditional probabilities for sample 188000 / 227100
# [t-SNE] Computed conditional probabilities for sample 189000 / 227100
# [t-SNE] Computed conditional probabilities for sample 190000 / 227100
# [t-SNE] Computed conditional probabilities for sample 191000 / 227100
# [t-SNE] Computed conditional probabilities for sample 192000 / 227100
# [t-SNE] Computed conditional probabilities for sample 193000 / 227100
# [t-SNE] Computed conditional probabilities for sample 194000 / 227100
# [t-SNE] Computed conditional probabilities for sample 195000 / 227100
# [t-SNE] Computed conditional probabilities for sample 196000 / 227100
# [t-SNE] Computed conditional probabilities for sample 197000 / 227100
# [t-SNE] Computed conditional probabilities for sample 198000 / 227100
# [t-SNE] Computed conditional probabilities for sample 199000 / 227100
# [t-SNE] Computed conditional probabilities for sample 200000 / 227100
# [t-SNE] Computed conditional probabilities for sample 201000 / 227100
# [t-SNE] Computed conditional probabilities for sample 202000 / 227100
# [t-SNE] Computed conditional probabilities for sample 203000 / 227100
# [t-SNE] Computed conditional probabilities for sample 204000 / 227100
# [t-SNE] Computed conditional probabilities for sample 205000 / 227100
# [t-SNE] Computed conditional probabilities for sample 206000 / 227100
# [t-SNE] Computed conditional probabilities for sample 207000 / 227100
# [t-SNE] Computed conditional probabilities for sample 208000 / 227100
# [t-SNE] Computed conditional probabilities for sample 209000 / 227100
# [t-SNE] Computed conditional probabilities for sample 210000 / 227100
# [t-SNE] Computed conditional probabilities for sample 211000 / 227100
# [t-SNE] Computed conditional probabilities for sample 212000 / 227100
# [t-SNE] Computed conditional probabilities for sample 213000 / 227100
# [t-SNE] Computed conditional probabilities for sample 214000 / 227100
# [t-SNE] Computed conditional probabilities for sample 215000 / 227100
# [t-SNE] Computed conditional probabilities for sample 216000 / 227100
# [t-SNE] Computed conditional probabilities for sample 217000 / 227100
# [t-SNE] Computed conditional probabilities for sample 218000 / 227100
# [t-SNE] Computed conditional probabilities for sample 219000 / 227100
# [t-SNE] Computed conditional probabilities for sample 220000 / 227100
# [t-SNE] Computed conditional probabilities for sample 221000 / 227100
# [t-SNE] Computed conditional probabilities for sample 222000 / 227100
# [t-SNE] Computed conditional probabilities for sample 223000 / 227100
# [t-SNE] Computed conditional probabilities for sample 224000 / 227100
# [t-SNE] Computed conditional probabilities for sample 225000 / 227100
# [t-SNE] Computed conditional probabilities for sample 226000 / 227100
# [t-SNE] Computed conditional probabilities for sample 227000 / 227100
# [t-SNE] Computed conditional probabilities for sample 227100 / 227100
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 52.498489
# [t-SNE] KL divergence after 300 iterations: 1.291803

# %%
tdesc_data2 = par_desc_data2.drop_duplicates(subset=['robot index', 'replicate'])
tdesc_data2 = par_desc_data2[["width","depth","height","voxels","wheels","sensors","joints","casters"]]
tsne_results2 = tsne.fit_transform(tdesc_data2)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 204300 samples in 0.185s...
# [t-SNE] Computed neighbors for 204300 samples in 35.871s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 204300
# [t-SNE] Computed conditional probabilities for sample 2000 / 204300
# [t-SNE] Computed conditional probabilities for sample 3000 / 204300
# [t-SNE] Computed conditional probabilities for sample 4000 / 204300
# [t-SNE] Computed conditional probabilities for sample 5000 / 204300
# [t-SNE] Computed conditional probabilities for sample 6000 / 204300
# [t-SNE] Computed conditional probabilities for sample 7000 / 204300
# [t-SNE] Computed conditional probabilities for sample 8000 / 204300
# [t-SNE] Computed conditional probabilities for sample 9000 / 204300
# [t-SNE] Computed conditional probabilities for sample 10000 / 204300
# [t-SNE] Computed conditional probabilities for sample 11000 / 204300
# [t-SNE] Computed conditional probabilities for sample 12000 / 204300
# [t-SNE] Computed conditional probabilities for sample 13000 / 204300
# [t-SNE] Computed conditional probabilities for sample 14000 / 204300
# [t-SNE] Computed conditional probabilities for sample 15000 / 204300
# [t-SNE] Computed conditional probabilities for sample 16000 / 204300
# [t-SNE] Computed conditional probabilities for sample 17000 / 204300
# [t-SNE] Computed conditional probabilities for sample 18000 / 204300
# [t-SNE] Computed conditional probabilities for sample 19000 / 204300
# [t-SNE] Computed conditional probabilities for sample 20000 / 204300
# [t-SNE] Computed conditional probabilities for sample 21000 / 204300
# [t-SNE] Computed conditional probabilities for sample 22000 / 204300
# [t-SNE] Computed conditional probabilities for sample 23000 / 204300
# [t-SNE] Computed conditional probabilities for sample 24000 / 204300
# [t-SNE] Computed conditional probabilities for sample 25000 / 204300
# [t-SNE] Computed conditional probabilities for sample 26000 / 204300
# [t-SNE] Computed conditional probabilities for sample 27000 / 204300
# [t-SNE] Computed conditional probabilities for sample 28000 / 204300
# [t-SNE] Computed conditional probabilities for sample 29000 / 204300
# [t-SNE] Computed conditional probabilities for sample 30000 / 204300
# [t-SNE] Computed conditional probabilities for sample 31000 / 204300
# [t-SNE] Computed conditional probabilities for sample 32000 / 204300
# [t-SNE] Computed conditional probabilities for sample 33000 / 204300
# [t-SNE] Computed conditional probabilities for sample 34000 / 204300
# [t-SNE] Computed conditional probabilities for sample 35000 / 204300
# [t-SNE] Computed conditional probabilities for sample 36000 / 204300
# [t-SNE] Computed conditional probabilities for sample 37000 / 204300
# [t-SNE] Computed conditional probabilities for sample 38000 / 204300
# [t-SNE] Computed conditional probabilities for sample 39000 / 204300
# [t-SNE] Computed conditional probabilities for sample 40000 / 204300
# [t-SNE] Computed conditional probabilities for sample 41000 / 204300
# [t-SNE] Computed conditional probabilities for sample 42000 / 204300
# [t-SNE] Computed conditional probabilities for sample 43000 / 204300
# [t-SNE] Computed conditional probabilities for sample 44000 / 204300
# [t-SNE] Computed conditional probabilities for sample 45000 / 204300
# [t-SNE] Computed conditional probabilities for sample 46000 / 204300
# [t-SNE] Computed conditional probabilities for sample 47000 / 204300
# [t-SNE] Computed conditional probabilities for sample 48000 / 204300
# [t-SNE] Computed conditional probabilities for sample 49000 / 204300
# [t-SNE] Computed conditional probabilities for sample 50000 / 204300
# [t-SNE] Computed conditional probabilities for sample 51000 / 204300
# [t-SNE] Computed conditional probabilities for sample 52000 / 204300
# [t-SNE] Computed conditional probabilities for sample 53000 / 204300
# [t-SNE] Computed conditional probabilities for sample 54000 / 204300
# [t-SNE] Computed conditional probabilities for sample 55000 / 204300
# [t-SNE] Computed conditional probabilities for sample 56000 / 204300
# [t-SNE] Computed conditional probabilities for sample 57000 / 204300
# [t-SNE] Computed conditional probabilities for sample 58000 / 204300
# [t-SNE] Computed conditional probabilities for sample 59000 / 204300
# [t-SNE] Computed conditional probabilities for sample 60000 / 204300
# [t-SNE] Computed conditional probabilities for sample 61000 / 204300
# [t-SNE] Computed conditional probabilities for sample 62000 / 204300
# [t-SNE] Computed conditional probabilities for sample 63000 / 204300
# [t-SNE] Computed conditional probabilities for sample 64000 / 204300
# [t-SNE] Computed conditional probabilities for sample 65000 / 204300
# [t-SNE] Computed conditional probabilities for sample 66000 / 204300
# [t-SNE] Computed conditional probabilities for sample 67000 / 204300
# [t-SNE] Computed conditional probabilities for sample 68000 / 204300
# [t-SNE] Computed conditional probabilities for sample 69000 / 204300
# [t-SNE] Computed conditional probabilities for sample 70000 / 204300
# [t-SNE] Computed conditional probabilities for sample 71000 / 204300
# [t-SNE] Computed conditional probabilities for sample 72000 / 204300
# [t-SNE] Computed conditional probabilities for sample 73000 / 204300
# [t-SNE] Computed conditional probabilities for sample 74000 / 204300
# [t-SNE] Computed conditional probabilities for sample 75000 / 204300
# [t-SNE] Computed conditional probabilities for sample 76000 / 204300
# [t-SNE] Computed conditional probabilities for sample 77000 / 204300
# [t-SNE] Computed conditional probabilities for sample 78000 / 204300
# [t-SNE] Computed conditional probabilities for sample 79000 / 204300
# [t-SNE] Computed conditional probabilities for sample 80000 / 204300
# [t-SNE] Computed conditional probabilities for sample 81000 / 204300
# [t-SNE] Computed conditional probabilities for sample 82000 / 204300
# [t-SNE] Computed conditional probabilities for sample 83000 / 204300
# [t-SNE] Computed conditional probabilities for sample 84000 / 204300
# [t-SNE] Computed conditional probabilities for sample 85000 / 204300
# [t-SNE] Computed conditional probabilities for sample 86000 / 204300
# [t-SNE] Computed conditional probabilities for sample 87000 / 204300
# [t-SNE] Computed conditional probabilities for sample 88000 / 204300
# [t-SNE] Computed conditional probabilities for sample 89000 / 204300
# [t-SNE] Computed conditional probabilities for sample 90000 / 204300
# [t-SNE] Computed conditional probabilities for sample 91000 / 204300
# [t-SNE] Computed conditional probabilities for sample 92000 / 204300
# [t-SNE] Computed conditional probabilities for sample 93000 / 204300
# [t-SNE] Computed conditional probabilities for sample 94000 / 204300
# [t-SNE] Computed conditional probabilities for sample 95000 / 204300
# [t-SNE] Computed conditional probabilities for sample 96000 / 204300
# [t-SNE] Computed conditional probabilities for sample 97000 / 204300
# [t-SNE] Computed conditional probabilities for sample 98000 / 204300
# [t-SNE] Computed conditional probabilities for sample 99000 / 204300
# [t-SNE] Computed conditional probabilities for sample 100000 / 204300
# [t-SNE] Computed conditional probabilities for sample 101000 / 204300
# [t-SNE] Computed conditional probabilities for sample 102000 / 204300
# [t-SNE] Computed conditional probabilities for sample 103000 / 204300
# [t-SNE] Computed conditional probabilities for sample 104000 / 204300
# [t-SNE] Computed conditional probabilities for sample 105000 / 204300
# [t-SNE] Computed conditional probabilities for sample 106000 / 204300
# [t-SNE] Computed conditional probabilities for sample 107000 / 204300
# [t-SNE] Computed conditional probabilities for sample 108000 / 204300
# [t-SNE] Computed conditional probabilities for sample 109000 / 204300
# [t-SNE] Computed conditional probabilities for sample 110000 / 204300
# [t-SNE] Computed conditional probabilities for sample 111000 / 204300
# [t-SNE] Computed conditional probabilities for sample 112000 / 204300
# [t-SNE] Computed conditional probabilities for sample 113000 / 204300
# [t-SNE] Computed conditional probabilities for sample 114000 / 204300
# [t-SNE] Computed conditional probabilities for sample 115000 / 204300
# [t-SNE] Computed conditional probabilities for sample 116000 / 204300
# [t-SNE] Computed conditional probabilities for sample 117000 / 204300
# [t-SNE] Computed conditional probabilities for sample 118000 / 204300
# [t-SNE] Computed conditional probabilities for sample 119000 / 204300
# [t-SNE] Computed conditional probabilities for sample 120000 / 204300
# [t-SNE] Computed conditional probabilities for sample 121000 / 204300
# [t-SNE] Computed conditional probabilities for sample 122000 / 204300
# [t-SNE] Computed conditional probabilities for sample 123000 / 204300
# [t-SNE] Computed conditional probabilities for sample 124000 / 204300
# [t-SNE] Computed conditional probabilities for sample 125000 / 204300
# [t-SNE] Computed conditional probabilities for sample 126000 / 204300
# [t-SNE] Computed conditional probabilities for sample 127000 / 204300
# [t-SNE] Computed conditional probabilities for sample 128000 / 204300
# [t-SNE] Computed conditional probabilities for sample 129000 / 204300
# [t-SNE] Computed conditional probabilities for sample 130000 / 204300
# [t-SNE] Computed conditional probabilities for sample 131000 / 204300
# [t-SNE] Computed conditional probabilities for sample 132000 / 204300
# [t-SNE] Computed conditional probabilities for sample 133000 / 204300
# [t-SNE] Computed conditional probabilities for sample 134000 / 204300
# [t-SNE] Computed conditional probabilities for sample 135000 / 204300
# [t-SNE] Computed conditional probabilities for sample 136000 / 204300
# [t-SNE] Computed conditional probabilities for sample 137000 / 204300
# [t-SNE] Computed conditional probabilities for sample 138000 / 204300
# [t-SNE] Computed conditional probabilities for sample 139000 / 204300
# [t-SNE] Computed conditional probabilities for sample 140000 / 204300
# [t-SNE] Computed conditional probabilities for sample 141000 / 204300
# [t-SNE] Computed conditional probabilities for sample 142000 / 204300
# [t-SNE] Computed conditional probabilities for sample 143000 / 204300
# [t-SNE] Computed conditional probabilities for sample 144000 / 204300
# [t-SNE] Computed conditional probabilities for sample 145000 / 204300
# [t-SNE] Computed conditional probabilities for sample 146000 / 204300
# [t-SNE] Computed conditional probabilities for sample 147000 / 204300
# [t-SNE] Computed conditional probabilities for sample 148000 / 204300
# [t-SNE] Computed conditional probabilities for sample 149000 / 204300
# [t-SNE] Computed conditional probabilities for sample 150000 / 204300
# [t-SNE] Computed conditional probabilities for sample 151000 / 204300
# [t-SNE] Computed conditional probabilities for sample 152000 / 204300
# [t-SNE] Computed conditional probabilities for sample 153000 / 204300
# [t-SNE] Computed conditional probabilities for sample 154000 / 204300
# [t-SNE] Computed conditional probabilities for sample 155000 / 204300
# [t-SNE] Computed conditional probabilities for sample 156000 / 204300
# [t-SNE] Computed conditional probabilities for sample 157000 / 204300
# [t-SNE] Computed conditional probabilities for sample 158000 / 204300
# [t-SNE] Computed conditional probabilities for sample 159000 / 204300
# [t-SNE] Computed conditional probabilities for sample 160000 / 204300
# [t-SNE] Computed conditional probabilities for sample 161000 / 204300
# [t-SNE] Computed conditional probabilities for sample 162000 / 204300
# [t-SNE] Computed conditional probabilities for sample 163000 / 204300
# [t-SNE] Computed conditional probabilities for sample 164000 / 204300
# [t-SNE] Computed conditional probabilities for sample 165000 / 204300
# [t-SNE] Computed conditional probabilities for sample 166000 / 204300
# [t-SNE] Computed conditional probabilities for sample 167000 / 204300
# [t-SNE] Computed conditional probabilities for sample 168000 / 204300
# [t-SNE] Computed conditional probabilities for sample 169000 / 204300
# [t-SNE] Computed conditional probabilities for sample 170000 / 204300
# [t-SNE] Computed conditional probabilities for sample 171000 / 204300
# [t-SNE] Computed conditional probabilities for sample 172000 / 204300
# [t-SNE] Computed conditional probabilities for sample 173000 / 204300
# [t-SNE] Computed conditional probabilities for sample 174000 / 204300
# [t-SNE] Computed conditional probabilities for sample 175000 / 204300
# [t-SNE] Computed conditional probabilities for sample 176000 / 204300
# [t-SNE] Computed conditional probabilities for sample 177000 / 204300
# [t-SNE] Computed conditional probabilities for sample 178000 / 204300
# [t-SNE] Computed conditional probabilities for sample 179000 / 204300
# [t-SNE] Computed conditional probabilities for sample 180000 / 204300
# [t-SNE] Computed conditional probabilities for sample 181000 / 204300
# [t-SNE] Computed conditional probabilities for sample 182000 / 204300
# [t-SNE] Computed conditional probabilities for sample 183000 / 204300
# [t-SNE] Computed conditional probabilities for sample 184000 / 204300
# [t-SNE] Computed conditional probabilities for sample 185000 / 204300
# [t-SNE] Computed conditional probabilities for sample 186000 / 204300
# [t-SNE] Computed conditional probabilities for sample 187000 / 204300
# [t-SNE] Computed conditional probabilities for sample 188000 / 204300
# [t-SNE] Computed conditional probabilities for sample 189000 / 204300
# [t-SNE] Computed conditional probabilities for sample 190000 / 204300
# [t-SNE] Computed conditional probabilities for sample 191000 / 204300
# [t-SNE] Computed conditional probabilities for sample 192000 / 204300
# [t-SNE] Computed conditional probabilities for sample 193000 / 204300
# [t-SNE] Computed conditional probabilities for sample 194000 / 204300
# [t-SNE] Computed conditional probabilities for sample 195000 / 204300
# [t-SNE] Computed conditional probabilities for sample 196000 / 204300
# [t-SNE] Computed conditional probabilities for sample 197000 / 204300
# [t-SNE] Computed conditional probabilities for sample 198000 / 204300
# [t-SNE] Computed conditional probabilities for sample 199000 / 204300
# [t-SNE] Computed conditional probabilities for sample 200000 / 204300
# [t-SNE] Computed conditional probabilities for sample 201000 / 204300
# [t-SNE] Computed conditional probabilities for sample 202000 / 204300
# [t-SNE] Computed conditional probabilities for sample 203000 / 204300
# [t-SNE] Computed conditional probabilities for sample 204000 / 204300
# [t-SNE] Computed conditional probabilities for sample 204300 / 204300
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.867561
# [t-SNE] KL divergence after 300 iterations: 1.638068

# %%
tdesc_data3 = par_desc_data3.drop_duplicates(subset=['robot index', 'replicate'])
tdesc_data3 = par_desc_data3[["width","depth","height","voxels","wheels","sensors","joints","casters"]]
tsne_results3 = tsne.fit_transform(tdesc_data3)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 207300 samples in 0.166s...
# [t-SNE] Computed neighbors for 207300 samples in 46.248s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 207300
# [t-SNE] Computed conditional probabilities for sample 2000 / 207300
# [t-SNE] Computed conditional probabilities for sample 3000 / 207300
# [t-SNE] Computed conditional probabilities for sample 4000 / 207300
# [t-SNE] Computed conditional probabilities for sample 5000 / 207300
# [t-SNE] Computed conditional probabilities for sample 6000 / 207300
# [t-SNE] Computed conditional probabilities for sample 7000 / 207300
# [t-SNE] Computed conditional probabilities for sample 8000 / 207300
# [t-SNE] Computed conditional probabilities for sample 9000 / 207300
# [t-SNE] Computed conditional probabilities for sample 10000 / 207300
# [t-SNE] Computed conditional probabilities for sample 11000 / 207300
# [t-SNE] Computed conditional probabilities for sample 12000 / 207300
# [t-SNE] Computed conditional probabilities for sample 13000 / 207300
# [t-SNE] Computed conditional probabilities for sample 14000 / 207300
# [t-SNE] Computed conditional probabilities for sample 15000 / 207300
# [t-SNE] Computed conditional probabilities for sample 16000 / 207300
# [t-SNE] Computed conditional probabilities for sample 17000 / 207300
# [t-SNE] Computed conditional probabilities for sample 18000 / 207300
# [t-SNE] Computed conditional probabilities for sample 19000 / 207300
# [t-SNE] Computed conditional probabilities for sample 20000 / 207300
# [t-SNE] Computed conditional probabilities for sample 21000 / 207300
# [t-SNE] Computed conditional probabilities for sample 22000 / 207300
# [t-SNE] Computed conditional probabilities for sample 23000 / 207300
# [t-SNE] Computed conditional probabilities for sample 24000 / 207300
# [t-SNE] Computed conditional probabilities for sample 25000 / 207300
# [t-SNE] Computed conditional probabilities for sample 26000 / 207300
# [t-SNE] Computed conditional probabilities for sample 27000 / 207300
# [t-SNE] Computed conditional probabilities for sample 28000 / 207300
# [t-SNE] Computed conditional probabilities for sample 29000 / 207300
# [t-SNE] Computed conditional probabilities for sample 30000 / 207300
# [t-SNE] Computed conditional probabilities for sample 31000 / 207300
# [t-SNE] Computed conditional probabilities for sample 32000 / 207300
# [t-SNE] Computed conditional probabilities for sample 33000 / 207300
# [t-SNE] Computed conditional probabilities for sample 34000 / 207300
# [t-SNE] Computed conditional probabilities for sample 35000 / 207300
# [t-SNE] Computed conditional probabilities for sample 36000 / 207300
# [t-SNE] Computed conditional probabilities for sample 37000 / 207300
# [t-SNE] Computed conditional probabilities for sample 38000 / 207300
# [t-SNE] Computed conditional probabilities for sample 39000 / 207300
# [t-SNE] Computed conditional probabilities for sample 40000 / 207300
# [t-SNE] Computed conditional probabilities for sample 41000 / 207300
# [t-SNE] Computed conditional probabilities for sample 42000 / 207300
# [t-SNE] Computed conditional probabilities for sample 43000 / 207300
# [t-SNE] Computed conditional probabilities for sample 44000 / 207300
# [t-SNE] Computed conditional probabilities for sample 45000 / 207300
# [t-SNE] Computed conditional probabilities for sample 46000 / 207300
# [t-SNE] Computed conditional probabilities for sample 47000 / 207300
# [t-SNE] Computed conditional probabilities for sample 48000 / 207300
# [t-SNE] Computed conditional probabilities for sample 49000 / 207300
# [t-SNE] Computed conditional probabilities for sample 50000 / 207300
# [t-SNE] Computed conditional probabilities for sample 51000 / 207300
# [t-SNE] Computed conditional probabilities for sample 52000 / 207300
# [t-SNE] Computed conditional probabilities for sample 53000 / 207300
# [t-SNE] Computed conditional probabilities for sample 54000 / 207300
# [t-SNE] Computed conditional probabilities for sample 55000 / 207300
# [t-SNE] Computed conditional probabilities for sample 56000 / 207300
# [t-SNE] Computed conditional probabilities for sample 57000 / 207300
# [t-SNE] Computed conditional probabilities for sample 58000 / 207300
# [t-SNE] Computed conditional probabilities for sample 59000 / 207300
# [t-SNE] Computed conditional probabilities for sample 60000 / 207300
# [t-SNE] Computed conditional probabilities for sample 61000 / 207300
# [t-SNE] Computed conditional probabilities for sample 62000 / 207300
# [t-SNE] Computed conditional probabilities for sample 63000 / 207300
# [t-SNE] Computed conditional probabilities for sample 64000 / 207300
# [t-SNE] Computed conditional probabilities for sample 65000 / 207300
# [t-SNE] Computed conditional probabilities for sample 66000 / 207300
# [t-SNE] Computed conditional probabilities for sample 67000 / 207300
# [t-SNE] Computed conditional probabilities for sample 68000 / 207300
# [t-SNE] Computed conditional probabilities for sample 69000 / 207300
# [t-SNE] Computed conditional probabilities for sample 70000 / 207300
# [t-SNE] Computed conditional probabilities for sample 71000 / 207300
# [t-SNE] Computed conditional probabilities for sample 72000 / 207300
# [t-SNE] Computed conditional probabilities for sample 73000 / 207300
# [t-SNE] Computed conditional probabilities for sample 74000 / 207300
# [t-SNE] Computed conditional probabilities for sample 75000 / 207300
# [t-SNE] Computed conditional probabilities for sample 76000 / 207300
# [t-SNE] Computed conditional probabilities for sample 77000 / 207300
# [t-SNE] Computed conditional probabilities for sample 78000 / 207300
# [t-SNE] Computed conditional probabilities for sample 79000 / 207300
# [t-SNE] Computed conditional probabilities for sample 80000 / 207300
# [t-SNE] Computed conditional probabilities for sample 81000 / 207300
# [t-SNE] Computed conditional probabilities for sample 82000 / 207300
# [t-SNE] Computed conditional probabilities for sample 83000 / 207300
# [t-SNE] Computed conditional probabilities for sample 84000 / 207300
# [t-SNE] Computed conditional probabilities for sample 85000 / 207300
# [t-SNE] Computed conditional probabilities for sample 86000 / 207300
# [t-SNE] Computed conditional probabilities for sample 87000 / 207300
# [t-SNE] Computed conditional probabilities for sample 88000 / 207300
# [t-SNE] Computed conditional probabilities for sample 89000 / 207300
# [t-SNE] Computed conditional probabilities for sample 90000 / 207300
# [t-SNE] Computed conditional probabilities for sample 91000 / 207300
# [t-SNE] Computed conditional probabilities for sample 92000 / 207300
# [t-SNE] Computed conditional probabilities for sample 93000 / 207300
# [t-SNE] Computed conditional probabilities for sample 94000 / 207300
# [t-SNE] Computed conditional probabilities for sample 95000 / 207300
# [t-SNE] Computed conditional probabilities for sample 96000 / 207300
# [t-SNE] Computed conditional probabilities for sample 97000 / 207300
# [t-SNE] Computed conditional probabilities for sample 98000 / 207300
# [t-SNE] Computed conditional probabilities for sample 99000 / 207300
# [t-SNE] Computed conditional probabilities for sample 100000 / 207300
# [t-SNE] Computed conditional probabilities for sample 101000 / 207300
# [t-SNE] Computed conditional probabilities for sample 102000 / 207300
# [t-SNE] Computed conditional probabilities for sample 103000 / 207300
# [t-SNE] Computed conditional probabilities for sample 104000 / 207300
# [t-SNE] Computed conditional probabilities for sample 105000 / 207300
# [t-SNE] Computed conditional probabilities for sample 106000 / 207300
# [t-SNE] Computed conditional probabilities for sample 107000 / 207300
# [t-SNE] Computed conditional probabilities for sample 108000 / 207300
# [t-SNE] Computed conditional probabilities for sample 109000 / 207300
# [t-SNE] Computed conditional probabilities for sample 110000 / 207300
# [t-SNE] Computed conditional probabilities for sample 111000 / 207300
# [t-SNE] Computed conditional probabilities for sample 112000 / 207300
# [t-SNE] Computed conditional probabilities for sample 113000 / 207300
# [t-SNE] Computed conditional probabilities for sample 114000 / 207300
# [t-SNE] Computed conditional probabilities for sample 115000 / 207300
# [t-SNE] Computed conditional probabilities for sample 116000 / 207300
# [t-SNE] Computed conditional probabilities for sample 117000 / 207300
# [t-SNE] Computed conditional probabilities for sample 118000 / 207300
# [t-SNE] Computed conditional probabilities for sample 119000 / 207300
# [t-SNE] Computed conditional probabilities for sample 120000 / 207300
# [t-SNE] Computed conditional probabilities for sample 121000 / 207300
# [t-SNE] Computed conditional probabilities for sample 122000 / 207300
# [t-SNE] Computed conditional probabilities for sample 123000 / 207300
# [t-SNE] Computed conditional probabilities for sample 124000 / 207300
# [t-SNE] Computed conditional probabilities for sample 125000 / 207300
# [t-SNE] Computed conditional probabilities for sample 126000 / 207300
# [t-SNE] Computed conditional probabilities for sample 127000 / 207300
# [t-SNE] Computed conditional probabilities for sample 128000 / 207300
# [t-SNE] Computed conditional probabilities for sample 129000 / 207300
# [t-SNE] Computed conditional probabilities for sample 130000 / 207300
# [t-SNE] Computed conditional probabilities for sample 131000 / 207300
# [t-SNE] Computed conditional probabilities for sample 132000 / 207300
# [t-SNE] Computed conditional probabilities for sample 133000 / 207300
# [t-SNE] Computed conditional probabilities for sample 134000 / 207300
# [t-SNE] Computed conditional probabilities for sample 135000 / 207300
# [t-SNE] Computed conditional probabilities for sample 136000 / 207300
# [t-SNE] Computed conditional probabilities for sample 137000 / 207300
# [t-SNE] Computed conditional probabilities for sample 138000 / 207300
# [t-SNE] Computed conditional probabilities for sample 139000 / 207300
# [t-SNE] Computed conditional probabilities for sample 140000 / 207300
# [t-SNE] Computed conditional probabilities for sample 141000 / 207300
# [t-SNE] Computed conditional probabilities for sample 142000 / 207300
# [t-SNE] Computed conditional probabilities for sample 143000 / 207300
# [t-SNE] Computed conditional probabilities for sample 144000 / 207300
# [t-SNE] Computed conditional probabilities for sample 145000 / 207300
# [t-SNE] Computed conditional probabilities for sample 146000 / 207300
# [t-SNE] Computed conditional probabilities for sample 147000 / 207300
# [t-SNE] Computed conditional probabilities for sample 148000 / 207300
# [t-SNE] Computed conditional probabilities for sample 149000 / 207300
# [t-SNE] Computed conditional probabilities for sample 150000 / 207300
# [t-SNE] Computed conditional probabilities for sample 151000 / 207300
# [t-SNE] Computed conditional probabilities for sample 152000 / 207300
# [t-SNE] Computed conditional probabilities for sample 153000 / 207300
# [t-SNE] Computed conditional probabilities for sample 154000 / 207300
# [t-SNE] Computed conditional probabilities for sample 155000 / 207300
# [t-SNE] Computed conditional probabilities for sample 156000 / 207300
# [t-SNE] Computed conditional probabilities for sample 157000 / 207300
# [t-SNE] Computed conditional probabilities for sample 158000 / 207300
# [t-SNE] Computed conditional probabilities for sample 159000 / 207300
# [t-SNE] Computed conditional probabilities for sample 160000 / 207300
# [t-SNE] Computed conditional probabilities for sample 161000 / 207300
# [t-SNE] Computed conditional probabilities for sample 162000 / 207300
# [t-SNE] Computed conditional probabilities for sample 163000 / 207300
# [t-SNE] Computed conditional probabilities for sample 164000 / 207300
# [t-SNE] Computed conditional probabilities for sample 165000 / 207300
# [t-SNE] Computed conditional probabilities for sample 166000 / 207300
# [t-SNE] Computed conditional probabilities for sample 167000 / 207300
# [t-SNE] Computed conditional probabilities for sample 168000 / 207300
# [t-SNE] Computed conditional probabilities for sample 169000 / 207300
# [t-SNE] Computed conditional probabilities for sample 170000 / 207300
# [t-SNE] Computed conditional probabilities for sample 171000 / 207300
# [t-SNE] Computed conditional probabilities for sample 172000 / 207300
# [t-SNE] Computed conditional probabilities for sample 173000 / 207300
# [t-SNE] Computed conditional probabilities for sample 174000 / 207300
# [t-SNE] Computed conditional probabilities for sample 175000 / 207300
# [t-SNE] Computed conditional probabilities for sample 176000 / 207300
# [t-SNE] Computed conditional probabilities for sample 177000 / 207300
# [t-SNE] Computed conditional probabilities for sample 178000 / 207300
# [t-SNE] Computed conditional probabilities for sample 179000 / 207300
# [t-SNE] Computed conditional probabilities for sample 180000 / 207300
# [t-SNE] Computed conditional probabilities for sample 181000 / 207300
# [t-SNE] Computed conditional probabilities for sample 182000 / 207300
# [t-SNE] Computed conditional probabilities for sample 183000 / 207300
# [t-SNE] Computed conditional probabilities for sample 184000 / 207300
# [t-SNE] Computed conditional probabilities for sample 185000 / 207300
# [t-SNE] Computed conditional probabilities for sample 186000 / 207300
# [t-SNE] Computed conditional probabilities for sample 187000 / 207300
# [t-SNE] Computed conditional probabilities for sample 188000 / 207300
# [t-SNE] Computed conditional probabilities for sample 189000 / 207300
# [t-SNE] Computed conditional probabilities for sample 190000 / 207300
# [t-SNE] Computed conditional probabilities for sample 191000 / 207300
# [t-SNE] Computed conditional probabilities for sample 192000 / 207300
# [t-SNE] Computed conditional probabilities for sample 193000 / 207300
# [t-SNE] Computed conditional probabilities for sample 194000 / 207300
# [t-SNE] Computed conditional probabilities for sample 195000 / 207300
# [t-SNE] Computed conditional probabilities for sample 196000 / 207300
# [t-SNE] Computed conditional probabilities for sample 197000 / 207300
# [t-SNE] Computed conditional probabilities for sample 198000 / 207300
# [t-SNE] Computed conditional probabilities for sample 199000 / 207300
# [t-SNE] Computed conditional probabilities for sample 200000 / 207300
# [t-SNE] Computed conditional probabilities for sample 201000 / 207300
# [t-SNE] Computed conditional probabilities for sample 202000 / 207300
# [t-SNE] Computed conditional probabilities for sample 203000 / 207300
# [t-SNE] Computed conditional probabilities for sample 204000 / 207300
# [t-SNE] Computed conditional probabilities for sample 205000 / 207300
# [t-SNE] Computed conditional probabilities for sample 206000 / 207300
# [t-SNE] Computed conditional probabilities for sample 207000 / 207300
# [t-SNE] Computed conditional probabilities for sample 207300 / 207300
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 41.095085
# [t-SNE] KL divergence after 300 iterations: 0.669754

# %%
df_tsne_results1 = pd.DataFrame(tsne_results1)
df_tsne_results1['hyperparameter_set']='HK1'
df_tsne_results2 = pd.DataFrame(tsne_results2)
df_tsne_results2['hyperparameter_set']='HK2'
df_tsne_results3 = pd.DataFrame(tsne_results3)
df_tsne_results3['hyperparameter_set']='HK3'
df_tsne_all = [df_tsne_results1, df_tsne_results2, df_tsne_results3]
df_tsne_all = pd.concat(df_tsne_all)

# %%
df_tsne_all
# Out:
#                 0          1 hyperparameter_set
# 0       11.365830  -8.261133                HK1
# 1       12.501251  -7.928127                HK1
# 2       13.325271  -7.488553                HK1
# 3       13.001450  -7.922006                HK1
# 4       14.890769  -1.726349                HK1
# ...           ...        ...                ...
# 207295  16.101278  -9.307412                HK3
# 207296   1.710970   6.939203                HK3
# 207297  28.156395  18.670788                HK3
# 207298 -31.062559  12.563479                HK3
# 207299   7.682970 -21.916969                HK3
#
# [638700 rows x 3 columns]

# %%
plt.figure(figsize=(16,10))
plt.xlim(-50, 50)
plt.ylim(-50, 50)
sns.scatterplot(
    x=0, y=1,
    hue="hyperparameter_set",
    palette=sns.color_palette("hls", 10),
    data=df_tsne_all,
    legend="full",
    alpha=0.1
)
# Out:
# /tmp/ipykernel_2049262/4253583380.py:4: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.scatterplot(
# <Axes: xlabel='0', ylabel='1'>
