# %%
import os
import sys
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import nipes_data_fcts as nidf
import me_data_fcts as medf
from statannotations.Annotator import Annotator

# %%
import importlib
importlib.reload(medf)
# Out:
# <module 'me_data_fcts' from '/home/leni/git/AREFramework/experiments/scripts/me_data_fcts.py'>

# %%
repo_folder = "/media/leni/DATADRIVE1/are-logs/"

# %% [markdown]
# # Random design generation

# %%
random_folder = repo_folder + "/sq_cppn_random/"
random_folder_2 = repo_folder + "/sq_cppn_random_2/"

# %%
parent_descs = []
for folder in os.listdir(random_folder):
    print(folder)
    descriptors = medf.load_feature_descriptor(random_folder + "/" + folder + "/morph_features.csv")
    descs = [[int(d[0])] + d[1:5] + [d[5]*16,d[6]*16,d[7]*16,d[8]*16] + d[9:]  + [folder] for d in descriptors]
    parent_descs += descs

par_desc_data1 = pd.DataFrame(data=parent_descs,columns=["robot id","width","depth","height","voxels","wheels","sensors","joints","casters","norm","skeleton norm","components norm","replicate"])
# Out:
# sq_cppn_random_12_11_10-13-30-230-3444138865
# sq_cppn_random_12_11_10-13-30-236-842617811
# sq_cppn_random_12_11_10-15-33-3554-2648169285
# sq_cppn_random_12_11_10-15-42-2554-2239398340
# sq_cppn_random_12_11_10-17-37-7617-1251448372

# %%
parent_descs = []
for folder in os.listdir(random_folder_2):
    print(folder)
    descriptors = medf.load_feature_descriptor(random_folder_2 + "/" + folder + "/morph_features.csv")
    descs = [[int(d[0])] + d[1:5] + [d[5]*16,d[6]*16,d[7]*16,d[8]*16] + d[9:]  + [folder] for d in descriptors]
    parent_descs += descs

par_desc_data2 = pd.DataFrame(data=parent_descs,columns=["robot id","width","depth","height","voxels","wheels","sensors","joints","casters","norm","skeleton norm","components norm","replicate"])
# Out:
# sq_cppn_random_12_11_13-48-35-5096-1517153808
# sq_cppn_random_12_11_13-48-40-901-793306471
# sq_cppn_random_12_11_13-48-43-3886-1602675102
# sq_cppn_random_12_11_13-50-36-6535-893724098
# sq_cppn_random_12_11_13-50-38-8624-1300464796

# %%
print(par_desc_data1)
# Out:
#       robot id     width     depth    height    voxels  wheels  sensors  \
# 0            0  0.909091  0.545455  0.545455  0.048084     0.0      7.0
# 1            1  0.727273  0.727273  0.090909  0.045079     0.0      5.0
# 2            2  0.545455  0.545455  0.090909  0.018783     1.0      1.0
# 3            3  0.909091  0.727273  0.545455  0.081893     1.0      1.0
# 4            4  0.909091  0.909091  0.909091  0.539444     0.0      2.0
# ...        ...       ...       ...       ...       ...     ...      ...
# 4995       995  0.818182  0.545455  0.181818  0.023291     2.0      0.0
# 4996       996  0.909091  0.727273  0.909091  0.089406     2.0      3.0
# 4997       997  0.909091  0.909091  0.636364  0.305034     5.0      2.0
# 4998       998  0.909091  0.909091  0.636364  0.422239     1.0      1.0
# 4999       999  0.909091  0.909091  0.090909  0.108189     0.0      1.0
#
#       joints  casters      norm  skeleton norm  components norm  \
# ...

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=par_desc_data1,x="voxels",legend=False,hue="replicate")
ax.yaxis.label.set_size(20)
#plt.legend(["MEHK","MEFC"],fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis number of voxels")
plt.yticks(fontsize=20)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2]),
#  [Text(0, 0.0, '0.0'),
#   Text(0, 0.2, '0.2'),
#   Text(0, 0.4, '0.4'),
#   Text(0, 0.6000000000000001, '0.6'),
#   Text(0, 0.8, '0.8'),
#   Text(0, 1.0, '1.0'),
#   Text(0, 1.2000000000000002, '1.2')])

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=par_desc_data2,x="voxels",legend=False,hue="replicate")
ax.yaxis.label.set_size(20)
#plt.legend(["MEHK","MEFC"],fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis number of voxels")
plt.yticks(fontsize=20)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2]),
#  [Text(0, 0.0, '0.0'),
#   Text(0, 0.2, '0.2'),
#   Text(0, 0.4, '0.4'),
#   Text(0, 0.6000000000000001, '0.6'),
#   Text(0, 0.8, '0.8'),
#   Text(0, 1.0, '1.0'),
#   Text(0, 1.2000000000000002, '1.2')])

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=par_desc_data1,x="height",legend=False,hue="replicate")
ax.yaxis.label.set_size(20)
#plt.legend(["MEHK","MEFC"],fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis height")
plt.yticks(fontsize=20)
# Out:
# (array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 ]),
#  [Text(0, 0.0, '0.00'),
#   Text(0, 0.05, '0.05'),
#   Text(0, 0.1, '0.10'),
#   Text(0, 0.15000000000000002, '0.15'),
#   Text(0, 0.2, '0.20'),
#   Text(0, 0.25, '0.25'),
#   Text(0, 0.30000000000000004, '0.30'),
#   Text(0, 0.35000000000000003, '0.35'),
#   Text(0, 0.4, '0.40')])

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=par_desc_data2,x="height",legend=False,hue="replicate")
ax.yaxis.label.set_size(20)
#plt.legend(["MEHK","MEFC"],fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis height")
plt.yticks(fontsize=20)
# Out:
# (array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35]),
#  [Text(0, 0.0, '0.00'),
#   Text(0, 0.05, '0.05'),
#   Text(0, 0.1, '0.10'),
#   Text(0, 0.15000000000000002, '0.15'),
#   Text(0, 0.2, '0.20'),
#   Text(0, 0.25, '0.25'),
#   Text(0, 0.30000000000000004, '0.30'),
#   Text(0, 0.35000000000000003, '0.35')])

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=par_desc_data1,x="width",legend=False,hue="replicate")
ax.yaxis.label.set_size(20)
#plt.legend(["MEHK","MEFC"],fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis width")
plt.yticks(fontsize=20)
# Out:
# (array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  ]),
#  [Text(0, 0.0, '0.00'),
#   Text(0, 0.25, '0.25'),
#   Text(0, 0.5, '0.50'),
#   Text(0, 0.75, '0.75'),
#   Text(0, 1.0, '1.00'),
#   Text(0, 1.25, '1.25'),
#   Text(0, 1.5, '1.50'),
#   Text(0, 1.75, '1.75'),
#   Text(0, 2.0, '2.00')])

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=par_desc_data2,x="width",legend=False,hue="replicate")
ax.yaxis.label.set_size(20)
#plt.legend(["MEHK","MEFC"],fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis width")
plt.yticks(fontsize=20)
# Out:
# (array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  ]),
#  [Text(0, 0.0, '0.00'),
#   Text(0, 0.25, '0.25'),
#   Text(0, 0.5, '0.50'),
#   Text(0, 0.75, '0.75'),
#   Text(0, 1.0, '1.00'),
#   Text(0, 1.25, '1.25'),
#   Text(0, 1.5, '1.50'),
#   Text(0, 1.75, '1.75'),
#   Text(0, 2.0, '2.00')])

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=par_desc_data1,x="depth",legend=False,hue="replicate")
ax.yaxis.label.set_size(20)
#plt.legend(["MEHK","MEFC"],fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis depth")
plt.yticks(fontsize=20)
# Out:
# (array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  ]),
#  [Text(0, 0.0, '0.00'),
#   Text(0, 0.25, '0.25'),
#   Text(0, 0.5, '0.50'),
#   Text(0, 0.75, '0.75'),
#   Text(0, 1.0, '1.00'),
#   Text(0, 1.25, '1.25'),
#   Text(0, 1.5, '1.50'),
#   Text(0, 1.75, '1.75'),
#   Text(0, 2.0, '2.00')])

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=par_desc_data2,x="depth",legend=False,hue="replicate")
ax.yaxis.label.set_size(20)
#plt.legend(["MEHK","MEFC"],fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis depth")
plt.yticks(fontsize=20)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8]),
#  [Text(0, 0.0, '0.0'),
#   Text(0, 0.2, '0.2'),
#   Text(0, 0.4, '0.4'),
#   Text(0, 0.6000000000000001, '0.6'),
#   Text(0, 0.8, '0.8'),
#   Text(0, 1.0, '1.0'),
#   Text(0, 1.2000000000000002, '1.2'),
#   Text(0, 1.4000000000000001, '1.4'),
#   Text(0, 1.6, '1.6'),
#   Text(0, 1.8, '1.8')])

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)
ax = sns.countplot(data=par_desc_data1,x="sensors",hue="replicate")
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of sensors")
ax.set_ylabel("Number of designs")
# Out:
# Text(0, 0.5, 'Number of designs')

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)
ax = sns.countplot(data=par_desc_data1,x="wheels",hue="replicate")
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of wheels")
ax.set_ylabel("Number of designs")
# Out:
# Text(0, 0.5, 'Number of designs')

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)
ax = sns.countplot(data=par_desc_data2,x="wheels",hue="replicate")
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of wheels")
ax.set_ylabel("Number of designs")
# Out:
# Text(0, 0.5, 'Number of designs')

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)
ax = sns.countplot(data=par_desc_data1,x="joints",hue="replicate")
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of joints")
ax.set_ylabel("Number of designs")
# Out:
# Text(0, 0.5, 'Number of designs')

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)
ax = sns.countplot(data=par_desc_data2,x="joints",hue="replicate")
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of joints")
ax.set_ylabel("Number of designs")
# Out:
# Text(0, 0.5, 'Number of designs')

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)
ax = sns.countplot(data=par_desc_data1,x="casters",hue="replicate")
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of casters")
ax.set_ylabel("Number of designs")
# Out:
# Text(0, 0.5, 'Number of designs')

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)
ax = sns.countplot(data=par_desc_data2,x="casters",hue="replicate")
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of casters")
ax.set_ylabel("Number of designs")
# Out:
# Text(0, 0.5, 'Number of designs')

# %% [markdown]
# # Novelty Search

# %%
novelty_folder = repo_folder + "/sq_cppn_novelty/"

# %%
parent_descs = []
for folder in os.listdir(novelty_folder):
    print(folder)
    descriptors = medf.load_feature_descriptor(novelty_folder + "/" + folder + "/morph_features.csv")
    descs = [[int(d[0])] + d[1:5] + [d[5]*16,d[6]*16,d[7]*16,d[8]*16] + d[9:]  + [folder] for d in descriptors]
    parent_descs += descs

par_desc_data1 = pd.DataFrame(data=parent_descs,columns=["robot id","width","depth","height","voxels","wheels","sensors","joints","casters","norm","skeleton norm","components norm","replicate"])
# Out:
# sq_cppn_novelty_11_11_16-47-17-7708-2918746651
# sq_cppn_novelty_11_11_16-47-9-9623-1733342887
# sq_cppn_novelty_11_11_16-50-58-8605-3290320857
# sq_cppn_novelty_11_11_16-55-15-5521-2919913596
# sq_cppn_novelty_11_11_17-11-54-4577-3466701940

# %% [markdown]
# ## Features

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=par_desc_data1,x="voxels",legend=False,hue="replicate")
ax.yaxis.label.set_size(20)
#plt.legend(["MEHK","MEFC"],fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis number of voxels")
plt.yticks(fontsize=20)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2]),
#  [Text(0, 0.0, '0.0'),
#   Text(0, 0.2, '0.2'),
#   Text(0, 0.4, '0.4'),
#   Text(0, 0.6000000000000001, '0.6'),
#   Text(0, 0.8, '0.8'),
#   Text(0, 1.0, '1.0'),
#   Text(0, 1.2000000000000002, '1.2')])

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=par_desc_data1,x="height",legend=False,hue="replicate")
ax.yaxis.label.set_size(20)
#plt.legend(["MEHK","MEFC"],fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis height")
plt.yticks(fontsize=20)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6., 7.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 1.0, '1'),
#   Text(0, 2.0, '2'),
#   Text(0, 3.0, '3'),
#   Text(0, 4.0, '4'),
#   Text(0, 5.0, '5'),
#   Text(0, 6.0, '6'),
#   Text(0, 7.0, '7')])

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=par_desc_data1,x="width",legend=False,hue="replicate")
ax.yaxis.label.set_size(20)
#plt.legend(["MEHK","MEFC"],fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis width")
plt.yticks(fontsize=20)
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 2.0, '2'),
#   Text(0, 4.0, '4'),
#   Text(0, 6.0, '6'),
#   Text(0, 8.0, '8'),
#   Text(0, 10.0, '10'),
#   Text(0, 12.0, '12')])

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=par_desc_data1,x="depth",legend=False,hue="replicate")
ax.yaxis.label.set_size(20)
#plt.legend(["MEHK","MEFC"],fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis depth")
plt.yticks(fontsize=20)
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12., 14.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 2.0, '2'),
#   Text(0, 4.0, '4'),
#   Text(0, 6.0, '6'),
#   Text(0, 8.0, '8'),
#   Text(0, 10.0, '10'),
#   Text(0, 12.0, '12'),
#   Text(0, 14.0, '14')])

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)
ax = sns.countplot(data=par_desc_data1,x="sensors",hue="replicate")
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of sensors")
ax.set_ylabel("Number of designs")
# Out:
# Text(0, 0.5, 'Number of designs')

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)
ax = sns.countplot(data=par_desc_data1,x="wheels",hue="replicate")
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of wheels")
ax.set_ylabel("Number of designs")
# Out:
# Text(0, 0.5, 'Number of designs')

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)
ax = sns.countplot(data=par_desc_data1,x="joints",hue="replicate")
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of joints")
ax.set_ylabel("Number of designs")
# Out:
# Text(0, 0.5, 'Number of designs')

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)
ax = sns.countplot(data=par_desc_data1,x="casters",hue="replicate")
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of casters")
ax.set_ylabel("Number of designs")
# Out:
# Text(0, 0.5, 'Number of designs')

# %% [markdown]
# ## Parenting, lineage, mutation

# %%
parents = medf.load_parenting(novelty_folder + "sq_cppn_novelty_11_11_16-47-17-7708-2918746651/parenting.csv")
offsprings = dict()
for key, value in parents.items():
    if value[0] in offsprings:
        offsprings[value[0]].append(key)
    else:
        offsprings[value[0]] = [key]

print(len(offsprings.keys()),offsprings.keys())
print(offsprings[27])
# Out:
# 283 dict_keys([-1, 27, 1, 25, 97, 26, 53, 9, 93, 88, 33, 16, 6, 90, 76, 41, 47, 37, 94, 99, 64, 59, 18, 52, 14, 98, 84, 19, 17, 45, 3, 48, 24, 44, 75, 21, 56, 80, 86, 8, 31, 32, 54, 13, 42, 11, 23, 36, 81, 71, 2, 29, 0, 74, 79, 87, 137, 104, 151, 128, 103, 190, 69, 153, 141, 154, 143, 177, 191, 182, 105, 175, 156, 189, 121, 140, 116, 112, 197, 144, 174, 142, 179, 100, 148, 184, 61, 192, 133, 96, 134, 181, 55, 124, 199, 296, 146, 299, 259, 161, 231, 238, 265, 218, 183, 269, 285, 268, 208, 213, 241, 258, 249, 22, 282, 233, 203, 204, 274, 210, 264, 228, 226, 290, 369, 334, 4, 306, 286, 211, 336, 393, 364, 355, 221, 206, 395, 420, 344, 422, 348, 352, 330, 471, 411, 431, 314, 511, 167, 518, 585, 540, 543, 519, 588, 279, 645, 552, 261, 671, 636, 652, 506, 682, 440, 715, 774, 864, 809, 832, 781, 797, 788, 880, 854, 794, 987, 1075, 1087, 975, 1056, 1127, 295, 1106, 1154, 1104, 1114, 1258, 1256, 1388, 1268, 1223, 1389, 1311, 1391, 1337, 1424, 1402, 1433, 1552, 1537, 1566, 1518, 1512, 1571, 15
# ...

# %%
novelty_scores = medf.load_fitness(novelty_folder + "sq_cppn_novelty_11_11_16-47-17-7708-2918746651/fitnesses.csv")
print(novelty_scores)
# Out:
# ([], [], [], [], [])

# %% [markdown]
# # MEIM

# %%
mehk_folder = repo_folder + "/sq_cppn_meim/"

# %%
parent_fits = []
for folder in os.listdir(mehk_folder):
    print(folder)
    parent_ids = medf.load_parent_pool(mehk_folder + "/" + folder + "/parents_pool.csv")
    ids, parents, fitnesses, evals, deltas = medf.load_fitness(mehk_folder + "/" + folder + "/fitness.csv")
    eval_times = medf.load_comp_time_dict(mehk_folder + "/" + folder + "/times.csv")
    fits = [[i,p[0],p[1],eval_times[i][0]/(1000000*3600),eval_times[i][1]/(1000000*3600),f,folder] for i, p, f in zip(ids,parents,fitnesses)]
    parent_fits += medf.filter_to_parent_pool(fits,parent_ids)
par_fit_data = pd.DataFrame(data=parent_fits,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","parent 1","parent 2","evaluation time","time","fitness","replicate"])
# Out:
# sq_cppn_meim_12_11_12-3-47-7776-2470449671
# sq_cppn_meim_12_11_12-3-50-825-188541801
# sq_cppn_meim_12_11_12-3-53-3784-4165195448
# sq_cppn_meim_12_11_12-3-56-6127-1379647653
# sq_cppn_meim_12_11_12-3-58-8722-2491805846

# %%
print(par_fit_data)
# Out:
#         iteration  robot index  discretized number of robots  \
# 0               0           24                           150
# 1               0           72                           150
# 2               0            8                           150
# 3               0           48                           150
# 4               0           14                           150
# ...           ...          ...                           ...
# 367295        658        10339                         10000
# 367296        658        10366                         10000
# 367297        658        10404                         10000
# 367298        658        10454                         10000
# 367299        658        10552                         10000
#
#         number of individuals  number new inds  parent 1  parent 2  \
# 0                         130              100        -1        -1
# 1                         130              100        -1        -1
# ...

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=par_fit_data,x="iteration",y="fitness",estimator=np.median,color='b')
sns.lineplot(data=par_fit_data,x="iteration",y="fitness",linestyle=":",estimator=np.max,ci=None,color='b')
sns.lineplot(data=par_fit_data,x="iteration",y="fitness",linestyle=":",estimator=np.min,ci=None,color='b')
# Out:
# /tmp/ipykernel_1422986/822971609.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=par_fit_data,x="iteration",y="fitness",linestyle=":",estimator=np.max,ci=None,color='b')
# /tmp/ipykernel_1422986/822971609.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=par_fit_data,x="iteration",y="fitness",linestyle=":",estimator=np.min,ci=None,color='b')
# <Axes: xlabel='iteration', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=par_fit_data,x="iteration",y="fitness",hue="replicate",estimator=np.median,color='b')
sns.lineplot(data=par_fit_data,x="iteration",y="fitness",hue="replicate",linestyle=":",estimator=np.max,ci=None,color='b')
sns.lineplot(data=par_fit_data,x="iteration",y="fitness",hue="replicate",linestyle=":",estimator=np.min,ci=None,color='b')
# Out:
# /tmp/ipykernel_1422986/1277936992.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=par_fit_data,x="iteration",y="fitness",hue="replicate",linestyle=":",estimator=np.max,ci=None,color='b')
# /tmp/ipykernel_1422986/1277936992.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=par_fit_data,x="iteration",y="fitness",hue="replicate",linestyle=":",estimator=np.min,ci=None,color='b')
# <Axes: xlabel='iteration', ylabel='fitness'>

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=par_fit_data,x="iteration",y="number of individuals",hue="replicate",estimator=None,color='b')

# %%
fig = plt.gcf()
fig.set_size_inches(20,10)
ax = sns.lineplot(data=par_fit_data,x="iteration",y="number new inds",hue="replicate",estimator=None,color='b')

# %%
fig = plt.gcf()
fig.set_size_inches(15,7.5)
ax = sns.lineplot(data=par_fit_data,x="discretized number of robots",y="fitness",hue="replicate",estimator=np.median,ci=None,color='b')
sns.lineplot(data=par_fit_data,x="discretized number of robots",y="fitness",hue="replicate",linestyle=":",estimator=np.max,ci=None,color='b',legend=False)
sns.lineplot(data=par_fit_data,x="discretized number of robots",y="fitness",hue="replicate",linestyle=":",estimator=np.min,ci=None,color='b',legend=False)
ax.set_xlabel("Number of designs")
ax.set_ylabel("Exploration score")
ax.xaxis.label.set_size(20)
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# /tmp/ipykernel_1422986/2545380895.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.lineplot(data=par_fit_data,x="discretized number of robots",y="fitness",hue="replicate",estimator=np.median,ci=None,color='b')
# /tmp/ipykernel_1422986/2545380895.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=par_fit_data,x="discretized number of robots",y="fitness",hue="replicate",linestyle=":",estimator=np.max,ci=None,color='b',legend=False)
# /tmp/ipykernel_1422986/2545380895.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=par_fit_data,x="discretized number of robots",y="fitness",hue="replicate",linestyle=":",estimator=np.min,ci=None,color='b',legend=False)
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  [Text(0, -0.2, '−0.2'),
#   Text(0, 0.0, '0.0'),
# ...

# %%
parent_descs = []
for folder in os.listdir(mehk_folder):
    print(folder)
    parent_ids = medf.load_parent_pool(mehk_folder + "/" + folder + "/parents_pool.csv")
    descriptors = medf.load_feature_descriptor(mehk_folder + "/" + folder + "/morph_features.csv")
    descs = [[int(d[0])] + d[1:5] + [d[5]*16,d[6]*16,d[7]*16,d[8]*16] + d[9:]  + [folder] for d in descriptors]
    parent_descs += medf.filter_to_parent_pool(descs,parent_ids)

par_desc_data1 = pd.DataFrame(data=parent_descs,columns=["iteration","robot index","discretized number of robots","number of individuals","number new inds","width","depth","height","voxels","wheels","sensors","joints","casters","norm","skeleton norm","components norm","replicate"])
# Out:
# sq_cppn_meim_12_11_12-3-47-7776-2470449671
# sq_cppn_meim_12_11_12-3-50-825-188541801
# sq_cppn_meim_12_11_12-3-53-3784-4165195448
# sq_cppn_meim_12_11_12-3-56-6127-1379647653
# sq_cppn_meim_12_11_12-3-58-8722-2491805846

# %%
desc_data = pd.merge(par_desc_data1,par_fit_data,how="left",on=["iteration","robot index","replicate","discretized number of robots","number of individuals","number new inds"])
desc_data = desc_data.drop_duplicates(subset=['robot index','replicate'])

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=desc_data,x="width",cut=0)
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis width")
ax = plt.twinx()
sns.scatterplot(data=desc_data,x="width",y="fitness",ax=ax,s=10,legend=False,alpha=0.2)
ax.set_ylabel("Exploration score")
ax.yaxis.label.set_size(20)
plt.yticks(fontsize=20)
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  [Text(1, -0.2, '−0.2'),
#   Text(1, 0.0, '0.0'),
#   Text(1, 0.2, '0.2'),
#   Text(1, 0.4000000000000001, '0.4'),
#   Text(1, 0.6000000000000001, '0.6'),
#   Text(1, 0.8, '0.8'),
#   Text(1, 1.0000000000000002, '1.0')])

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=desc_data,x="depth",cut=0)
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis depth")
ax = plt.twinx()
sns.scatterplot(data=desc_data,x="depth",y="fitness",ax=ax,s=10,legend=False,alpha=0.2)
ax.set_ylabel("Exploration score")
ax.yaxis.label.set_size(20)
plt.yticks(fontsize=20)
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  [Text(1, -0.2, '−0.2'),
#   Text(1, 0.0, '0.0'),
#   Text(1, 0.2, '0.2'),
#   Text(1, 0.4000000000000001, '0.4'),
#   Text(1, 0.6000000000000001, '0.6'),
#   Text(1, 0.8, '0.8'),
#   Text(1, 1.0000000000000002, '1.0')])

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=desc_data,x="height",cut=0)
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis height")
ax = plt.twinx()
sns.scatterplot(data=desc_data,x="height",y="fitness",ax=ax,s=10,legend=False,alpha=0.2)
ax.set_ylabel("Exploration score")
ax.yaxis.label.set_size(20)
plt.yticks(fontsize=20)
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  [Text(1, -0.2, '−0.2'),
#   Text(1, 0.0, '0.0'),
#   Text(1, 0.2, '0.2'),
#   Text(1, 0.4000000000000001, '0.4'),
#   Text(1, 0.6000000000000001, '0.6'),
#   Text(1, 0.8, '0.8'),
#   Text(1, 1.0000000000000002, '1.0')])

# %%
fig = plt.gcf()
fig.set_size_inches(10,5)
ax = sns.kdeplot(data=desc_data,x="voxels",cut=0)
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Chassis voxels")
ax = plt.twinx()
sns.scatterplot(data=desc_data,x="voxels",y="fitness",ax=ax,s=10,legend=False,alpha=0.2)
ax.set_ylabel("Exploration score")
ax.yaxis.label.set_size(20)
plt.yticks(fontsize=20)
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  [Text(1, -0.2, '−0.2'),
#   Text(1, 0.0, '0.0'),
#   Text(1, 0.2, '0.2'),
#   Text(1, 0.4000000000000001, '0.4'),
#   Text(1, 0.6000000000000001, '0.6'),
#   Text(1, 0.8, '0.8'),
#   Text(1, 1.0000000000000002, '1.0')])

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)

ax = sns.countplot(data=desc_data,x="sensors",alpha=0.5)
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of sensors")
ax.set_ylabel("Percentage of designs")
ax = plt.twinx()
sns.boxplot(data=desc_data,x="sensors",y="fitness",ax=ax,fill=False,legend=False)
ax.set_ylabel("Exploration score")
ax.yaxis.label.set_size(20)
ax.xaxis.set_major_formatter('{x:}')
plt.yticks(fontsize=20)
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  [Text(1, -0.2, '−0.2'),
#   Text(1, 0.0, '0.0'),
#   Text(1, 0.2, '0.2'),
#   Text(1, 0.4000000000000001, '0.4'),
#   Text(1, 0.6000000000000001, '0.6'),
#   Text(1, 0.8, '0.8'),
#   Text(1, 1.0000000000000002, '1.0')])

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)
ax = sns.countplot(data=desc_data,x="joints",alpha=0.5)
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of joints")
ax.set_ylabel("Percentage of designs")
ax = plt.twinx()
sns.boxplot(data=desc_data,x="joints",y="fitness",ax=ax,fill=False,legend=False)
ax.set_ylabel("Exploration score")
ax.yaxis.label.set_size(20)
ax.xaxis.set_major_formatter('{x:}')
plt.yticks(fontsize=20)
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  [Text(1, -0.2, '−0.2'),
#   Text(1, 0.0, '0.0'),
#   Text(1, 0.2, '0.2'),
#   Text(1, 0.4000000000000001, '0.4'),
#   Text(1, 0.6000000000000001, '0.6'),
#   Text(1, 0.8, '0.8'),
#   Text(1, 1.0000000000000002, '1.0')])

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)
ax = sns.countplot(data=desc_data,x="wheels",alpha=0.5)
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of wheels")
ax.set_ylabel("Percentage of designs")
ax = plt.twinx()
sns.boxplot(data=desc_data,x="wheels",y="fitness",ax=ax,fill=False,legend=False)
ax.set_ylabel("Exploration score")
ax.yaxis.label.set_size(20)
ax.xaxis.set_major_formatter('{x:}')
plt.yticks(fontsize=20)
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  [Text(1, -0.2, '−0.2'),
#   Text(1, 0.0, '0.0'),
#   Text(1, 0.2, '0.2'),
#   Text(1, 0.4000000000000001, '0.4'),
#   Text(1, 0.6000000000000001, '0.6'),
#   Text(1, 0.8, '0.8'),
#   Text(1, 1.0000000000000002, '1.0')])

# %%
fig = plt.gcf()
fig.set_size_inches(7,7)
ax = sns.countplot(data=desc_data,x="casters",alpha=0.5)
ax.yaxis.label.set_size(20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.xaxis.label.set_size(20)
ax.set_xlabel("Number of casters")
ax.set_ylabel("Percentage of designs")
ax = plt.twinx()
sns.boxplot(data=desc_data,x="casters",y="fitness",ax=ax,fill=False,legend=False)
ax.set_ylabel("Exploration score")
ax.yaxis.label.set_size(20)
ax.xaxis.set_major_formatter('{x:}')
plt.yticks(fontsize=20)
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  [Text(1, -0.2, '−0.2'),
#   Text(1, 0.0, '0.0'),
#   Text(1, 0.2, '0.2'),
#   Text(1, 0.4000000000000001, '0.4'),
#   Text(1, 0.6000000000000001, '0.6'),
#   Text(1, 0.8, '0.8'),
#   Text(1, 1.0000000000000002, '1.0')])
