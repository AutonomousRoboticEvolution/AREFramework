# %%
import csv
import matplotlib.pyplot as plt
import os
import imageio


def load_fitness(filename) :
    print(filename)

    with open(filename) as file :
        csv_data = csv.reader(file,delimiter=',')
        fitnesses = []
        for row in csv_data :
            fitnesses.append(float(row[206]))
        return fitnesses
def load_final_pos(filename,pop,gen) :
    with open(filename) as file :
        csv_data = csv.reader(file,delimiter=',')
        x = []
        y = []
        for row in csv_data :
            if(float(row[1]) == gen) :
                i = 0
                j = 2
                while(i < pop - 1):
                    if(j >= len(row) -1) :
                        break
                    if(float(row[j]) == i and float(row[j+1]) != i+1) :
                        x.append(float(row[j+1]))
                        y.append(float(row[j+2]))
                        j+=3
                    
                    j+=1
                    i+=1
                break
        return x, y
def load_eval_time(filename) :
    with open(filename) as file :
        csv_data = csv.reader(file,delimiter=',')
        durations = []
        eval_nb = []
        i = 1
        for row in csv_data :
            durations.append(float(row[1])/1000000000.)
            eval_nb.append(i)
            i+=1
    return eval_nb, durations
def best_fit(fitnesses_vec) :
    best_fits = []
    for fits in fitnesses_vec :
        best_fits.append(max(fits))
    return best_fits
def animation_pop(foldername,pop,max_gen,step) :
    plt.ioff()
    images = []
    for i in range(0,max_gen,step) :
        x_vec = []
        y_vec = []
        for folder in os.listdir(foldername) :
            if(not os.path.isdir(foldername + folder)) :
                continue
            x, y = load_final_pos(foldername + folder + "/final_pos.csv",pop,i)
            x_vec = x_vec + x
            y_vec = y_vec + y   
                
        fig2, ax2 = plt.subplots(figsize=[10,10])
        ax2.set_ylim(-1.,1.)
        ax2.set_xlim(-1.,1.)
        plt.title("Generation " + str(i))
        plt.plot(x_vec,y_vec,'o')
        plt.savefig(foldername + "/pop_" + str(i) + ".jpg")
        plt.close(fig2)
        images.append(imageio.imread(foldername + "/pop_" + str(i) + ".jpg"))
        os.remove(foldername + "/pop_" + str(i) + ".jpg")
    imageio.mimwrite(foldername + "/pop_gen.gif",images)

# %%
ne_arena = "/home/le_goff/are-logs/are_ne_arena/"
x_vec = []
y_vec = []

for folder in os.listdir(ne_arena) :
    if(not os.path.isdir(ne_arena + folder)) :
        continue
    fit = load_fitness(ne_arena + folder + "/fitnesses_hn.csv")
    fig, ax = plt.subplots()
#     ax.set_xlim(0,250)
    plt.plot(fit)
    plt.show()
    eval_nb, eval_time = load_eval_time(ne_arena + folder + "/eval_durations.csv")
    fig, ax = plt.subplots(figsize=[20,5])
    ax.set_xlim(0,300)
    plt.plot(eval_nb,eval_time,'.')
    plt.show()
    
animation_pop(ne_arena,200,100,1)
# Out:
# /home/le_goff/are-logs/are_ne_arena/neuroEvolution25_1_19-10-0-412/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_arena/neuroEvolution25_1_19-9-48-8223/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_arena/neuroEvolution25_1_19-10-3-3277/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_arena/neuroEvolution25_1_19-9-58-8583/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_arena/neuroEvolution25_1_19-9-41-1297/fitnesses_hn.csv

# %%
ne_easy_race = "/home/le_goff/are-logs/are_ne_easy_race/"
x_vec = []
y_vec = []
for folder in os.listdir(ne_easy_race) :
    if(not os.path.isdir(ne_easy_race + folder)) :
        continue
    fit = load_fitness(ne_easy_race + folder + "/fitnesses_hn.csv")
    fig, ax = plt.subplots()
#     ax.set_xlim(0,250)
    plt.plot(fit)
    plt.show()
    eval_nb, eval_time = load_eval_time(ne_easy_race + folder + "/eval_durations.csv")
    fig, ax = plt.subplots(figsize=[20,5])
    ax.set_xlim(0,300)
    plt.plot(eval_nb,eval_time,'.')
    plt.show()

    
    
animation_pop(ne_easy_race,200,100,1)
# Out:
# /home/le_goff/are-logs/are_ne_easy_race/neuroEvolution25_1_19-14-54-4780/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_easy_race/neuroEvolution25_1_19-14-46-6393/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_easy_race/neuroEvolution25_1_19-14-46-6325/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_easy_race/neuroEvolution25_1_19-15-6-6011/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_easy_race/neuroEvolution25_1_19-14-50-102/fitnesses_hn.csv

# %%
ne_empty = "/home/le_goff/are-logs/are_ne_escape/"
x_vec = []
y_vec = []
for folder in os.listdir(ne_empty) :
    if(not os.path.isdir(ne_empty + folder)) :
        continue
    fit = load_fitness(ne_empty + folder + "/fitnesses_hn.csv")
    fig, ax = plt.subplots()
#     ax.set_xlim(0,250)
    plt.plot(fit)
    plt.show()
    
animation_pop(ne_empty,200,100,1)
# Out:
# /home/le_goff/are-logs/are_ne_escape/neuroEvolution25_1_19-8-34-4075/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape/neuroEvolution25_1_19-8-43-3164/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape/neuroEvolution25_1_19-8-23-3097/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape/neuroEvolution25_1_19-8-52-2183/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape/neuroEvolution25_1_19-8-53-3200/fitnesses_hn.csv

# %%
ne_escape_0 = "/home/le_goff/are-logs/are_ne_escape_0/"
x_vec = []
y_vec = []
for folder in os.listdir(ne_escape_0) :
    if(not os.path.isdir(ne_escape_0 + folder)) :
        continue
    fit = load_fitness(ne_escape_0 + folder + "/fitnesses_hn.csv")
    fig, ax = plt.subplots()
#     ax.set_xlim(0,250)
    plt.plot(fit)
    plt.show()
    
animation_pop(ne_escape_0,200,100,1)
# Out:
# /home/le_goff/are-logs/are_ne_escape_0/neuroEvolution27_1_11-45-26-6109/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape_0/neuroEvolution27_1_11-47-42-2934/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape_0/neuroEvolution27_1_11-45-26-6849/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape_0/neuroEvolution27_1_11-45-15-5145/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape_0/neuroEvolution27_1_11-47-31-1004/fitnesses_hn.csv

# %%
ne_escape_02 = "/home/le_goff/are-logs/are_ne_escape_02/"
x_vec = []
y_vec = []
for folder in os.listdir(ne_escape_02) :
    if(not os.path.isdir(ne_escape_02 + folder)) :
        continue
    fit = load_fitness(ne_escape_02 + folder + "/fitnesses_hn.csv")
    fig, ax = plt.subplots()
#     ax.set_xlim(0,250)
    plt.plot(fit)
    plt.show()
    
animation_pop(ne_escape_02,200,100,1)
# Out:
# /home/le_goff/are-logs/are_ne_escape_02/neuroEvolution27_1_11-51-20-942/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape_02/neuroEvolution27_1_11-51-40-655/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape_02/neuroEvolution27_1_11-51-29-9433/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape_02/neuroEvolution27_1_11-51-29-9777/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape_02/neuroEvolution27_1_11-51-39-9391/fitnesses_hn.csv

# %%
ne_easy_race_0 = "/home/le_goff/are-logs/are_ne_easy_race_0/"
x_vec = []
y_vec = []
for folder in os.listdir(ne_easy_race_0) :
    if(not os.path.isdir(ne_easy_race_0 + folder)) :
        continue
    fit = load_fitness(ne_easy_race_0 + folder + "/fitnesses_hn.csv")
    fig, ax = plt.subplots()
#     ax.set_xlim(0,250)
    plt.plot(fit)
    plt.show()
    
animation_pop(ne_easy_race_0,200,100,1)
# Out:
# /home/le_goff/are-logs/are_ne_easy_race_0/neuroEvolution27_1_11-52-23-3710/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_easy_race_0/neuroEvolution27_1_11-52-23-3742/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_easy_race_0/neuroEvolution27_1_11-52-33-3711/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_easy_race_0/neuroEvolution27_1_11-52-16-6106/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_easy_race_0/neuroEvolution27_1_11-52-26-6886/fitnesses_hn.csv

# %%
list_dir = ["/home/le_goff/are-logs/are_ne_arena/", \
            "/home/le_goff/are-logs/are_ne_escape_0/", \
            "/home/le_goff/are-logs/are_ne_escape_02/", \
            "/home/le_goff/are-logs/are_ne_easy_race_0/", \
            "/home/le_goff/are-logs/are_ne_easy_race/"]
list_label = ["arena","escape","escape_var","easy_race","easy_race_var"]
best_fits = []
i = 0
for dire in list_dir :
    fitnesses = []
    for folder in os.listdir(dire) :
        if(folder.split("E")[0] != "neuro") :
            continue
        fitnesses.append(load_fitness(dire + folder + "/fitnesses_hn.csv"))
    print(len(fitnesses),len(fitnesses[0]))
    best_fits.append(best_fit(fitnesses))
    i+=1
plt.figure(figsize=(10,5))
plt.boxplot(best_fits,labels=list_label)
plt.ylabel("best fitness")
plt.xlabel("acquisition fct")
plt.show()
# Out:
# /home/le_goff/are-logs/are_ne_arena/neuroEvolution25_1_19-10-0-412/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_arena/neuroEvolution25_1_19-9-48-8223/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_arena/neuroEvolution25_1_19-10-3-3277/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_arena/neuroEvolution25_1_19-9-58-8583/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_arena/neuroEvolution25_1_19-9-41-1297/fitnesses_hn.csv
# 5 300
# /home/le_goff/are-logs/are_ne_escape_0/neuroEvolution27_1_11-45-26-6109/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape_0/neuroEvolution27_1_11-47-42-2934/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape_0/neuroEvolution27_1_11-45-26-6849/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape_0/neuroEvolution27_1_11-45-15-5145/fitnesses_hn.csv
# /home/le_goff/are-logs/are_ne_escape_0/neuroEvolution27_1_11-47-31-1004/fitnesses_hn.csv
# 5 300
# /home/le_goff/are-logs/are_ne_escape_02/neuroEvolution27_1_11-51-20-942/fitnesses_hn.csv
# ...
