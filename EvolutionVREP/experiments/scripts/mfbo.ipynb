# %%
import csv
import matplotlib.pyplot as plt
import os
def load_fitness(filename) :
    with open(filename) as file :
        csv_data = csv.reader(file,delimiter=',')
        fitnesses = []
        for row in csv_data :
            fitnesses.append(float(row[2]))
        return fitnesses
def load_final_pos(filename) :
    with open(filename) as file :
        csv_data = csv.reader(file,delimiter=',')
        x = []
        y = []
        for row in csv_data :
            x.append(float(row[1]))
            y.append(float(row[2]))
        return x, y

# %%
print("Model Free Bayes Opt with UCB acqui fct and 100 samples")
mfbo_ucb = "/home/le_goff/are-logs/are_mfbo_ucb/"
for folder in os.listdir(mfbo_ucb) :
    if(folder.split("_")[0] != "model") :
        continue
    fit = load_fitness(mfbo_ucb + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
    ax.set_xlim([99,120])
    plt.plot(fit)
    plt.show()
# Out:
# Model Free Bayes Opt with UCB acqui fct and 100 samples

# %%
print("Model Free Bayes Opt with GP-UCB acqui fct and 100 samples")
mfbo_gpucb = "/home/le_goff/are-logs/are_mfbo_gpucb/"
for folder in os.listdir(mfbo_gpucb) :
    if(folder.split("_")[0] != "model") :
        continue
    fit = load_fitness(mfbo_gpucb + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
    ax.set_xlim([99,200])
    plt.plot(fit)
    plt.show()
# Out:
# Model Free Bayes Opt with GP-UCB acqui fct and 100 samples

# %%
print("Model Free Bayes Opt with EI acqui fct and 100 samples")
mfbo_ei = "/home/le_goff/are-logs/are_mfbo_ei/"
for folder in os.listdir(mfbo_ei) :
    if(folder.split("_")[0] != "model") :
        continue
    fit = load_fitness(mfbo_ei + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
    ax.set_xlim([99,200])
    plt.plot(fit)
    plt.show()
# Out:
# Model Free Bayes Opt with EI acqui fct and 100 samples

# %%
print("Model Free Bayes Opt with UCB acqui fct and 20 samples")
mfbo_ucb_20 = "/home/le_goff/are-logs/are_mfbo_ucb_20/"
for folder in os.listdir(mfbo_ucb_20) :
    if(folder.split("_")[0] != "model") :
        continue
    fit = load_fitness(mfbo_ucb_20 + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
    ax.set_xlim([20,70])
    plt.plot(fit)
    plt.show()
# Out:
# Model Free Bayes Opt with UCB acqui fct and 20 samples

# %%
print("Model Free Bayes Opt with EI acqui fct and 20 samples")
mfbo_ei_20 = "/home/le_goff/are-logs/are_mfbo_ei_20/"
for folder in os.listdir(mfbo_ei_20) :
    if(folder.split("_")[0] != "model") :
        continue
    fit = load_fitness(mfbo_ei_20 + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
    ax.set_xlim([20,70])
    plt.plot(fit)
    plt.show()
# Out:
# Model Free Bayes Opt with EI acqui fct and 20 samples

# %%
print("Model Free Bayes Opt with UCB acqui fct and 20 samples modif in the algo")
mfbo_ucb_20_2 = "/home/le_goff/are-logs/are_mfbo_ucb_20-2/"
for folder in os.listdir(mfbo_ucb_20_2) :
    if(folder.split("_")[0] != "model") :
        continue
    fit = load_fitness(mfbo_ucb_20_2 + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
    ax.set_xlim([20,70])
    plt.plot(fit)
    plt.show()
# Out:
# Model Free Bayes Opt with UCB acqui fct and 20 samples modif in the algo

# %%
print("Model Free Bayes Opt with UCB acqui fct and 100 samples hard maze")
mfbo_hard_maze_t1 = "/home/leni/are-logs/mfbo_hard_maze_t1/"
for folder in os.listdir(mfbo_hard_maze_t1) :
    if(folder.split("_")[0] != "model") :
        continue
    print(folder)
    fit = load_fitness(mfbo_hard_maze_t1 + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
    ax.set_ylim(-1.5,0)
    ax.set_xlim([200,250])
    plt.plot(fit)
    plt.show()
# Out:
# Model Free Bayes Opt with UCB acqui fct and 100 samples hard maze
# model_free_bayes_opt24_0_12-8-47-7593
# model_free_bayes_opt24_0_12-8-45-5643
# model_free_bayes_opt24_0_12-8-45-5641
# model_free_bayes_opt24_0_12-8-49-9581
# model_free_bayes_opt24_0_12-8-47-7595
# model_free_bayes_opt24_0_12-8-47-7597
# model_free_bayes_opt24_0_12-8-45-5642
# model_free_bayes_opt24_0_12-8-49-9580

# %%
print("Model Free Bayes Opt with UCB acqui fct and 100 samples hard maze")
mfbo_hard_maze_t2 = "/home/leni/are-logs/mfbo_hard_maze_t2/"
for folder in os.listdir(mfbo_hard_maze_t2) :
    if(folder.split("_")[0] != "model") :
        continue
    print(folder)
    fit = load_fitness(mfbo_hard_maze_t2 + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
    ax.set_ylim(-1.5,0)
    ax.set_xlim([200,250])
    plt.plot(fit)
    plt.show()
# Out:
# Model Free Bayes Opt with UCB acqui fct and 100 samples hard maze
# model_free_bayes_opt24_0_16-38-15-5023
# model_free_bayes_opt24_0_16-38-13-3149
# model_free_bayes_opt24_0_16-38-13-3148
# model_free_bayes_opt24_0_16-38-15-5032
# model_free_bayes_opt24_0_16-38-15-5029
# model_free_bayes_opt24_0_16-38-13-3147
# model_free_bayes_opt24_0_16-38-13-3084
# model_free_bayes_opt24_0_16-38-15-5022

# %%
mfbo_easy_race_90 = "/home/le_goff/are-logs/are_mfbo_easy_race/"
for folder in os.listdir(mfbo_easy_race_90) :
    if(folder.split("_")[0] != "model") :
        continue
    print(folder)
    fit = load_fitness(mfbo_easy_race_90 + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
#    ax.set_ylim(-1.5,0)
    ax.set_xlim([200,300])
    plt.plot(fit)
    plt.show()
# Out:
# model_free_bayes_opt27_0_15-13-26-6459
# model_free_bayes_opt27_0_15-13-22-2440
# model_free_bayes_opt27_0_15-13-22-2438
# model_free_bayes_opt27_0_15-13-20-505
# model_free_bayes_opt27_0_15-13-20-509
# model_free_bayes_opt27_0_15-13-24-4432
# model_free_bayes_opt27_0_15-13-24-4430
# model_free_bayes_opt27_0_15-13-20-503

# %%
mfbo_easy_race_120 = "/home/le_goff/are-logs/are_mfbo_easy_race_120/"
for folder in os.listdir(mfbo_easy_race_120) :
    if(folder.split("_")[0] != "model") :
        continue
    print(folder)
    fit = load_fitness(mfbo_easy_race_120 + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
#    ax.set_ylim(-1.5,0)
    ax.set_xlim([200,300])
    plt.plot(fit)
    plt.show()
# Out:
# model_free_bayes_opt28_0_11-4-25-5090
# model_free_bayes_opt28_0_11-4-25-5089
# model_free_bayes_opt28_0_11-4-23-3140
# model_free_bayes_opt28_0_11-4-23-3163
# model_free_bayes_opt28_0_11-4-25-5157
# model_free_bayes_opt28_0_11-4-23-3110
# model_free_bayes_opt28_0_11-4-23-3164
# model_free_bayes_opt28_0_11-4-23-3141
# model_free_bayes_opt28_0_11-4-27-7149

# %%
are_mfbo_arena = "/home/le_goff/are-logs/are_mfbo_arena/"
for folder in os.listdir(are_mfbo_arena) :
    if(folder.split("_")[0] != "model") :
        continue
    print(folder)
    fit = load_fitness(are_mfbo_arena + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
#    ax.set_ylim(-1.5,0)
    ax.set_xlim([200,300])
    plt.plot(fit)
    plt.show()
    
    x, y = load_final_pos(are_mfbo_arena + folder + "/final_pos.csv")
    fig2, ax2 = plt.subplots()
    ax2.set_ylim(-0.75,0.75)
    ax2.set_xlim(-0.75,0.75)
    plt.plot(x[:200],y[:200],'.',label="initial dataset")
    plt.plot(x[200:],y[200:],'+',label="bayesian opt sampling")
    plt.legend(loc=1,bbox_to_anchor=(1, 1.2))
    plt.show()
# Out:
# model_free_bayes_opt31_0_16-7-19-9394
# model_free_bayes_opt31_0_16-7-19-9419
# model_free_bayes_opt31_0_16-7-21-1383
# model_free_bayes_opt31_0_16-7-21-1379
# model_free_bayes_opt31_0_16-7-21-1377
# model_free_bayes_opt31_0_16-7-19-9400
# model_free_bayes_opt31_0_16-7-21-1389

# %%
are_mfbo_arena_ei_100 = "/home/le_goff/are-logs/are_mfbo_arena_ei_100/"
for folder in os.listdir(are_mfbo_arena_ei_100) :
    if(folder.split("_")[0] != "model") :
        continue
    print(folder)
    fit = load_fitness(are_mfbo_arena_ei_100 + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
#    ax.set_ylim(-1.5,0)
    ax.set_xlim([200,300])
    plt.plot(fit)
    plt.show()
    
    x, y = load_final_pos(are_mfbo_arena_ei_100 + folder + "/final_pos.csv")
    fig2, ax2 = plt.subplots()
    ax2.set_ylim(-0.75,0.75)
    ax2.set_xlim(-0.75,0.75)
    plt.plot(x[:200],y[:200],'.',label="initial dataset")
    plt.plot(x[200:],y[200:],'+',label="bayesian opt sampling")
    plt.legend(loc=1,bbox_to_anchor=(1, 1.2))
    plt.show()
# Out:
# model_free_bayes_opt4_1_10-42-28-8462
# model_free_bayes_opt4_1_10-42-28-8397
# model_free_bayes_opt4_1_10-42-34-4368
# model_free_bayes_opt4_1_10-42-28-8406
# model_free_bayes_opt4_1_10-42-30-350
# model_free_bayes_opt4_1_10-42-30-386
# model_free_bayes_opt4_1_10-42-30-351
# model_free_bayes_opt4_1_10-42-32-2359

# %%
are_mfbo_arena_ei_10 = "/home/le_goff/are-logs/are_mfbo_arena_ei_10/"
for folder in os.listdir(are_mfbo_arena_ei_10) :
    if(folder.split("_")[0] != "model") :
        continue
    print(folder)
    fit = load_fitness(are_mfbo_arena_ei_10 + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
#    ax.set_ylim(-1.5,0)
    ax.set_xlim([200,300])
    plt.plot(fit)
    plt.show()
    
    x, y = load_final_pos(are_mfbo_arena_ei_10 + folder + "/final_pos.csv")
    fig2, ax2 = plt.subplots()
    ax2.set_ylim(-0.75,0.75)
    ax2.set_xlim(-0.75,0.75)
    plt.plot(x[:200],y[:200],'.',label="initial dataset")
    plt.plot(x[200:],y[200:],'+',label="bayesian opt sampling")
    plt.legend(loc=1,bbox_to_anchor=(1, 1.2))
    plt.show()
# Out:
# model_free_bayes_opt4_1_10-43-58-8745
# model_free_bayes_opt4_1_10-43-58-8744
# model_free_bayes_opt4_1_10-43-58-8670
# model_free_bayes_opt4_1_10-43-58-8672
# model_free_bayes_opt4_1_10-43-58-8662
# model_free_bayes_opt4_1_10-43-58-8728
# model_free_bayes_opt4_1_10-43-58-8669
# model_free_bayes_opt4_1_10-43-58-8743

# %%
are_mfbo_arena_ei_1 = "/home/le_goff/are-logs/are_mfbo_arena_ei_1/"
for folder in os.listdir(are_mfbo_arena_ei_1) :
    if(folder.split("_")[0] != "model") :
        continue
    print(folder)
    fit = load_fitness(are_mfbo_arena_ei_1 + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
#    ax.set_ylim(-1.5,0)
    ax.set_xlim([200,300])
    plt.plot(fit)
    plt.show()
    
    x, y = load_final_pos(are_mfbo_arena_ei_1 + folder + "/final_pos.csv")
    fig2, ax2 = plt.subplots()
    ax2.set_ylim(-0.75,0.75)
    ax2.set_xlim(-0.75,0.75)
    plt.plot(x[:200],y[:200],'.',label="initial dataset")
    plt.plot(x[200:],y[200:],'+',label="bayesian opt sampling")
    plt.legend(loc=1,bbox_to_anchor=(1, 1.2))
    plt.show()
# Out:
# model_free_bayes_opt4_1_10-44-0-640
# model_free_bayes_opt4_1_10-44-0-639
# model_free_bayes_opt4_1_10-44-0-659
# model_free_bayes_opt4_1_10-44-0-624
# model_free_bayes_opt4_1_10-44-0-638

# %%
are_mfbo_arena_ei_01 = "/home/le_goff/are-logs/are_mfbo_arena_ei_01/"
for folder in os.listdir(are_mfbo_arena_ei_01) :
    if(folder.split("_")[0] != "model") :
        continue
    print(folder)
    fit = load_fitness(are_mfbo_arena_ei_01 + folder + "/bo_data.csv")
    fig, ax = plt.subplots()
#    ax.set_ylim(-1.5,0)
    ax.set_xlim([200,300])
    plt.plot(fit)
    plt.show()
    
    x, y = load_final_pos(are_mfbo_arena_ei_01 + folder + "/final_pos.csv")
    fig2, ax2 = plt.subplots()
    ax2.set_ylim(-0.75,0.75)
    ax2.set_xlim(-0.75,0.75)
    plt.plot(x[:200],y[:200],'.',label="initial dataset")
    plt.plot(x[200:],y[200:],'+',label="bayesian opt sampling")
    plt.legend(loc=1,bbox_to_anchor=(1, 1.2))
    plt.show()
# Out:
# model_free_bayes_opt4_1_10-50-48-8195
# model_free_bayes_opt4_1_10-50-52-2199
# model_free_bayes_opt4_1_10-50-46-6277
# model_free_bayes_opt4_1_10-50-50-264
# model_free_bayes_opt4_1_10-50-46-6276
