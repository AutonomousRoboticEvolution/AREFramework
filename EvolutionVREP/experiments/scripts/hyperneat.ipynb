# %%
import csv
import matplotlib.pyplot as plt
import os
def load_fitness(filename) :
    print(filename)
    with open(filename) as file :
        print(filename)
        csv_data = csv.reader(file,delimiter=',')
        fitnesses = []
        for row in csv_data :
            fitnesses.append(float(row[406]))
        return fitnesses

# %%
hn_hard_maze_t1 = "/home/le_goff/are-logs/hyperneat_hard_maze_t1/"
for folder in os.listdir(hn_hard_maze_t1) :

    fit = load_fitness(hn_hard_maze_t1 + folder + "/fitnesses_hn.csv")
    fig, ax = plt.subplots()
    plt.plot(fit)
    plt.show()
# Out:
# /home/le_goff/are-logs/hyperneat_hard_maze_t1/hyperneat23_0_16-56-17-7090/fitnesses_hn.csv
# /home/le_goff/are-logs/hyperneat_hard_maze_t1/hyperneat23_0_16-56-21-1024/fitnesses_hn.csv
# /home/le_goff/are-logs/hyperneat_hard_maze_t1/hyperneat23_0_16-56-20-994/fitnesses_hn.csv
# /home/le_goff/are-logs/hyperneat_hard_maze_t1/hyperneat23_0_16-56-17-7118/fitnesses_hn.csv
# /home/le_goff/are-logs/hyperneat_hard_maze_t1/hyperneat23_0_16-56-23-3031/fitnesses_hn.csv
# /home/le_goff/are-logs/hyperneat_hard_maze_t1/hyperneat23_0_16-56-19-9083/fitnesses_hn.csv
# /home/le_goff/are-logs/hyperneat_hard_maze_t1/hyperneat23_0_16-56-17-7120/fitnesses_hn.csv
# /home/le_goff/are-logs/hyperneat_hard_maze_t1/hyperneat23_0_16-56-19-9159/fitnesses_hn.csv

# %%
hn_hard_maze_t2 = "/home/le_goff/are-logs/hyperneat_hard_maze_t2/"
for folder in os.listdir(hn_hard_maze_t2) :

    fit = load_fitness(hn_hard_maze_t2 + folder + "/fitnesses_hn.csv")
    fig, ax = plt.subplots()
    plt.plot(fit)
    plt.show()
# Out:
# /home/le_goff/are-logs/hyperneat_hard_maze_t2/hyperneat24_0_16-40-25-5974/fitnesses_hn.csv
# /home/le_goff/are-logs/hyperneat_hard_maze_t2/hyperneat24_0_16-40-27-7901/fitnesses_hn.csv
# /home/le_goff/are-logs/hyperneat_hard_maze_t2/hyperneat24_0_16-40-25-5973/fitnesses_hn.csv
# /home/le_goff/are-logs/hyperneat_hard_maze_t2/hyperneat24_0_16-40-24-4005/fitnesses_hn.csv
# /home/le_goff/are-logs/hyperneat_hard_maze_t2/hyperneat24_0_16-40-25-5970/fitnesses_hn.csv
# /home/le_goff/are-logs/hyperneat_hard_maze_t2/hyperneat24_0_16-40-25-5981/fitnesses_hn.csv
# /home/le_goff/are-logs/hyperneat_hard_maze_t2/hyperneat24_0_16-40-24-4035/fitnesses_hn.csv

# %%
hn_easy_race = "/home/le_goff/are-logs/are_hn_easy_race_90/"
for folder in os.listdir(hn_easy_race) :

    fit = load_fitness(hn_easy_race + folder + "/fitnesses_hn.csv")
    fig, ax = plt.subplots()
    plt.plot(fit)
    plt.show()

# %%
hn_race = "/home/le_goff/are-logs/are_hn_race/"
for folder in os.listdir(hn_race) :

    fit = load_fitness(hn_race + folder + "/fitnesses_hn.csv")
    fig, ax = plt.subplots()
    ax.set_xlim(0,250)
    plt.plot(fit)
    plt.show()
# Out:
# /home/le_goff/are-logs/are_hn_race/hyperneat30_0_14-11-53-3463/fitnesses_hn.csv
# /home/le_goff/are-logs/are_hn_race/hyperneat30_0_13-36-4-4850/fitnesses_hn.csv
# /home/le_goff/are-logs/are_hn_race/hyperneat30_0_18-34-30-979/fitnesses_hn.csv
# /home/le_goff/are-logs/are_hn_race/hyperneat30_0_13-36-4-4862/fitnesses_hn.csv
# /home/le_goff/are-logs/are_hn_race/hyperneat30_0_13-36-11-1357/fitnesses_hn.csv
# /home/le_goff/are-logs/are_hn_race/hyperneat30_0_13-38-30-352/fitnesses_hn.csv

# %%
hn_easy_race = "/home/le_goff/are-logs/are_hn_easy_race_90/"
for folder in os.listdir(hn_easy_race) :

    fit = load_fitness(hn_easy_race + folder + "/fitnesses_hn.csv")
    fig, ax = plt.subplots()
    plt.plot(fit)
    plt.show()
# Out:
# /home/le_goff/are-logs/are_hn_easy_race_90/hyperneat27_0_15-8-32-2060/fitnesses_hn.csv
# /home/le_goff/are-logs/are_hn_easy_race_90/hyperneat27_0_15-8-32-2024/fitnesses_hn.csv
# /home/le_goff/are-logs/are_hn_easy_race_90/hyperneat27_0_15-8-30-91/fitnesses_hn.csv
# /home/le_goff/are-logs/are_hn_easy_race_90/hyperneat27_0_15-8-30-90/fitnesses_hn.csv
# /home/le_goff/are-logs/are_hn_easy_race_90/hyperneat27_0_15-8-32-2059/fitnesses_hn.csv
